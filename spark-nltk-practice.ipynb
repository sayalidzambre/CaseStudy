# %%
import findspark
# provide path to your spark directory directly
findspark.init("/home/canwill/spark2")
import pyspark
sc = pyspark.SparkContext(appName="helloworld")

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
# %%bash
# wget "https://en.wikipedia.org/wiki/Python_(programming_language)" #Python Wikipedia Page
# Out:
# --2017-04-13 16:37:48--  https://en.wikipedia.org/wiki/Python_(programming_language)
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.154.224, 2620:0:861:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.154.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 338014 (330K) [text/html]
# Saving to: ‘Python_(programming_language)’
#
#      0K .......... .......... .......... .......... .......... 15%  109K 3s
#     50K .......... .......... .......... .......... .......... 30%  228K 2s
#    100K .......... .......... .......... .......... .......... 45% 1.13M 1s
#    150K .......... .......... .......... .......... .......... 60% 1.24M 0s
#    200K .......... .......... .......... .......... .......... 75%  281K 0s
#    250K .......... .......... .......... .......... .......... 90% 1.18M 0s
#    300K .......... .......... ..........                      100% 62.2K=1.5s
#
# 2017-04-13 16:37:50 (226 KB/s) - ‘Python_(programming_language)’ saved [338014/338014]

# %%
# %%bash
# mv 'Python_(programming_language)' python_wiki
# Out:
# mv: cannot stat 'Python_(programming_language)': No such file or directory

# %%
# %%bash
# ls
# Out:
# bank_cross_sale.ipynb
# churn_measurements.py
# ColorQuantization
# credit_risk_modeling.ipynb
# customer_churn.ipynb
# data
# medaplexis
# python_wiki
# README.md
# sms_spam_collector.ipynb
# sms_spam_detector.pkl
# spark-wiki-practice.ipynb

# %%
lines = sc.textFile("python_wiki")

# %%
lines.take(5)
# Out:
# [u'<!DOCTYPE html>',
#  u'<html class="client-nojs" lang="en" dir="ltr">',
#  u'<head>',
#  u'<meta charset="UTF-8"/>',
#  u'<title>Python (programming language) - Wikipedia</title>']

# %%
lines.count()
# Out:
# 1261

# %%
import nltk

# %%
from pyspark import SparkConf
from pyspark import SparkContext

conf = SparkConf()
conf.setMaster('yarn-client')
conf.setAppName('spark-nltk')
sc = SparkContext(conf=conf)

data = sc.textFile('file:///usr/share/nltk_data/corpora/state_union/1972-Nixon.txt')

def word_tokenize(x):
    import nltk
    return nltk.word_tokenize(x)

def pos_tag(x):
    import nltk
    return nltk.pos_tag([x])

words = data.flatMap(word_tokenize)
print words.take(10)

pos_word = words.map(pos_tag)
print pos_word.take(5)

# %%
import nltk
import re
import string

from nltk.corpus import wordnet as wn

wnl = nltk.WordNetLemmatizer()
#html_parser = HTMLParser()

stopword_list = nltk.corpus.stopwords.words('english')
stopword_list = stopword_list + ['mr', 'mrs', 'come', 'go', 'get',
                                 'tell', 'listen', 'one', 'two', 'three',
                                 'four', 'five', 'six', 'seven', 'eight',
                                 'nine', 'zero', 'join', 'find', 'make',
                                 'say', 'ask', 'tell', 'see', 'try', 'back',
                                 'also', '', None, ' ']
def word_tokenize(text):
    tokens = nltk.word_tokenize(text) 
    tokens = [token.strip() for token in tokens]
    return tokens

def remove_special_characters(text):
    tokens = text
    pattern = re.compile('[{}]'.format(re.escape(string.punctuation)))
    filtered_tokens = filter(None, [pattern.sub(' ', token) for token in tokens])
    return filtered_tokens
    
    
def remove_stopwords(text):
    tokens = text
    filtered_tokens = [token for token in tokens if token.strip() not in stopword_list]
    return filtered_tokens


# Annotate text tokens with POS tags
def pos_tag_text(words):
    
    def penn_to_wn_tags(pos_tag):
        if pos_tag.startswith('J'):
            return wn.ADJ
        elif pos_tag.startswith('V'):
            return wn.VERB
        elif pos_tag.startswith('N'):
            return wn.NOUN
        elif pos_tag.startswith('R'):
            return wn.ADV
        else:
            return None
        
        
    def pos_tagging(words):
        print 'pos_tagging'
        return nltk.pos_tag(words)
    
    tagged_words = pos_tagging(words)
    print 'pos_tagging'
    tagged_lower_text = [(word.lower(), penn_to_wn_tags(pos_tag))
                         for word, pos_tag in
                         tagged_words]
    return tagged_lower_text
    


def lemmatize_text(words):
    print 'lemma'
    pos_tagged_words = pos_tag_text(words)
    print 'pos done'
    lemmatized_tokens = [wnl.lemmatize(word, pos_tag) if pos_tag
                         else word                     
                         for word, pos_tag in pos_tagged_words]
    return lemmatized_tokens

def parse_hippa(text):
    hippa_pattern = '[[^a-zA-Z0-9]*/*[[^a-zA-Z0-9., -_]*/*[^a-zA-Z0-9., -_]*]*~]*'    
    if re.match(hippa_pattern, text)    :
        text = re.sub('\*','\* ', text)
        text = re.sub('~',' ~ ', text)
 
    return text

# %%
import pandas as pd
data = pd.read_csv('data/retuters_test_data.csv', sep='\t')
data = spark.createDataFrame(data)
data.take(20)
# Out:
# [Row(Unnamed: 0=0, text=u'SANDOZ PLANS WEEDKILLER JOINT VENTURE IN USSR\n\nSandoz AG said it planned a joint venture to produce herbicides in the Soviet Union. The company said it had signed a letter of intent with the Soviet Ministry of Fertiliser Production to form the first foreign joint venture the ministry had undertaken since the Soviet Union allowed Western firms to enter into joint ventures two months ago. The ministry and Sandoz will each have a 50 pct stake, but a company spokeswoman was unable to give details of the size of investment or planned output. Reuter \x03', tags=u'usa,ussr'),
#  Row(Unnamed: 0=1, text=u'TAIWAN REJECTS TEXTILE MAKERS EXCHANGE RATE PLEA\n\nCentral bank governor Chang Chi-cheng rejected a request by textile makers to halt the rise of the Taiwan dollar against the U.S. Dollar to stop them losing orders to South Korea, Hong Kong and Singapore, a spokesman for the Taiwan Textile Federation said. He quoted Chang as telling representatives of 19 textile associations last Saturday the government could not fix the Taiwan dollar exchange rate at 35 to one U.S. Dollar due to U.S. Pressure for an appreciation of the local currency. The Federation asked the government on February 19 to hold the exchange rate at that level. The federation said in its request that many local textile exporters were operating without profit and would go out of business if the rate continued to fall. Reuter \x03', tags=u'usa,taiwan'),
#  Row(Unnamed: 0=2, text=u'NATIONAL FSI INC <NFSI> 4TH QTR LOSS\n\nShr loss six cts vs profit 19 cts Net loss 166,000 vs profit 580,000 Revs 3,772,000 vs 5,545,000 Year Shr loss 13 cts vs profit 52 cts Net loss 391,000 vs profit 1,425,000 Revs 15.4 mln vs 16.6 mln NOTE: 1985 year figures pro forma for purchase accounting adjustments resulting from March 1985 reeacquisition of company by its original shareholders before August 1985 initial public offering. Reuter \x03', tags=u'earn,usa'),
#  Row(Unnamed: 0=3, text=u'OCCIDENTAL <OXY> OFFICIAL RESIGNS\n\nMidCon Corp, a subsidiary of Occidental Petroleum Corp <OXY>, said William C. Terpstra has resigned as president and chief operating officer and his reponsibilities will be assumed by MidCon chairman O.C. Davis. No reason was given. Reuter \x03', tags=u'usa'),
#  Row(Unnamed: 0=4, text=u"ITALY'S BNL TO ISSUE 120 MLN DLR CONVERTIBLE BOND\n\nItaly's state-owned <Banca Nazionale del Lavoro - BNL> said it would issue 120 mln dlrs of five-year convertible eurobonds, an operation to be lead-managed by <Credit Suisse-First Boston Ltd>. BNL president Nerio Nesi told a news conference that the issue, to be placed on the main international markets and listed in Luxembourg, would be the first equity linked issue by an Italian bank on the Euromarket. BNL officials said the issue is scheduled for mid-March and additional financial details were not immediately available. They said the operation would be through the issue of depositary receipts by BNL's London branch. They said the bonds would carry warrants issued by its <Efibanca> subsidiary and convertible into BNL saving shares within five years. The officials said a banking consortium led by Credit Suisse-First Boston would at the same time arrange for the private placing of an unspecified number of BNL savings shares with foreign institutional investors. The operation was to further its aim of obtaining a listing on foreign stock exchanges with a view to future capital increases through ordinary share issues, they said. REUTER \x03", tags=u'italy'),
#  Row(Unnamed: 0=5, text=u"GE <GE> SAYS AMR <AMR> ORDER WORTH 650 MLN DLRS\n\nGeneral Electric Co said AMR Corp's oprder of GE CFG-80C2 engines to power 25 new <Airbus Industrie> A300-600R and 15 Boeing Co <BA> 767-300ER twinjets is worth over 650 mln dlrs. The company said the order is the largest single one it has ever received for commercial aircraft engines. AMR announced the order earlier today. GE said deliveries will start in early 1988. Reuter \x03", tags=u'usa'),
#  Row(Unnamed: 0=6, text=u'<PRECAMBRIAN SHIELD RESOURCES LTD> YEAR LOSS\n\nShr loss 1.93 dlrs vs profit 16 cts Net loss 53,412,000 vs profit 4,479,000 Revs 24.8 mln vs 32.7 mln Note: 1986 shr and net include 51,187,000 dlr writedown on U.S. operations, uneconomic coal operations and other mineral properties Reuter \x03', tags=u'earn,canada'),
#  Row(Unnamed: 0=7, text=u"U.K. MONEY MARKET GIVEN FURTHER 437 MLN STG HELP\n\nThe Bank of England said it had provided the money market with a further 437 mln stg assistance in the afternoon session. This brings the Bank's total help so far today to 461 mln stg and compares with its revised shortage forecast of 450 mln stg. The central bank made purchases of bank bills outright comprising 120 mln stg in band one at 10-7/8 pct and 315 mln stg in band two at 10-13/16 pct. In addition, it also bought two mln stg of treasury bills in band two at 10-13/16 pct. REUTER \x03", tags=u'money-fx,interest,uk'),
#  Row(Unnamed: 0=8, text=u'GREASE MONKEY HOLDING CORP <GMHC> YEAR NOV 30\n\nShr nil vs nil Net 130,998 vs 30,732 Revs 1,568,941 vs 1,0053,234 Reuter \x03', tags=u'earn,usa'),
#  Row(Unnamed: 0=9, text=u'ACCEPTANCE INSURANCE HOLDINGS INC <ACPT> YEAR\n\nOper shr profit 1.80 dlrs vs loss 2.28 dlrs Oper net profit 2,048,0000 vs loss 1,318,000 Revs 25.4 mln vs 12.3 mln Avg shrs 1,135,000 vs 576,000 NOTE: Net excludes realized investment gains of 40,000 dlrs vs 13,000 dlrs. 1986 net excludes 729,000 dlr tax credit. Reuter \x03', tags=u'earn,usa'),
#  Row(Unnamed: 0=10, text=u'MINSTAR INC <MNST> 4TH QTR NET\n\nOper shr loss 31 cts vs loss 30 cts Oper net loss 5,429,000 vs loss 5,216,000 Revs 257.5 mln vs 243.6 mln Avg shrs 17.5 mln vs 13.5 mln Year Oper shr loss eight cts vs profit 28 cts Oper net loss 1,324,000 vs profit 4,067,000 Revs 989.5 mln vs 747.9 mln Avg shrs 17.6 mln vs 15.7 mln NOTE: 1986 operating net loss excludes income from discontinued operations equal to 11 cts in the quarter and 66 cts in the year compared with 1.07 dlrs in the quarter and 1.23 dlrs in the respective periods of 1985. 1986 operating net loss also excludes extraordinary charges of 14 cts in the quarter and 54 cts in the year. 1985 operating net profit excludes an extraordinary gain of 47 cts. Reuter \x03', tags=u'earn,usa'),
#  Row(Unnamed: 0=11, text=u"DAI-ICHI HOTEL SWISS FRANC NOTES COUPON CUT\n\nThe coupon on Dai-Ichi Hotel Ltd's 50 mln Swiss franc issue of five-year notes with equity warrants has been cut to 1-5/8 pct from the indicated 1-7/8 pct, lead manager Swiss Volksbank said. The warrants have an exercise price of 1,507 yen per share, compared with the last traded price of 1,470 yen, it said. The notes are guarantees by Long-Term Credit Bank of Japan Ltd. Payment is due on March 25. REUTER \x03", tags=u'switzerland'),
#  Row(Unnamed: 0=12, text=u'<MARK RESOURCES INC> YEAR LOSS\n\nShr not given Loss 54.9 mln Revs 27.2 mln Note: Prior year results not given. 1986 results include accounts of 89 pct owned <Precambrian Shield Resources Ltd>, acquired November 5, 1986 Reuter \x03', tags=u'earn,canada'),
#  Row(Unnamed: 0=13, text=u'SAAB-SCANIA ISSUES 150 MLN DLR EUROBOND\n\nSaab-Scania AB is issuing a 150 mln dlr eurobond due April 2, 1992 paying 7-3/4 pct and priced at 101-3/4 pct, lead manager Morgan Guaranty Ltd said. The bond is available in denominations of 5,000 and 50,000 dlrs and will be listed in London. Payment date is April 2, 1992. Fees comprise 1-1/4 pct selling concession and 5/8 pct management and underwriting combined, and listing will be in London. REUTER \x03', tags=u'uk'),
#  Row(Unnamed: 0=14, text=u'TRANSFORM LOGIC <TOOG> REVISES RESULTS DOWNWARD\n\nTransform Logic Corp said it has revised downward its previously reported fourth quarter and year, ended October 31, results to reflect compensation expense for employee stock options. The company said resolution of this disagreement with its auditors came as a result of Securities and Exchange Commission involvement. The company will amend its option-granting procedure to conform to the SEC decision which will eliminate future charges, it added. Transform said its fourth quarter profit was revised to 305,082 dlrs, or two cts a share, from the previously reported 580,955 dlrs, which left the company with a fiscal 1986 loss of 249,814 dlrs, or two cts a share, instead of the reported 26,195 dlrs profit. Reuter \x03', tags=u'earn,usa'),
#  Row(Unnamed: 0=15, text=u'AMERICAN STORES <ASC> SEES LOWER YEAR NET\n\nAmerican Stores Co said it expects to report earnings per share of 3.70 to 3.85 dlrs per share on sales of slightly over 14 billion dlrs for the year ended January 31. The supermarket chain earned 4.11 dlrs per share on sales of 13.89 billion dlrs last year. The company did not elaborate. Reuter \x03', tags=u'earn,usa'),
#  Row(Unnamed: 0=16, text=u'KASLER CORP <KASL> 1ST QTR JAN 31 NET\n\nShr profit three cts vs loss seven cts Net profit 161,000 vs loss 367,000 Revs 24.3 mln vs 26.5 mln Reuter \x03', tags=u'earn,usa'),
#  Row(Unnamed: 0=17, text=u'CARIBBEAN SELECT <CSEL> TO REDEEM WARRANTS\n\nCaribbean Select Inc said it has elected to redeem on April 10 all its Class A warrants and all Class B warrants at 0.01 ct each. At the same time, it said its board has decided to reduce the exercise price of the Class B warrants to 3.50 dlrs per common share from four dlrs to encourage the exercise of the warrants. Each Class B warrant allows the purchase of one common share. It said each Class A warrant is still exercisable into one common share at two dlrs each. Reuter \x03', tags=u'usa'),
#  Row(Unnamed: 0=18, text=u'UNILEVER HAS IMPROVED MARGINS, VOLUMES IN 1986\n\nUnilever Plc <UN.A> and NV group reported improvements in margins and underlying sales volume growth of five pct in 1986 after stripping out the effects of falling prices, disposals and currency movements, Unilever Plc chairman Michael Angus said. He told reporters that volumes in North America increased some 10.5 pct while European consumer goods rose about 2.5 pct after being flat for some years. Much of the disposal strategy, aimed at concentrating activities on core businesses, had now been completed, he noted. But the process of acquisitions would go on, with strategic acquisitions taking place "from time to time," he said. The company earlier reported a 20 pct rise in pre-tax profits for 1986 to 1.14 billion stg from 953 mln previously. In guilder terms, however, profits at the pre-tax level dropped three pct to 3.69 billion from 3.81 billion. Angus said the recent purchase of Chesebrough-Pond\'s Inc <CBM.N> for 72.50 dlrs a share was unlikely to bring any earnings dilution. However, it would not add much to profits, with much of the company\'s operating profits paying for the acquisition costs. Finance director Niall Fitzgerald added that while gearing - debt to equity plus debt - rose to about 60 pct at end 1986 from 35 pct last year, this was expected to drop back to about 40 pct by end-1987. The same divergence was made in full year dividend, with Unilever NV\'s rising 3.4 pct to 15.33 guilders and Unilever Plc\'s increasing 29.9 pct to 50.17p, approximately in line with the change in attributable profit. Angus said the prospectus for the sale of parts of Chesebrough was due to be published shortly. However, he said that there was no target date for completing the process. He also declined to say what sort of sum Unilever hoped to realise from the operation, beyond noting that Chesebrough had paid around 1.25 billion dlrs for Stauffer Chemical Co, which operates outside Unilever\'s core activities. In the U.S., Organic growth from the Lipton Foods business, considerable expansion in the household products business and in margarine had been behind the overall sales increase. However, he noted that the U.S. Household products business had turned in a planned loss, with fourth quarter performance better than expected despite the anticipated heavy launch costs of its Surf detergents. Reuter \x03', tags=u'earn,uk'),
#  Row(Unnamed: 0=19, text=u'SARA LEE <SLE> TO BUY 34 PCT OF DIM\n\nSara Lee Corp said it agreed to buy a 34 pct interest in Paris-based DIM S.A., a subsidiary of BIC S.A., at a cost of about 84 mln dlrs. DIM S.A., a hosiery manufacturer, had 1985 sales of about 260 mln dlrs. The investment includes the purchase of 360,537 newly issued DIM shares valued at about 51 mln dlrs and a loan of about 33 mln dlrs, it said. The loan is convertible into an additional 229,463 DIM shares, it noted. The proposed agreement is subject to approval by the French government, it said. Reuter \x03', tags=u'acq,usa')]

# %%
data.printSchema()
# Out:
# root
#  |-- Unnamed: 0: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- tags: string (nullable = true)

# %%
datas = sc.textFile('data/retuters_test_data.csv')

# %%
def normalize_data(line):
    words = word_tokenize(line)
    words = remove_special_characters(words)
    words = remove_stopwords(words)
    words = lemmatize_text(words)
    return words

# %%
words = lines.map(word_tokenize)
words = words.map(remove_special_characters)
words = words.map(remove_stopwords)
words = words.map(lemmatize_text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-9a478b071d78> in <module>()
# ----> 1 words = lines.map(word_tokenize)
#       2 words = words.map(remove_special_characters)
#       3 words = words.map(remove_stopwords)
#       4 words = words.map(lemmatize_text)
#
# TypeError: 'Column' object is not callable

# %%
words.take(20)
# Out:
# [[u'doctype', u'html'],
#  [u'html', u'class ', u'client nojs', u'lang ', u'en', u'dir ', u'ltr'],
#  [u'head'],
#  [u'meta', u'charset ', u'utf 8'],
#  [u'title', u'python', u'programming', u'language', u'wikipedia', u' title'],
#  [u'script',
#   u'document documentelement classname',
#   u'document documentelement classname replace',
#   u'client nojs',
#   u'1client js',
#   u'2',
#   u' script'],
#  [u'script',
#   u'window rlq window rlq  ',
#   u' push',
#   u'function',
#   u'mw config set',
#   u'wgcanonicalnamespace',
#   u'wgcanonicalspecialpagename',
#   u'false',
#   u'wgnamespacenumber',
#   u' 0',
#   u'wgpagename',
#   u'python ',
#   u'programming language',
#   u'wgtitle',
#   u'python',
#   u'programming',
#   u'language',
#   u'wgcurrevisionid',
#   u' 774758975',
#   u'wgrevisionid',
#   u' 774758975',
#   u'wgarticleid',
#   u' 23862',
#   u'wgisarticle',
#   u'true',
#   u'wgisredirect',
#   u'false',
#   u'wgaction',
#   u'view',
#   u'wgusername',
#   u'null',
#   u'wgusergroups',
#   u'wgcategories',
#   u'wikipedia',
#   u'article',
#   u'need',
#   u'page',
#   u'number',
#   u'citation',
#   u'january',
#   u'2012',
#   u'article',
#   u'contain',
#   u'potentially',
#   u'dated',
#   u'statement',
#   u'august',
#   u'2016',
#   u'all',
#   u'article',
#   u'contain',
#   u'potentially',
#   u'dated',
#   u'statement',
#   u'article',
#   u'contain',
#   u'potentially',
#   u'dated',
#   u'statement',
#   u'march',
#   u'2017',
#   u'article',
#   u'dmoz',
#   u'link',
#   u'wikipedia',
#   u'article',
#   u'lccn',
#   u'identifier',
#   u'wikipedia',
#   u'article',
#   u'gnd',
#   u'identifier',
#   u'wikipedia',
#   u'article',
#   u'bnf',
#   u'identifier',
#   u'good',
#   u'article',
#   u'use',
#   u'dmy',
#   u'date',
#   u'august',
#   u'2015',
#   u'class based',
#   u'program',
#   u'language',
#   u'computational',
#   u'notebook',
#   u'computer',
#   u'science',
#   u'netherlands',
#   u'cross platform',
#   u'free',
#   u'software',
#   u'dutch',
#   u'invention',
#   u'dynamically',
#   u'type',
#   u'program',
#   u'language',
#   u'educational',
#   u'programming',
#   u'language',
#   u'high level',
#   u'program',
#   u'language',
#   u'information',
#   u'technology',
#   u'netherlands',
#   u'object oriented',
#   u'programming',
#   u'language',
#   u'program',
#   u'language',
#   u'create',
#   u'1991',
#   u'python',
#   u'program',
#   u'language',
#   u'script',
#   u'language',
#   u'text oriented',
#   u'program',
#   u'language',
#   u'wgbreakframes',
#   u'false',
#   u'wgpagecontentlanguage',
#   u'en',
#   u'wgpagecontentmodel',
#   u'wikitext',
#   u'wgseparatortransformtable',
#   u'wgdigittransformtable',
#   u'wgdefaultdateformat',
#   u'dmy',
#   u'wgmonthnames',
#   u'january',
#   u'february',
#   u'march',
#   u'april',
#   u'may',
#   u'june',
#   u'july',
#   u'august',
#   u'september',
#   u'october',
#   u'november',
#   u'december',
#   u'wgmonthnamesshort',
#   u'jan',
#   u'feb',
#   u'mar',
#   u'apr',
#   u'may',
#   u'jun',
#   u'jul',
#   u'aug',
#   u'sep',
#   u'oct',
#   u'nov',
#   u'dec',
#   u'wgrelevantpagename',
#   u'python ',
#   u'programming language',
#   u'wgrelevantarticleid',
#   u' 23862',
#   u'wgrequestid',
#   u'wouv9qpamesaabpszoaaaabn',
#   u'wgisprobablyeditable',
#   u'true',
#   u'wgrestrictionedit',
#   u'wgrestrictionmove',
#   u'wgflaggedrevsparams',
#   u'tag',
#   u'wgstablerevisionid',
#   u'null',
#   u'wgwikieditorenabledmodules',
#   u'toolbar',
#   u'true',
#   u'dialog',
#   u'true',
#   u'preview',
#   u'false',
#   u'publish',
#   u'false',
#   u'wgbetafeaturesfeatures',
#   u'wgmediavieweronclick',
#   u'true',
#   u'wgmediaviewerenabledbydefault',
#   u'true',
#   u'wgpopupsshouldsendmoduletouser',
#   u'false',
#   u'wgpopupsconflictswithnavpopupgadget',
#   u'false',
#   u'wgvisualeditor',
#   u'pagelanguagecode',
#   u'en',
#   u'pagelanguagedir',
#   u'ltr',
#   u'usepageimages',
#   u'true',
#   u'usepagedescriptions',
#   u'true',
#   u'wgpreferredvariant',
#   u'en',
#   u'wgmfdisplaywikibasedescriptions',
#   u'search',
#   u'true',
#   u'nearby',
#   u'true',
#   u'watchlist',
#   u'true',
#   u'tagline',
#   u'false',
#   u'wgrelatedarticles',
#   u'null',
#   u'wgrelatedarticlesbetafeatureenabled',
#   u'false',
#   u'wgrelatedarticlesusecirrussearch',
#   u'true',
#   u'wgrelatedarticlesonlyusecirrussearch',
#   u'false',
#   u'wgulscurrentautonym',
#   u'english',
#   u'wgnoticeproject',
#   u'wikipedia',
#   u'wgcentralnoticecookiestodelete',
#   u'wgcentralnoticecategoriesusinglegacy',
#   u'fundraise',
#   u'fundraise',
#   u'wgcategorytreepagecategoryoptions',
#   u'mode ',
#   u' 0',
#   u'hideprefix ',
#   u' 20',
#   u'showcount ',
#   u'true',
#   u'namespaces ',
#   u'false',
#   u'wgwikibaseitemid',
#   u'q28865',
#   u'wgcentralauthmobiledomain',
#   u'false',
#   u'wgvisualeditortoolbarscrolloffset',
#   u' 0',
#   u'wgeditsubmitbuttonlabelpublish',
#   u'false',
#   u'mw loader state',
#   u'ext globalcssjs user styles',
#   u'ready',
#   u'ext globalcssjs site styles',
#   u'ready',
#   u'site styles',
#   u'ready',
#   u'noscript',
#   u'ready',
#   u'user styles',
#   u'ready',
#   u'user',
#   u'ready',
#   u'user options',
#   u'load',
#   u'user tokens',
#   u'loading',
#   u'ext cite styles',
#   u'ready',
#   u'wikibase client init',
#   u'ready',
#   u'ext visualeditor desktoparticletarget noscript',
#   u'ready',
#   u'ext uls interlanguage',
#   u'ready',
#   u'ext wikimediabadges',
#   u'ready',
#   u'mediawiki legacy shared',
#   u'ready',
#   u'mediawiki legacy commonprint',
#   u'ready',
#   u'mediawiki sectionanchor',
#   u'ready',
#   u'mediawiki skinning interface',
#   u'ready',
#   u'skins vector styles',
#   u'ready',
#   u'ext globalcssjs user',
#   u'ready',
#   u'ext globalcssjs site',
#   u'ready',
#   u'mw loader implement',
#   u'user options',
#   u'0j3lz3q',
#   u'function',
#   u'jquery',
#   u'require',
#   u'module',
#   u'mw user options set',
#   u'variant',
#   u'en',
#   u'mw loader implement',
#   u'user tokens',
#   u'1dqfd7l',
#   u'function',
#   u'jquery',
#   u'require',
#   u'module'],
#  [u'mw user tokens set',
#   u'edittoken',
#   u'patroltoken',
#   u'watchtoken',
#   u'csrftoken',
#   u'nomin  '],
#  [],
#  [u'mw loader load',
#   u'ext cite a11y',
#   u'mediawiki toc',
#   u'mediawiki action view postedit',
#   u'site',
#   u'mediawiki page startup',
#   u'mediawiki user',
#   u'mediawiki hidpi',
#   u'mediawiki page ready',
#   u'mediawiki legacy wikibits',
#   u'mediawiki searchsuggest',
#   u'ext gadget teahouse',
#   u'ext gadget referencetooltips',
#   u'ext gadget watchlist notice',
#   u'ext gadget drn wizard',
#   u'ext gadget charinsert',
#   u'ext gadget reftoolbar',
#   u'ext gadget extra toolbar buttons',
#   u'ext gadget switcher',
#   u'ext gadget featured articles links',
#   u'ext centralauth centralautologin',
#   u'mmv head',
#   u'mmv bootstrap autostart',
#   u'ext visualeditor desktoparticletarget init',
#   u'ext visualeditor targetloader',
#   u'ext eventlogging subscriber',
#   u'ext wikimediaevents',
#   u'ext navigationtiming',
#   u'ext uls eventlogger',
#   u'ext uls init',
#   u'ext uls interface',
#   u'ext quicksurveys init',
#   u'ext centralnotice geoip',
#   u'ext centralnotice startup',
#   u'skins vector js',
#   u' script'],
#  [u'link',
#   u'rel ',
#   u'stylesheet',
#   u'href ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules ext cite styles',
#   u'7cext uls interlanguage',
#   u'7cext visualeditor desktoparticletarget noscript',
#   u'7cext wikimediabadges',
#   u'7cmediawiki legacy commonprint',
#   u'2cshared',
#   u'7cmediawiki sectionanchor',
#   u'7cmediawiki skinning interface',
#   u'7cskins vector styles',
#   u'7cwikibase client init',
#   u'amp',
#   u'only styles',
#   u'amp',
#   u'skin vector'],
#  [u'script',
#   u'async ',
#   u'src ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules startup',
#   u'amp',
#   u'only scripts',
#   u'amp',
#   u'skin vector',
#   u' script'],
#  [u'meta', u'name ', u'resourceloaderdynamicstyles', u'content '],
#  [u'link',
#   u'rel ',
#   u'stylesheet',
#   u'href ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules site styles',
#   u'amp',
#   u'only styles',
#   u'amp',
#   u'skin vector'],
#  [u'meta',
#   u'name ',
#   u'generator',
#   u'content ',
#   u'mediawiki',
#   u'1 29 0 wmf 19'],
#  [u'meta', u'name ', u'referrer', u'content ', u'origin when cross origin'],
#  [u'link',
#   u'rel ',
#   u'alternate',
#   u'href ',
#   u'android app',
#   u'  org wikipedia http en m wikipedia org wiki python ',
#   u'programming language'],
#  [u'link',
#   u'rel ',
#   u'alternate',
#   u'type ',
#   u'application x wiki',
#   u'title ',
#   u'edit',
#   u'page',
#   u'href ',
#   u' w index php',
#   u'title python ',
#   u'programming language',
#   u'amp',
#   u'action edit'],
#  [u'link',
#   u'rel ',
#   u'edit',
#   u'title ',
#   u'edit',
#   u'page',
#   u'href ',
#   u' w index php',
#   u'title python ',
#   u'programming language',
#   u'amp',
#   u'action edit'],
#  [u'link',
#   u'rel ',
#   u'apple touch icon',
#   u'href ',
#   u' static apple touch wikipedia png']]

# %% [raw]
# Difference between map and flat map -
# map will append list in list
# flatmap will extend list in list

# %%
words = lines.flatMap(word_tokenize)

# %%
words.take(20)
# Out:
# [[u'DOCTYPE', u'html'],
#  [u'html', u'class ', u'client nojs', u'lang ', u'en', u'dir ', u'ltr'],
#  [u'head'],
#  [u'meta', u'charset ', u'UTF 8'],
#  [u'title', u'Python', u'programming', u'language', u'Wikipedia', u' title'],
#  [u'script',
#   u'document documentElement className',
#   u'document documentElement className replace',
#   u'client nojs',
#   u'1client js',
#   u'2',
#   u' script'],
#  [u'script',
#   u'window RLQ window RLQ  ',
#   u' push',
#   u'function',
#   u'mw config set',
#   u'wgCanonicalNamespace',
#   u'wgCanonicalSpecialPageName',
#   u'false',
#   u'wgNamespaceNumber',
#   u' 0',
#   u'wgPageName',
#   u'Python ',
#   u'programming language',
#   u'wgTitle',
#   u'Python',
#   u'programming',
#   u'language',
#   u'wgCurRevisionId',
#   u' 774758975',
#   u'wgRevisionId',
#   u' 774758975',
#   u'wgArticleId',
#   u' 23862',
#   u'wgIsArticle',
#   u'true',
#   u'wgIsRedirect',
#   u'false',
#   u'wgAction',
#   u'view',
#   u'wgUserName',
#   u'null',
#   u'wgUserGroups',
#   u'wgCategories',
#   u'Wikipedia',
#   u'articles',
#   u'needing',
#   u'page',
#   u'number',
#   u'citations',
#   u'January',
#   u'2012',
#   u'Articles',
#   u'containing',
#   u'potentially',
#   u'dated',
#   u'statements',
#   u'August',
#   u'2016',
#   u'All',
#   u'articles',
#   u'containing',
#   u'potentially',
#   u'dated',
#   u'statements',
#   u'Articles',
#   u'containing',
#   u'potentially',
#   u'dated',
#   u'statements',
#   u'March',
#   u'2017',
#   u'Articles',
#   u'DMOZ',
#   u'links',
#   u'Wikipedia',
#   u'articles',
#   u'LCCN',
#   u'identifiers',
#   u'Wikipedia',
#   u'articles',
#   u'GND',
#   u'identifiers',
#   u'Wikipedia',
#   u'articles',
#   u'BNF',
#   u'identifiers',
#   u'Good',
#   u'articles',
#   u'Use',
#   u'dmy',
#   u'dates',
#   u'August',
#   u'2015',
#   u'Class based',
#   u'programming',
#   u'languages',
#   u'Computational',
#   u'notebook',
#   u'Computer',
#   u'science',
#   u'Netherlands',
#   u'Cross platform',
#   u'free',
#   u'software',
#   u'Dutch',
#   u'inventions',
#   u'Dynamically',
#   u'typed',
#   u'programming',
#   u'languages',
#   u'Educational',
#   u'programming',
#   u'languages',
#   u'High level',
#   u'programming',
#   u'languages',
#   u'Information',
#   u'technology',
#   u'Netherlands',
#   u'Object oriented',
#   u'programming',
#   u'languages',
#   u'Programming',
#   u'languages',
#   u'created',
#   u'1991',
#   u'Python',
#   u'programming',
#   u'language',
#   u'Scripting',
#   u'languages',
#   u'Text oriented',
#   u'programming',
#   u'languages',
#   u'wgBreakFrames',
#   u'false',
#   u'wgPageContentLanguage',
#   u'en',
#   u'wgPageContentModel',
#   u'wikitext',
#   u'wgSeparatorTransformTable',
#   u'wgDigitTransformTable',
#   u'wgDefaultDateFormat',
#   u'dmy',
#   u'wgMonthNames',
#   u'January',
#   u'February',
#   u'March',
#   u'April',
#   u'May',
#   u'June',
#   u'July',
#   u'August',
#   u'September',
#   u'October',
#   u'November',
#   u'December',
#   u'wgMonthNamesShort',
#   u'Jan',
#   u'Feb',
#   u'Mar',
#   u'Apr',
#   u'May',
#   u'Jun',
#   u'Jul',
#   u'Aug',
#   u'Sep',
#   u'Oct',
#   u'Nov',
#   u'Dec',
#   u'wgRelevantPageName',
#   u'Python ',
#   u'programming language',
#   u'wgRelevantArticleId',
#   u' 23862',
#   u'wgRequestId',
#   u'WOuV9QpAMEsAABpSzoAAAABN',
#   u'wgIsProbablyEditable',
#   u'true',
#   u'wgRestrictionEdit',
#   u'wgRestrictionMove',
#   u'wgFlaggedRevsParams',
#   u'tags',
#   u'wgStableRevisionId',
#   u'null',
#   u'wgWikiEditorEnabledModules',
#   u'toolbar',
#   u'true',
#   u'dialogs',
#   u'true',
#   u'preview',
#   u'false',
#   u'publish',
#   u'false',
#   u'wgBetaFeaturesFeatures',
#   u'wgMediaViewerOnClick',
#   u'true',
#   u'wgMediaViewerEnabledByDefault',
#   u'true',
#   u'wgPopupsShouldSendModuleToUser',
#   u'false',
#   u'wgPopupsConflictsWithNavPopupGadget',
#   u'false',
#   u'wgVisualEditor',
#   u'pageLanguageCode',
#   u'en',
#   u'pageLanguageDir',
#   u'ltr',
#   u'usePageImages',
#   u'true',
#   u'usePageDescriptions',
#   u'true',
#   u'wgPreferredVariant',
#   u'en',
#   u'wgMFDisplayWikibaseDescriptions',
#   u'search',
#   u'true',
#   u'nearby',
#   u'true',
#   u'watchlist',
#   u'true',
#   u'tagline',
#   u'false',
#   u'wgRelatedArticles',
#   u'null',
#   u'wgRelatedArticlesBetaFeatureEnabled',
#   u'false',
#   u'wgRelatedArticlesUseCirrusSearch',
#   u'true',
#   u'wgRelatedArticlesOnlyUseCirrusSearch',
#   u'false',
#   u'wgULSCurrentAutonym',
#   u'English',
#   u'wgNoticeProject',
#   u'wikipedia',
#   u'wgCentralNoticeCookiesToDelete',
#   u'wgCentralNoticeCategoriesUsingLegacy',
#   u'Fundraising',
#   u'fundraising',
#   u'wgCategoryTreePageCategoryOptions',
#   u'mode ',
#   u' 0',
#   u'hideprefix ',
#   u' 20',
#   u'showcount ',
#   u'true',
#   u'namespaces ',
#   u'false',
#   u'wgWikibaseItemId',
#   u'Q28865',
#   u'wgCentralAuthMobileDomain',
#   u'false',
#   u'wgVisualEditorToolbarScrollOffset',
#   u' 0',
#   u'wgEditSubmitButtonLabelPublish',
#   u'false',
#   u'mw loader state',
#   u'ext globalCssJs user styles',
#   u'ready',
#   u'ext globalCssJs site styles',
#   u'ready',
#   u'site styles',
#   u'ready',
#   u'noscript',
#   u'ready',
#   u'user styles',
#   u'ready',
#   u'user',
#   u'ready',
#   u'user options',
#   u'loading',
#   u'user tokens',
#   u'loading',
#   u'ext cite styles',
#   u'ready',
#   u'wikibase client init',
#   u'ready',
#   u'ext visualEditor desktopArticleTarget noscript',
#   u'ready',
#   u'ext uls interlanguage',
#   u'ready',
#   u'ext wikimediaBadges',
#   u'ready',
#   u'mediawiki legacy shared',
#   u'ready',
#   u'mediawiki legacy commonPrint',
#   u'ready',
#   u'mediawiki sectionAnchor',
#   u'ready',
#   u'mediawiki skinning interface',
#   u'ready',
#   u'skins vector styles',
#   u'ready',
#   u'ext globalCssJs user',
#   u'ready',
#   u'ext globalCssJs site',
#   u'ready',
#   u'mw loader implement',
#   u'user options',
#   u'0j3lz3q',
#   u'function',
#   u'jQuery',
#   u'require',
#   u'module',
#   u'mw user options set',
#   u'variant',
#   u'en',
#   u'mw loader implement',
#   u'user tokens',
#   u'1dqfd7l',
#   u'function',
#   u'jQuery',
#   u'require',
#   u'module'],
#  [u'mw user tokens set',
#   u'editToken',
#   u'patrolToken',
#   u'watchToken',
#   u'csrfToken',
#   u'nomin  '],
#  [],
#  [u'mw loader load',
#   u'ext cite a11y',
#   u'mediawiki toc',
#   u'mediawiki action view postEdit',
#   u'site',
#   u'mediawiki page startup',
#   u'mediawiki user',
#   u'mediawiki hidpi',
#   u'mediawiki page ready',
#   u'mediawiki legacy wikibits',
#   u'mediawiki searchSuggest',
#   u'ext gadget teahouse',
#   u'ext gadget ReferenceTooltips',
#   u'ext gadget watchlist notice',
#   u'ext gadget DRN wizard',
#   u'ext gadget charinsert',
#   u'ext gadget refToolbar',
#   u'ext gadget extra toolbar buttons',
#   u'ext gadget switcher',
#   u'ext gadget featured articles links',
#   u'ext centralauth centralautologin',
#   u'mmv head',
#   u'mmv bootstrap autostart',
#   u'ext visualEditor desktopArticleTarget init',
#   u'ext visualEditor targetLoader',
#   u'ext eventLogging subscriber',
#   u'ext wikimediaEvents',
#   u'ext navigationTiming',
#   u'ext uls eventlogger',
#   u'ext uls init',
#   u'ext uls interface',
#   u'ext quicksurveys init',
#   u'ext centralNotice geoIP',
#   u'ext centralNotice startUp',
#   u'skins vector js',
#   u' script'],
#  [u'link',
#   u'rel ',
#   u'stylesheet',
#   u'href ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules ext cite styles',
#   u'7Cext uls interlanguage',
#   u'7Cext visualEditor desktopArticleTarget noscript',
#   u'7Cext wikimediaBadges',
#   u'7Cmediawiki legacy commonPrint',
#   u'2Cshared',
#   u'7Cmediawiki sectionAnchor',
#   u'7Cmediawiki skinning interface',
#   u'7Cskins vector styles',
#   u'7Cwikibase client init',
#   u'amp',
#   u'only styles',
#   u'amp',
#   u'skin vector'],
#  [u'script',
#   u'async ',
#   u'src ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules startup',
#   u'amp',
#   u'only scripts',
#   u'amp',
#   u'skin vector',
#   u' script'],
#  [u'meta', u'name ', u'ResourceLoaderDynamicStyles', u'content '],
#  [u'link',
#   u'rel ',
#   u'stylesheet',
#   u'href ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules site styles',
#   u'amp',
#   u'only styles',
#   u'amp',
#   u'skin vector'],
#  [u'meta',
#   u'name ',
#   u'generator',
#   u'content ',
#   u'MediaWiki',
#   u'1 29 0 wmf 19'],
#  [u'meta', u'name ', u'referrer', u'content ', u'origin when cross origin'],
#  [u'link',
#   u'rel ',
#   u'alternate',
#   u'href ',
#   u'android app',
#   u'  org wikipedia http en m wikipedia org wiki Python ',
#   u'programming language'],
#  [u'link',
#   u'rel ',
#   u'alternate',
#   u'type ',
#   u'application x wiki',
#   u'title ',
#   u'Edit',
#   u'page',
#   u'href ',
#   u' w index php',
#   u'title Python ',
#   u'programming language',
#   u'amp',
#   u'action edit'],
#  [u'link',
#   u'rel ',
#   u'edit',
#   u'title ',
#   u'Edit',
#   u'page',
#   u'href ',
#   u' w index php',
#   u'title Python ',
#   u'programming language',
#   u'amp',
#   u'action edit'],
#  [u'link',
#   u'rel ',
#   u'apple touch icon',
#   u'href ',
#   u' static apple touch wikipedia png']]

# %%
import wordcloud
