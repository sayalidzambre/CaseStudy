# %%
import findspark
# provide path to your spark directory directly
findspark.init("/home/canwill/spark2")
import pyspark
sc = pyspark.SparkContext(appName="helloworld")

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

# %%
spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
# %%bash
# wget "https://en.wikipedia.org/wiki/Python_(programming_language)" #Python Wikipedia Page
# Out:
# --2017-04-14 11:28:30--  https://en.wikipedia.org/wiki/Python_(programming_language)
# Resolving en.wikipedia.org (en.wikipedia.org)... 91.198.174.192, 2620:0:862:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|91.198.174.192|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 338014 (330K) [text/html]
# Saving to: ‘Python_(programming_language)’
#
#      0K .......... .......... .......... .......... .......... 15%  160K 2s
#     50K .......... .......... .......... .......... .......... 30%  342K 1s
#    100K .......... .......... .......... .......... .......... 45% 1.14M 1s
#    150K .......... .......... .......... .......... .......... 60% 1.21M 0s
#    200K .......... .......... .......... .......... .......... 75%  205K 0s
#    250K .......... .......... .......... .......... .......... 90%  142M 0s
#    300K .......... .......... ..........                      100%  146M=0.8s
#
# 2017-04-14 11:28:32 (419 KB/s) - ‘Python_(programming_language)’ saved [338014/338014]

# %%
# %%bash
# mv 'Python_(programming_language)' python_wiki

# %%
# %%bash
# ls
# Out:
# bank_cross_sale.ipynb
# churn_measurements.py
# ColorQuantization
# contractions.py
# contractions.pyc
# credit_risk_modeling.ipynb
# customer_churn.ipynb
# data
# medaplexis
# PageRankingwithSparseMatrix.ipynb
# python_wiki
# README.md
# sms_spam_collector.ipynb
# sms_spam_detector.pkl
# spark-nltk-practice.ipynb
# spark-warehouse

# %%
lines = sc.textFile("python_wiki")

# %%
lines.take(5)
# Out:
# [u'<!DOCTYPE html>',
#  u'<html class="client-nojs" lang="en" dir="ltr">',
#  u'<head>',
#  u'<meta charset="UTF-8"/>',
#  u'<title>Python (programming language) - Wikipedia</title>']

# %%
lines.count()
# Out:
# 1261

# %%
import nltk

# %%
from pyspark import SparkConf
from pyspark import SparkContext

conf = SparkConf()
conf.setMaster('yarn-client')
conf.setAppName('spark-nltk')
sc = SparkContext(conf=conf)

data = sc.textFile('file:///usr/share/nltk_data/corpora/state_union/1972-Nixon.txt')

def word_tokenize(x):
    import nltk
    return nltk.word_tokenize(x)

def pos_tag(x):
    import nltk
    return nltk.pos_tag([x])

words = data.flatMap(word_tokenize)
print words.take(10)

pos_word = words.map(pos_tag)
print pos_word.take(5)

# %%
import nltk
import re
import string

from nltk.corpus import wordnet as wn
from contractions import CONTRACTION_MAP
from nltk.stem import WordNetLemmatizer
from HTMLParser import HTMLParser
import unicodedata

wnl = WordNetLemmatizer()
html_parser = HTMLParser()

stopword_list = nltk.corpus.stopwords.words('english')
stopword_list = stopword_list + ['mr', 'mrs', 'come', 'go', 'get',
                                 'tell', 'listen', 'one', 'two', 'three',
                                 'four', 'five', 'six', 'seven', 'eight',
                                 'nine', 'zero', 'join', 'find', 'make',
                                 'say', 'ask', 'tell', 'see', 'try', 'back',
                                 'also', '', None, ' ']


def expand_contractions(text, contraction_mapping):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text
    

def word_tokenize(text):
    tokens = nltk.word_tokenize(text) 
    tokens = [token.strip() for token in tokens]
    return tokens

def remove_special_characters(text):
    tokens = text
    pattern = re.compile('[{}]'.format(re.escape(string.punctuation)))
    filtered_tokens = filter(None, [pattern.sub(' ', token) for token in tokens])
    return filtered_tokens
    
    
def remove_stopwords(text):
    tokens = text
    filtered_tokens = [token for token in tokens if token.strip() not in stopword_list]
    return filtered_tokens


# Annotate text tokens with POS tags
def pos_tag_text(words):
    
    def penn_to_wn_tags(pos_tag):
        if pos_tag.startswith('J'):
            return wn.ADJ
        elif pos_tag.startswith('V'):
            return wn.VERB
        elif pos_tag.startswith('N'):
            return wn.NOUN
        elif pos_tag.startswith('R'):
            return wn.ADV
        else:
            return None
        
        
    def pos_tagging(words):
        print 'pos_tagging'
        return nltk.pos_tag(words)
    
    tagged_words = pos_tagging(words)
    print 'pos_tagging'
    tagged_lower_text = [(word.lower(), penn_to_wn_tags(pos_tag))
                         for word, pos_tag in
                         tagged_words]
    return tagged_lower_text
    


def lemmatize_text(words):
    print 'lemma'
    pos_tagged_words = pos_tag_text(words)
    print 'pos done'
    lemmatized_tokens = [wnl.lemmatize(word, pos_tag) if pos_tag
                         else word                     
                         for word, pos_tag in pos_tagged_words]
    return lemmatized_tokens

def parse_hippa(text):
    hippa_pattern = '[[^a-zA-Z0-9]*/*[[^a-zA-Z0-9., -_]*/*[^a-zA-Z0-9., -_]*]*~]*'    
    if re.match(hippa_pattern, text)    :
        text = re.sub('\*','\* ', text)
        text = re.sub('~',' ~ ', text)
        return True, text
 
    return False, text

# %%
import pandas as pd
data = pd.read_csv('data/retuters_test_data.csv', sep='\t')
data = spark.createDataFrame(data)
data.take(2)
# Out:
# [Row(Unnamed: 0=0, text=u'SANDOZ PLANS WEEDKILLER JOINT VENTURE IN USSR\n\nSandoz AG said it planned a joint venture to produce herbicides in the Soviet Union. The company said it had signed a letter of intent with the Soviet Ministry of Fertiliser Production to form the first foreign joint venture the ministry had undertaken since the Soviet Union allowed Western firms to enter into joint ventures two months ago. The ministry and Sandoz will each have a 50 pct stake, but a company spokeswoman was unable to give details of the size of investment or planned output. Reuter \x03', tags=u'usa,ussr'),
#  Row(Unnamed: 0=1, text=u'TAIWAN REJECTS TEXTILE MAKERS EXCHANGE RATE PLEA\n\nCentral bank governor Chang Chi-cheng rejected a request by textile makers to halt the rise of the Taiwan dollar against the U.S. Dollar to stop them losing orders to South Korea, Hong Kong and Singapore, a spokesman for the Taiwan Textile Federation said. He quoted Chang as telling representatives of 19 textile associations last Saturday the government could not fix the Taiwan dollar exchange rate at 35 to one U.S. Dollar due to U.S. Pressure for an appreciation of the local currency. The Federation asked the government on February 19 to hold the exchange rate at that level. The federation said in its request that many local textile exporters were operating without profit and would go out of business if the rate continued to fall. Reuter \x03', tags=u'usa,taiwan')]

# %%
data.printSchema()
# Out:
# root
#  |-- Unnamed: 0: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- tags: string (nullable = true)

# %%
def normalize_data(line):
    line = html_parser.unescape(line)
    line = expand_contractions(line, CONTRACTION_MAP)
    ishippa, line = parse_hippa(line)
    words = word_tokenize(line)
    if not ishippa:
        words = remove_special_characters(words)
    words = remove_stopwords(words)
    words = lemmatize_text(words)
    return words

udf_normalize_data = udf(normalize_data, StringType())
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-31-18d77bfb3b47> in <module>()
#      11     return words
#      12
# ---> 13 udf_normalize_data=udf(normalize_data, StringType())
#
# /home/canwill/spark2/python/pyspark/sql/functions.pyc in udf(f, returnType)
#    1866     [Row(slen=5), Row(slen=3)]
#    1867     """
# -> 1868     return UserDefinedFunction(f, returnType)
#    1869
#    1870 blacklist = ['map', 'since', 'ignore_unicode_prefix']
#
# /home/canwill/spark2/python/pyspark/sql/functions.pyc in __init__(self, func, returnType, name)
#    1824         self.returnType = returnType
#    1825         self._broadcast = None
# -> 1826         self._judf = self._create_judf(name)
#    1827
#    1828     def _create_judf(self, name):
#
# /home/canwill/spark2/python/pyspark/sql/functions.pyc in _create_judf(self, name)
#    1829         from pyspark.sql import SparkSession
#    1830         sc = SparkContext.getOrCreate()
# -> 1831         wrapped_func = _wrap_function(sc, self.func, self.returnType)
#    1832         spark = SparkSession.builder.getOrCreate()
#    1833         jdt = spark._jsparkSession.parseDataType(self.returnType.json())
#
# /home/canwill/spark2/python/pyspark/sql/functions.pyc in _wrap_function(sc, func, returnType)
#    1809 def _wrap_function(sc, func, returnType):
#    1810     command = (func, returnType)
# -> 1811     pickled_command, broadcast_vars, env, includes = _prepare_for_python_RDD(sc, command)
#    1812     return sc._jvm.PythonFunction(bytearray(pickled_command), env, includes, sc.pythonExec,
#    1813                                   sc.pythonVer, broadcast_vars, sc._javaAccumulator)
#
# /home/canwill/spark2/python/pyspark/rdd.pyc in _prepare_for_python_RDD(sc, command)
#    2356     # the serialized command will be compressed by broadcast
#    2357     ser = CloudPickleSerializer()
# -> 2358     pickled_command = ser.dumps(command)
#    2359     if len(pickled_command) > (1 << 20):  # 1M
#    2360         # The broadcast will have same life cycle as created PythonRDD
#
# /home/canwill/spark2/python/pyspark/serializers.pyc in dumps(self, obj)
#     438
#     439     def dumps(self, obj):
# --> 440         return cloudpickle.dumps(obj, 2)
#     441
#     442
#
# /home/canwill/spark2/python/pyspark/cloudpickle.pyc in dumps(obj, protocol)
#     665
#     666     cp = CloudPickler(file,protocol)
# --> 667     cp.dump(obj)
#     668
#     669     return file.getvalue()
#
# /home/canwill/spark2/python/pyspark/cloudpickle.pyc in dump(self, obj)
#     105         self.inject_addons()
#     106         try:
# --> 107             return Pickler.dump(self, obj)
#     108         except RuntimeError as e:
#     109             if 'recursion' in e.args[0]:
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in dump(self, obj)
#     222         if self.proto >= 2:
#     223             self.write(PROTO + chr(self.proto))
# --> 224         self.save(obj)
#     225         self.write(STOP)
#     226
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save_tuple(self, obj)
#     552         if n <= 3 and proto >= 2:
#     553             for element in obj:
# --> 554                 save(element)
#     555             # Subtle.  Same as in the big comment below.
#     556             if id(obj) in memo:
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/canwill/spark2/python/pyspark/cloudpickle.pyc in save_function(self, obj, name)
#     206         if islambda(obj) or obj.__code__.co_filename == '<stdin>' or themodule is None:
#     207             #print("save global", islambda(obj), obj.__code__.co_filename, modname, themodule)
# --> 208             self.save_function_tuple(obj)
#     209             return
#     210         else:
#
# /home/canwill/spark2/python/pyspark/cloudpickle.pyc in save_function_tuple(self, func)
#     254
#     255         # save the rest of the func data needed by _fill_function
# --> 256         save(f_globals)
#     257         save(defaults)
#     258         save(dct)
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save_dict(self, obj)
#     653
#     654         self.memoize(obj)
# --> 655         self._batch_setitems(obj.iteritems())
#     656
#     657     dispatch[DictionaryType] = save_dict
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in _batch_setitems(self, items)
#     685                 for k, v in tmp:
#     686                     save(k)
# --> 687                     save(v)
#     688                 write(SETITEMS)
#     689             elif n:
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/canwill/spark2/python/pyspark/cloudpickle.pyc in save_function(self, obj, name)
#     206         if islambda(obj) or obj.__code__.co_filename == '<stdin>' or themodule is None:
#     207             #print("save global", islambda(obj), obj.__code__.co_filename, modname, themodule)
# --> 208             self.save_function_tuple(obj)
#     209             return
#     210         else:
#
# /home/canwill/spark2/python/pyspark/cloudpickle.pyc in save_function_tuple(self, func)
#     254
#     255         # save the rest of the func data needed by _fill_function
# --> 256         save(f_globals)
#     257         save(defaults)
#     258         save(dct)
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save_dict(self, obj)
#     653
#     654         self.memoize(obj)
# --> 655         self._batch_setitems(obj.iteritems())
#     656
#     657     dispatch[DictionaryType] = save_dict
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in _batch_setitems(self, items)
#     685                 for k, v in tmp:
#     686                     save(k)
# --> 687                     save(v)
#     688                 write(SETITEMS)
#     689             elif n:
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/canwill/spark2/python/pyspark/cloudpickle.pyc in save_function(self, obj, name)
#     206         if islambda(obj) or obj.__code__.co_filename == '<stdin>' or themodule is None:
#     207             #print("save global", islambda(obj), obj.__code__.co_filename, modname, themodule)
# --> 208             self.save_function_tuple(obj)
#     209             return
#     210         else:
#
# /home/canwill/spark2/python/pyspark/cloudpickle.pyc in save_function_tuple(self, func)
#     254
#     255         # save the rest of the func data needed by _fill_function
# --> 256         save(f_globals)
#     257         save(defaults)
#     258         save(dct)
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save_dict(self, obj)
#     653
#     654         self.memoize(obj)
# --> 655         self._batch_setitems(obj.iteritems())
#     656
#     657     dispatch[DictionaryType] = save_dict
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in _batch_setitems(self, items)
#     685                 for k, v in tmp:
#     686                     save(k)
# --> 687                     save(v)
#     688                 write(SETITEMS)
#     689             elif n:
#
# /home/canwill/anaconda2/lib/python2.7/pickle.pyc in save(self, obj)
#     329
#     330         # Save the reduce() output and finally memoize the object
# --> 331         self.save_reduce(obj=obj, *rv)
#     332
#     333     def persistent_id(self, obj):
#
# /home/canwill/spark2/python/pyspark/cloudpickle.pyc in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     526             if obj is not None and cls is not obj.__class__:
#     527                 raise pickle.PicklingError(
# --> 528                     "args[0] from __newobj__ args has the wrong class")
#     529             args = args[1:]
#     530             save(cls)
#
# PicklingError: args[0] from __newobj__ args has the wrong class

# %%
df.withColumn("new_text", udf_normalize_data("text")).show(10)

# %%
words = lines.map(word_tokenize)
words = words.map(remove_special_characters)
words = words.map(remove_stopwords)
words = words.map(lemmatize_text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-9a478b071d78> in <module>()
# ----> 1 words = lines.map(word_tokenize)
#       2 words = words.map(remove_special_characters)
#       3 words = words.map(remove_stopwords)
#       4 words = words.map(lemmatize_text)
#
# TypeError: 'Column' object is not callable

# %%
words.take(20)
# Out:
# [[u'doctype', u'html'],
#  [u'html', u'class ', u'client nojs', u'lang ', u'en', u'dir ', u'ltr'],
#  [u'head'],
#  [u'meta', u'charset ', u'utf 8'],
#  [u'title', u'python', u'programming', u'language', u'wikipedia', u' title'],
#  [u'script',
#   u'document documentelement classname',
#   u'document documentelement classname replace',
#   u'client nojs',
#   u'1client js',
#   u'2',
#   u' script'],
#  [u'script',
#   u'window rlq window rlq  ',
#   u' push',
#   u'function',
#   u'mw config set',
#   u'wgcanonicalnamespace',
#   u'wgcanonicalspecialpagename',
#   u'false',
#   u'wgnamespacenumber',
#   u' 0',
#   u'wgpagename',
#   u'python ',
#   u'programming language',
#   u'wgtitle',
#   u'python',
#   u'programming',
#   u'language',
#   u'wgcurrevisionid',
#   u' 774758975',
#   u'wgrevisionid',
#   u' 774758975',
#   u'wgarticleid',
#   u' 23862',
#   u'wgisarticle',
#   u'true',
#   u'wgisredirect',
#   u'false',
#   u'wgaction',
#   u'view',
#   u'wgusername',
#   u'null',
#   u'wgusergroups',
#   u'wgcategories',
#   u'wikipedia',
#   u'article',
#   u'need',
#   u'page',
#   u'number',
#   u'citation',
#   u'january',
#   u'2012',
#   u'article',
#   u'contain',
#   u'potentially',
#   u'dated',
#   u'statement',
#   u'august',
#   u'2016',
#   u'all',
#   u'article',
#   u'contain',
#   u'potentially',
#   u'dated',
#   u'statement',
#   u'article',
#   u'contain',
#   u'potentially',
#   u'dated',
#   u'statement',
#   u'march',
#   u'2017',
#   u'article',
#   u'dmoz',
#   u'link',
#   u'wikipedia',
#   u'article',
#   u'lccn',
#   u'identifier',
#   u'wikipedia',
#   u'article',
#   u'gnd',
#   u'identifier',
#   u'wikipedia',
#   u'article',
#   u'bnf',
#   u'identifier',
#   u'good',
#   u'article',
#   u'use',
#   u'dmy',
#   u'date',
#   u'august',
#   u'2015',
#   u'class based',
#   u'program',
#   u'language',
#   u'computational',
#   u'notebook',
#   u'computer',
#   u'science',
#   u'netherlands',
#   u'cross platform',
#   u'free',
#   u'software',
#   u'dutch',
#   u'invention',
#   u'dynamically',
#   u'type',
#   u'program',
#   u'language',
#   u'educational',
#   u'programming',
#   u'language',
#   u'high level',
#   u'program',
#   u'language',
#   u'information',
#   u'technology',
#   u'netherlands',
#   u'object oriented',
#   u'programming',
#   u'language',
#   u'program',
#   u'language',
#   u'create',
#   u'1991',
#   u'python',
#   u'program',
#   u'language',
#   u'script',
#   u'language',
#   u'text oriented',
#   u'program',
#   u'language',
#   u'wgbreakframes',
#   u'false',
#   u'wgpagecontentlanguage',
#   u'en',
#   u'wgpagecontentmodel',
#   u'wikitext',
#   u'wgseparatortransformtable',
#   u'wgdigittransformtable',
#   u'wgdefaultdateformat',
#   u'dmy',
#   u'wgmonthnames',
#   u'january',
#   u'february',
#   u'march',
#   u'april',
#   u'may',
#   u'june',
#   u'july',
#   u'august',
#   u'september',
#   u'october',
#   u'november',
#   u'december',
#   u'wgmonthnamesshort',
#   u'jan',
#   u'feb',
#   u'mar',
#   u'apr',
#   u'may',
#   u'jun',
#   u'jul',
#   u'aug',
#   u'sep',
#   u'oct',
#   u'nov',
#   u'dec',
#   u'wgrelevantpagename',
#   u'python ',
#   u'programming language',
#   u'wgrelevantarticleid',
#   u' 23862',
#   u'wgrequestid',
#   u'wouv9qpamesaabpszoaaaabn',
#   u'wgisprobablyeditable',
#   u'true',
#   u'wgrestrictionedit',
#   u'wgrestrictionmove',
#   u'wgflaggedrevsparams',
#   u'tag',
#   u'wgstablerevisionid',
#   u'null',
#   u'wgwikieditorenabledmodules',
#   u'toolbar',
#   u'true',
#   u'dialog',
#   u'true',
#   u'preview',
#   u'false',
#   u'publish',
#   u'false',
#   u'wgbetafeaturesfeatures',
#   u'wgmediavieweronclick',
#   u'true',
#   u'wgmediaviewerenabledbydefault',
#   u'true',
#   u'wgpopupsshouldsendmoduletouser',
#   u'false',
#   u'wgpopupsconflictswithnavpopupgadget',
#   u'false',
#   u'wgvisualeditor',
#   u'pagelanguagecode',
#   u'en',
#   u'pagelanguagedir',
#   u'ltr',
#   u'usepageimages',
#   u'true',
#   u'usepagedescriptions',
#   u'true',
#   u'wgpreferredvariant',
#   u'en',
#   u'wgmfdisplaywikibasedescriptions',
#   u'search',
#   u'true',
#   u'nearby',
#   u'true',
#   u'watchlist',
#   u'true',
#   u'tagline',
#   u'false',
#   u'wgrelatedarticles',
#   u'null',
#   u'wgrelatedarticlesbetafeatureenabled',
#   u'false',
#   u'wgrelatedarticlesusecirrussearch',
#   u'true',
#   u'wgrelatedarticlesonlyusecirrussearch',
#   u'false',
#   u'wgulscurrentautonym',
#   u'english',
#   u'wgnoticeproject',
#   u'wikipedia',
#   u'wgcentralnoticecookiestodelete',
#   u'wgcentralnoticecategoriesusinglegacy',
#   u'fundraise',
#   u'fundraise',
#   u'wgcategorytreepagecategoryoptions',
#   u'mode ',
#   u' 0',
#   u'hideprefix ',
#   u' 20',
#   u'showcount ',
#   u'true',
#   u'namespaces ',
#   u'false',
#   u'wgwikibaseitemid',
#   u'q28865',
#   u'wgcentralauthmobiledomain',
#   u'false',
#   u'wgvisualeditortoolbarscrolloffset',
#   u' 0',
#   u'wgeditsubmitbuttonlabelpublish',
#   u'false',
#   u'mw loader state',
#   u'ext globalcssjs user styles',
#   u'ready',
#   u'ext globalcssjs site styles',
#   u'ready',
#   u'site styles',
#   u'ready',
#   u'noscript',
#   u'ready',
#   u'user styles',
#   u'ready',
#   u'user',
#   u'ready',
#   u'user options',
#   u'load',
#   u'user tokens',
#   u'loading',
#   u'ext cite styles',
#   u'ready',
#   u'wikibase client init',
#   u'ready',
#   u'ext visualeditor desktoparticletarget noscript',
#   u'ready',
#   u'ext uls interlanguage',
#   u'ready',
#   u'ext wikimediabadges',
#   u'ready',
#   u'mediawiki legacy shared',
#   u'ready',
#   u'mediawiki legacy commonprint',
#   u'ready',
#   u'mediawiki sectionanchor',
#   u'ready',
#   u'mediawiki skinning interface',
#   u'ready',
#   u'skins vector styles',
#   u'ready',
#   u'ext globalcssjs user',
#   u'ready',
#   u'ext globalcssjs site',
#   u'ready',
#   u'mw loader implement',
#   u'user options',
#   u'0j3lz3q',
#   u'function',
#   u'jquery',
#   u'require',
#   u'module',
#   u'mw user options set',
#   u'variant',
#   u'en',
#   u'mw loader implement',
#   u'user tokens',
#   u'1dqfd7l',
#   u'function',
#   u'jquery',
#   u'require',
#   u'module'],
#  [u'mw user tokens set',
#   u'edittoken',
#   u'patroltoken',
#   u'watchtoken',
#   u'csrftoken',
#   u'nomin  '],
#  [],
#  [u'mw loader load',
#   u'ext cite a11y',
#   u'mediawiki toc',
#   u'mediawiki action view postedit',
#   u'site',
#   u'mediawiki page startup',
#   u'mediawiki user',
#   u'mediawiki hidpi',
#   u'mediawiki page ready',
#   u'mediawiki legacy wikibits',
#   u'mediawiki searchsuggest',
#   u'ext gadget teahouse',
#   u'ext gadget referencetooltips',
#   u'ext gadget watchlist notice',
#   u'ext gadget drn wizard',
#   u'ext gadget charinsert',
#   u'ext gadget reftoolbar',
#   u'ext gadget extra toolbar buttons',
#   u'ext gadget switcher',
#   u'ext gadget featured articles links',
#   u'ext centralauth centralautologin',
#   u'mmv head',
#   u'mmv bootstrap autostart',
#   u'ext visualeditor desktoparticletarget init',
#   u'ext visualeditor targetloader',
#   u'ext eventlogging subscriber',
#   u'ext wikimediaevents',
#   u'ext navigationtiming',
#   u'ext uls eventlogger',
#   u'ext uls init',
#   u'ext uls interface',
#   u'ext quicksurveys init',
#   u'ext centralnotice geoip',
#   u'ext centralnotice startup',
#   u'skins vector js',
#   u' script'],
#  [u'link',
#   u'rel ',
#   u'stylesheet',
#   u'href ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules ext cite styles',
#   u'7cext uls interlanguage',
#   u'7cext visualeditor desktoparticletarget noscript',
#   u'7cext wikimediabadges',
#   u'7cmediawiki legacy commonprint',
#   u'2cshared',
#   u'7cmediawiki sectionanchor',
#   u'7cmediawiki skinning interface',
#   u'7cskins vector styles',
#   u'7cwikibase client init',
#   u'amp',
#   u'only styles',
#   u'amp',
#   u'skin vector'],
#  [u'script',
#   u'async ',
#   u'src ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules startup',
#   u'amp',
#   u'only scripts',
#   u'amp',
#   u'skin vector',
#   u' script'],
#  [u'meta', u'name ', u'resourceloaderdynamicstyles', u'content '],
#  [u'link',
#   u'rel ',
#   u'stylesheet',
#   u'href ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules site styles',
#   u'amp',
#   u'only styles',
#   u'amp',
#   u'skin vector'],
#  [u'meta',
#   u'name ',
#   u'generator',
#   u'content ',
#   u'mediawiki',
#   u'1 29 0 wmf 19'],
#  [u'meta', u'name ', u'referrer', u'content ', u'origin when cross origin'],
#  [u'link',
#   u'rel ',
#   u'alternate',
#   u'href ',
#   u'android app',
#   u'  org wikipedia http en m wikipedia org wiki python ',
#   u'programming language'],
#  [u'link',
#   u'rel ',
#   u'alternate',
#   u'type ',
#   u'application x wiki',
#   u'title ',
#   u'edit',
#   u'page',
#   u'href ',
#   u' w index php',
#   u'title python ',
#   u'programming language',
#   u'amp',
#   u'action edit'],
#  [u'link',
#   u'rel ',
#   u'edit',
#   u'title ',
#   u'edit',
#   u'page',
#   u'href ',
#   u' w index php',
#   u'title python ',
#   u'programming language',
#   u'amp',
#   u'action edit'],
#  [u'link',
#   u'rel ',
#   u'apple touch icon',
#   u'href ',
#   u' static apple touch wikipedia png']]

# %% [raw]
# Difference between map and flat map -
# map will append list in list
# flatmap will extend list in list

# %%
words = lines.flatMap(word_tokenize)

# %%
words.take(20)
# Out:
# [[u'DOCTYPE', u'html'],
#  [u'html', u'class ', u'client nojs', u'lang ', u'en', u'dir ', u'ltr'],
#  [u'head'],
#  [u'meta', u'charset ', u'UTF 8'],
#  [u'title', u'Python', u'programming', u'language', u'Wikipedia', u' title'],
#  [u'script',
#   u'document documentElement className',
#   u'document documentElement className replace',
#   u'client nojs',
#   u'1client js',
#   u'2',
#   u' script'],
#  [u'script',
#   u'window RLQ window RLQ  ',
#   u' push',
#   u'function',
#   u'mw config set',
#   u'wgCanonicalNamespace',
#   u'wgCanonicalSpecialPageName',
#   u'false',
#   u'wgNamespaceNumber',
#   u' 0',
#   u'wgPageName',
#   u'Python ',
#   u'programming language',
#   u'wgTitle',
#   u'Python',
#   u'programming',
#   u'language',
#   u'wgCurRevisionId',
#   u' 774758975',
#   u'wgRevisionId',
#   u' 774758975',
#   u'wgArticleId',
#   u' 23862',
#   u'wgIsArticle',
#   u'true',
#   u'wgIsRedirect',
#   u'false',
#   u'wgAction',
#   u'view',
#   u'wgUserName',
#   u'null',
#   u'wgUserGroups',
#   u'wgCategories',
#   u'Wikipedia',
#   u'articles',
#   u'needing',
#   u'page',
#   u'number',
#   u'citations',
#   u'January',
#   u'2012',
#   u'Articles',
#   u'containing',
#   u'potentially',
#   u'dated',
#   u'statements',
#   u'August',
#   u'2016',
#   u'All',
#   u'articles',
#   u'containing',
#   u'potentially',
#   u'dated',
#   u'statements',
#   u'Articles',
#   u'containing',
#   u'potentially',
#   u'dated',
#   u'statements',
#   u'March',
#   u'2017',
#   u'Articles',
#   u'DMOZ',
#   u'links',
#   u'Wikipedia',
#   u'articles',
#   u'LCCN',
#   u'identifiers',
#   u'Wikipedia',
#   u'articles',
#   u'GND',
#   u'identifiers',
#   u'Wikipedia',
#   u'articles',
#   u'BNF',
#   u'identifiers',
#   u'Good',
#   u'articles',
#   u'Use',
#   u'dmy',
#   u'dates',
#   u'August',
#   u'2015',
#   u'Class based',
#   u'programming',
#   u'languages',
#   u'Computational',
#   u'notebook',
#   u'Computer',
#   u'science',
#   u'Netherlands',
#   u'Cross platform',
#   u'free',
#   u'software',
#   u'Dutch',
#   u'inventions',
#   u'Dynamically',
#   u'typed',
#   u'programming',
#   u'languages',
#   u'Educational',
#   u'programming',
#   u'languages',
#   u'High level',
#   u'programming',
#   u'languages',
#   u'Information',
#   u'technology',
#   u'Netherlands',
#   u'Object oriented',
#   u'programming',
#   u'languages',
#   u'Programming',
#   u'languages',
#   u'created',
#   u'1991',
#   u'Python',
#   u'programming',
#   u'language',
#   u'Scripting',
#   u'languages',
#   u'Text oriented',
#   u'programming',
#   u'languages',
#   u'wgBreakFrames',
#   u'false',
#   u'wgPageContentLanguage',
#   u'en',
#   u'wgPageContentModel',
#   u'wikitext',
#   u'wgSeparatorTransformTable',
#   u'wgDigitTransformTable',
#   u'wgDefaultDateFormat',
#   u'dmy',
#   u'wgMonthNames',
#   u'January',
#   u'February',
#   u'March',
#   u'April',
#   u'May',
#   u'June',
#   u'July',
#   u'August',
#   u'September',
#   u'October',
#   u'November',
#   u'December',
#   u'wgMonthNamesShort',
#   u'Jan',
#   u'Feb',
#   u'Mar',
#   u'Apr',
#   u'May',
#   u'Jun',
#   u'Jul',
#   u'Aug',
#   u'Sep',
#   u'Oct',
#   u'Nov',
#   u'Dec',
#   u'wgRelevantPageName',
#   u'Python ',
#   u'programming language',
#   u'wgRelevantArticleId',
#   u' 23862',
#   u'wgRequestId',
#   u'WOuV9QpAMEsAABpSzoAAAABN',
#   u'wgIsProbablyEditable',
#   u'true',
#   u'wgRestrictionEdit',
#   u'wgRestrictionMove',
#   u'wgFlaggedRevsParams',
#   u'tags',
#   u'wgStableRevisionId',
#   u'null',
#   u'wgWikiEditorEnabledModules',
#   u'toolbar',
#   u'true',
#   u'dialogs',
#   u'true',
#   u'preview',
#   u'false',
#   u'publish',
#   u'false',
#   u'wgBetaFeaturesFeatures',
#   u'wgMediaViewerOnClick',
#   u'true',
#   u'wgMediaViewerEnabledByDefault',
#   u'true',
#   u'wgPopupsShouldSendModuleToUser',
#   u'false',
#   u'wgPopupsConflictsWithNavPopupGadget',
#   u'false',
#   u'wgVisualEditor',
#   u'pageLanguageCode',
#   u'en',
#   u'pageLanguageDir',
#   u'ltr',
#   u'usePageImages',
#   u'true',
#   u'usePageDescriptions',
#   u'true',
#   u'wgPreferredVariant',
#   u'en',
#   u'wgMFDisplayWikibaseDescriptions',
#   u'search',
#   u'true',
#   u'nearby',
#   u'true',
#   u'watchlist',
#   u'true',
#   u'tagline',
#   u'false',
#   u'wgRelatedArticles',
#   u'null',
#   u'wgRelatedArticlesBetaFeatureEnabled',
#   u'false',
#   u'wgRelatedArticlesUseCirrusSearch',
#   u'true',
#   u'wgRelatedArticlesOnlyUseCirrusSearch',
#   u'false',
#   u'wgULSCurrentAutonym',
#   u'English',
#   u'wgNoticeProject',
#   u'wikipedia',
#   u'wgCentralNoticeCookiesToDelete',
#   u'wgCentralNoticeCategoriesUsingLegacy',
#   u'Fundraising',
#   u'fundraising',
#   u'wgCategoryTreePageCategoryOptions',
#   u'mode ',
#   u' 0',
#   u'hideprefix ',
#   u' 20',
#   u'showcount ',
#   u'true',
#   u'namespaces ',
#   u'false',
#   u'wgWikibaseItemId',
#   u'Q28865',
#   u'wgCentralAuthMobileDomain',
#   u'false',
#   u'wgVisualEditorToolbarScrollOffset',
#   u' 0',
#   u'wgEditSubmitButtonLabelPublish',
#   u'false',
#   u'mw loader state',
#   u'ext globalCssJs user styles',
#   u'ready',
#   u'ext globalCssJs site styles',
#   u'ready',
#   u'site styles',
#   u'ready',
#   u'noscript',
#   u'ready',
#   u'user styles',
#   u'ready',
#   u'user',
#   u'ready',
#   u'user options',
#   u'loading',
#   u'user tokens',
#   u'loading',
#   u'ext cite styles',
#   u'ready',
#   u'wikibase client init',
#   u'ready',
#   u'ext visualEditor desktopArticleTarget noscript',
#   u'ready',
#   u'ext uls interlanguage',
#   u'ready',
#   u'ext wikimediaBadges',
#   u'ready',
#   u'mediawiki legacy shared',
#   u'ready',
#   u'mediawiki legacy commonPrint',
#   u'ready',
#   u'mediawiki sectionAnchor',
#   u'ready',
#   u'mediawiki skinning interface',
#   u'ready',
#   u'skins vector styles',
#   u'ready',
#   u'ext globalCssJs user',
#   u'ready',
#   u'ext globalCssJs site',
#   u'ready',
#   u'mw loader implement',
#   u'user options',
#   u'0j3lz3q',
#   u'function',
#   u'jQuery',
#   u'require',
#   u'module',
#   u'mw user options set',
#   u'variant',
#   u'en',
#   u'mw loader implement',
#   u'user tokens',
#   u'1dqfd7l',
#   u'function',
#   u'jQuery',
#   u'require',
#   u'module'],
#  [u'mw user tokens set',
#   u'editToken',
#   u'patrolToken',
#   u'watchToken',
#   u'csrfToken',
#   u'nomin  '],
#  [],
#  [u'mw loader load',
#   u'ext cite a11y',
#   u'mediawiki toc',
#   u'mediawiki action view postEdit',
#   u'site',
#   u'mediawiki page startup',
#   u'mediawiki user',
#   u'mediawiki hidpi',
#   u'mediawiki page ready',
#   u'mediawiki legacy wikibits',
#   u'mediawiki searchSuggest',
#   u'ext gadget teahouse',
#   u'ext gadget ReferenceTooltips',
#   u'ext gadget watchlist notice',
#   u'ext gadget DRN wizard',
#   u'ext gadget charinsert',
#   u'ext gadget refToolbar',
#   u'ext gadget extra toolbar buttons',
#   u'ext gadget switcher',
#   u'ext gadget featured articles links',
#   u'ext centralauth centralautologin',
#   u'mmv head',
#   u'mmv bootstrap autostart',
#   u'ext visualEditor desktopArticleTarget init',
#   u'ext visualEditor targetLoader',
#   u'ext eventLogging subscriber',
#   u'ext wikimediaEvents',
#   u'ext navigationTiming',
#   u'ext uls eventlogger',
#   u'ext uls init',
#   u'ext uls interface',
#   u'ext quicksurveys init',
#   u'ext centralNotice geoIP',
#   u'ext centralNotice startUp',
#   u'skins vector js',
#   u' script'],
#  [u'link',
#   u'rel ',
#   u'stylesheet',
#   u'href ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules ext cite styles',
#   u'7Cext uls interlanguage',
#   u'7Cext visualEditor desktopArticleTarget noscript',
#   u'7Cext wikimediaBadges',
#   u'7Cmediawiki legacy commonPrint',
#   u'2Cshared',
#   u'7Cmediawiki sectionAnchor',
#   u'7Cmediawiki skinning interface',
#   u'7Cskins vector styles',
#   u'7Cwikibase client init',
#   u'amp',
#   u'only styles',
#   u'amp',
#   u'skin vector'],
#  [u'script',
#   u'async ',
#   u'src ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules startup',
#   u'amp',
#   u'only scripts',
#   u'amp',
#   u'skin vector',
#   u' script'],
#  [u'meta', u'name ', u'ResourceLoaderDynamicStyles', u'content '],
#  [u'link',
#   u'rel ',
#   u'stylesheet',
#   u'href ',
#   u' w load php',
#   u'debug false',
#   u'amp',
#   u'lang en',
#   u'amp',
#   u'modules site styles',
#   u'amp',
#   u'only styles',
#   u'amp',
#   u'skin vector'],
#  [u'meta',
#   u'name ',
#   u'generator',
#   u'content ',
#   u'MediaWiki',
#   u'1 29 0 wmf 19'],
#  [u'meta', u'name ', u'referrer', u'content ', u'origin when cross origin'],
#  [u'link',
#   u'rel ',
#   u'alternate',
#   u'href ',
#   u'android app',
#   u'  org wikipedia http en m wikipedia org wiki Python ',
#   u'programming language'],
#  [u'link',
#   u'rel ',
#   u'alternate',
#   u'type ',
#   u'application x wiki',
#   u'title ',
#   u'Edit',
#   u'page',
#   u'href ',
#   u' w index php',
#   u'title Python ',
#   u'programming language',
#   u'amp',
#   u'action edit'],
#  [u'link',
#   u'rel ',
#   u'edit',
#   u'title ',
#   u'Edit',
#   u'page',
#   u'href ',
#   u' w index php',
#   u'title Python ',
#   u'programming language',
#   u'amp',
#   u'action edit'],
#  [u'link',
#   u'rel ',
#   u'apple touch icon',
#   u'href ',
#   u' static apple touch wikipedia png']]

# %%
import wordcloud
