# %% [markdown]
# ### Cosine Similarity for different documents

# %%
import pandas as pd
import numpy as np
import gensim.utils as utils
import re

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec

from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ##### Read data

# %%
columns = ['index','text', 'tag']
def add_row(text, classes, df):
    df.loc[len(df)] = [len(df), utils.to_utf8(text, errors='replace').decode("utf8"), classes]

# %%
import textract
from os import listdir
from os.path import isfile, join


data = pd.DataFrame( columns=columns)
data

dirpath = 'data/train/shortstory/'
shortstory = [add_row(textract.process(dirpath + f),'shortstory', data) for f in listdir(dirpath) if isfile(join(dirpath, f))]

dirpath = 'data/train/java/'
java = [add_row(textract.process(dirpath + f), 'technical', data) for f in listdir(dirpath) if isfile(join(dirpath, f))]

dirpath = 'data/train/python/'
python = [add_row(textract.process(dirpath + f),'technical', data) for f in listdir(dirpath) if isfile(join(dirpath, f))]

dirpath = 'data/train/medicine/'
medicine = [add_row(textract.process(dirpath + f),'medicine', data) for f in listdir(dirpath) if isfile(join(dirpath, f))]

dirpath = 'data/train/mobilescreen/'
mobilescreen = [add_row(textract.process(dirpath + f),'mobile', data) for f in listdir(dirpath) if isfile(join(dirpath, f))]

dirpath = 'data/train/mobilememorycard/'
mobilememorycard = [add_row(textract.process(dirpath + f),'mobile', data) for f in listdir(dirpath) if isfile(join(dirpath, f))]

dirpath = 'data/train/lcd/'
mobilememorycard = [add_row(textract.process(dirpath + f),'lcd', data) for f in listdir(dirpath) if isfile(join(dirpath, f))]

dirpath = 'data/train/hippa/'
mobilememorycard = [add_row(textract.process(dirpath + f),'hippa', data) for f in listdir(dirpath) if isfile(join(dirpath, f))]

dirpath = 'data/train/srs/'
mobilememorycard = [add_row(textract.process(dirpath + f),'srs', data) for f in listdir(dirpath) if isfile(join(dirpath, f))]

# %%
columns = ['index','text', 'tag']
test = pd.DataFrame( columns=columns)
dirpath = 'data/test/medicine/'
[add_row(textract.process(dirpath + f),'medicine', test) for f in listdir(dirpath) if isfile(join(dirpath, f))]
dirpath = 'data/test/mobilescreen/'
[add_row(textract.process(dirpath + f),'mobile', test) for f in listdir(dirpath) if isfile(join(dirpath, f))]
dirpath = 'data/test/mobilememorycard/'
[add_row(textract.process(dirpath + f),'mobile', test) for f in listdir(dirpath) if isfile(join(dirpath, f))]
dirpath = 'data/test/lcd/'
[add_row(textract.process(dirpath + f),'lcd', test) for f in listdir(dirpath) if isfile(join(dirpath, f))]
dirpath = 'data/test/java/'
[add_row(textract.process(dirpath + f),'technical', test) for f in listdir(dirpath) if isfile(join(dirpath, f))]
dirpath = 'data/test/hippa/'
[add_row(textract.process(dirpath + f),'hippa', test) for f in listdir(dirpath) if isfile(join(dirpath, f))]
dirpath = 'data/test/mobile/'
[add_row(textract.process(dirpath + f),'mobile', test) for f in listdir(dirpath) if isfile(join(dirpath, f))]
dirpath = 'data/test/srs/'
[add_row(textract.process(dirpath + f),'srs', test) for f in listdir(dirpath) if isfile(join(dirpath, f))]
# Out:
# [None, None, None]

# %% [markdown]
# ##### Tokenizers for different data types

# %%
def verify_tokenize_xml(text):
#    text = '<guestbook><guest><fname>Terje</fname><lname>Beck</lname></guest><guest><fname>Jan</fname><lname>Refsnes</lname></guest><guest><fname>Torleif</fname><lname>Rasmussen</lname></guest>'
    xml_pattern = '<([^<>]+)>([^<>]*)<(\/[^<>]+)>'
    if re.search(xml_pattern, text):
        text = re.sub('<',' <', text)
        text = re.sub('>','> ', text)
        return re.split(' |\n', text) 
    else :
        return []

# %%
def verify_tokenize_hippa(text):
#    text = 'ISA*00*          *00*          *ZZ*EMEDNYBAT      *ZZ*ETIN           *100101*1000*^*00501*006000600*0*T*:~GS*HP*EMEDNYBAT*ETIN*20100101*1050*6000600*X*005010X221A1~ST*835*1740~BPR*H*0*C*NON************20100101~TRN*1*10100000000*1000000000~REF*EV*ETIN~DTM*405*20100101~N1*PR*NYSDOH~N3*OFFICE OF HEALTH INSURANCE PROGRAMS*CORNING TOWER, EMPIRE STATE PLAZA~N4*ALBANY*NY*122370080~PER*BL*PROVIDER SERVICES*TE*8003439000*UR*www.emedny.org~N1*PE*MAJOR MEDICAL PROVIDER*XX*9999999995~REF*TJ*000000000~LX*1~CLP*PATIENT ACCOUNT NUMBER*2*34*0**MC*1000220000000030*11~NM1*QC*1*SUBMITTED LAST*SUBMITTED FIRST****MI*LL88888L~NM1*74*1*CORRECTED LAST*CORRECTED FIRST~REF*EA*PATIENT ACCOUNT NUMBER~DTM*232*20100101~DTM*233*20100101~SVC*HC:V2020*12*0**0~DTM*472*20100101~CAS*CO*29*12~SVC*HC:V2103*22*0**0~DTM*472*20100101~CAS*CO*29*22~SE*25*1740~GE*1*6000600~IEA*1*006000600~'
    hippa_pattern = '[[^a-zA-Z0-9]*/*[[^a-zA-Z0-9., -_]*/*[^a-zA-Z0-9., -_]*]*~]*'    
    if re.match(hippa_pattern, text)    :
        text = re.sub('\*','\* ', text)
        text = re.sub('~',' ~ ', text)
        return re.split(' |\n', text) 
    else :
        return []

# %%
def verify_tokenize_log(text):
#    text = "172.16.0.3 - - [25/Sep/2002:14:04:19 +0200] \"GET / HTTP/1.1\" 401 - \"\" \"Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.1) Gecko/20020827"
#    text = "192.168.2.32 - - [10/Feb/2017:13:02:23 +0530] \"GET / HTTP/1.0\" 200 45"
    log_pattern1 = r"(.*): (.*): (.*)"
    log_pattern2 = r"((\[[^\]]+\]) (\[[^\]]+\]) (\[[^\]]+\]) (.*): (.*))"
#    log_pattern3 = r"\"(.*?)\"|\[(.*?)\]|(\S+)"
    log_pattern5 = r"(.*?)-\[(.*?)\](.*)"
    log_pattern4 = r"^(\[[^\]]+\]) (\[[^\]]+\]) (\[[^\]]+\]) (.*)$"
    pattern = "|".join([log_pattern1, log_pattern2, log_pattern4, log_pattern5])

    if re.search(pattern, text):
        return re.split(pattern + "| |\n", text) 
    else :
        return []

verify_tokenize_log('Hi This is I am')
# Out:
# []

# %%
import nltk
from nltk.corpus import stopwords
cashedstopwords = stopwords.words('english')
cashedstopwords.extend(["\'",',','.','...', 'i\'m', 'n\'t','\'m',''])

def tokenize_text(text):
#    filtered = [w for w in get_tokens(nltk.word_tokenize(text.lower())) if not w in cashedstopwords]
    review_text = re.sub("[^a-zA-Z0-9]"," ", text)
    words = review_text.lower().split()
    words = [w for w in words if not w in cashedstopwords]
    return words

# %%
def review_to_wordlist( text):
    words = verify_tokenize_xml(text)
    if len(words) == 0:
        words = verify_tokenize_hippa(text)
        if len(words) == 0:
            words = verify_tokenize_log(text)
            if len(words) == 0:
                review_text = re.sub("[^a-zA-Z0-9]"," ", text)
                words = review_text.lower().split()
                words = [w for w in words if not w in cashedstopwords]
    return([word for word in words if word is not None ])

# %%
import nltk.data

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
import string

printable = set(string.printable)

def review_to_sentences( text):
    text = filter(lambda x: x in printable, text.strip())
    raw_sentences = tokenizer.tokenize(text)
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.extend( review_to_wordlist( raw_sentence ))
    return sentences

# %% [markdown]
# ##### Term Frequency using CountVectorize - Cosine Similarity

# %%
vectorizer = CountVectorizer(tokenizer=review_to_sentences,  analyzer = "word",   \
                             preprocessor = None, \
                             stop_words = None) 
train_data_features = vectorizer.fit_transform(data['text'])

# %%
pairwise_similarity = cosine_similarity(train_data_features)
print(pairwise_similarity.shape)
dist = 1 - pairwise_similarity
print(dist.shape)
# Out:
# (116, 116)
# (116, 116)

# %%
for i in range(len(pairwise_similarity)):
    for j in range(len(pairwise_similarity)):
        if( pairwise_similarity[i][j] > 0.6):
            print(i , j,  pairwise_similarity[i][j], data['tag'][i], data['tag'][j])
# Out:
# (0, 0, 1.0000000000000155, 'shortstory', 'shortstory')
# (0, 1, 0.66550071448199644, 'shortstory', 'shortstory')
# (0, 2, 0.63067213902944208, 'shortstory', 'shortstory')
# (0, 3, 0.62927429400527113, 'shortstory', 'shortstory')
# (0, 5, 0.68384797283727783, 'shortstory', 'shortstory')
# (0, 6, 0.69449758671910788, 'shortstory', 'shortstory')
# (0, 9, 0.60481769896147286, 'shortstory', 'shortstory')
# (1, 0, 0.66550071448199644, 'shortstory', 'shortstory')
# (1, 1, 0.99999999999997635, 'shortstory', 'shortstory')
# (1, 2, 0.66355526366197926, 'shortstory', 'shortstory')
# (1, 3, 0.72255794365432158, 'shortstory', 'shortstory')
# (1, 5, 0.74182290906846249, 'shortstory', 'shortstory')
# (1, 6, 0.77417140882202362, 'shortstory', 'shortstory')
# (1, 8, 0.60512632809738498, 'shortstory', 'shortstory')
# (1, 9, 0.62376298376350636, 'shortstory', 'shortstory')
# (2, 0, 0.63067213902944208, 'shortstory', 'shortstory')
# (2, 1, 0.66355526366197926, 'shortstory', 'shortstory')
# (2, 2, 0.99999999999998079, 'shortstory', 'shortstory')
# (2, 3, 0.67942160190577117, 'shortstory', 'shortstory')
# (2, 5, 0.69974481741564254, 'shortstory', 'shortstory')
# (2, 6, 0.63025100326265115, 'shortstory', 'shortstory')
# (2, 8, 0.61880746992405289, 'shortstory', 'shortstory')
# (2, 9, 0.66943276248538974, 'shortstory', 'shortstory')
# (3, 0, 0.62927429400527113, 'shortstory', 'shortstory')
# (3, 1, 0.72255794365432158, 'shortstory', 'shortstory')
# (3, 2, 0.67942160190577117, 'shortstory', 'shortstory')
# (3, 3, 1.0000000000000329, 'shortstory', 'shortstory')
# (3, 5, 0.75465487816475352, 'shortstory', 'shortstory')
# (3, 6, 0.60998983625342174, 'shortstory', 'shortstory')
# (3, 8, 0.66105557982354346, 'shortstory', 'shortstory')
# (4, 4, 1.0000000000001052, 'shortstory', 'shortstory')
# (5, 0, 0.68384797283727783, 'shortstory', 'shortstory')
# (5, 1, 0.74182290906846249, 'shortstory', 'shortstory')
# (5, 2, 0.69974481741564254, 'shortstory', 'shortstory')
# (5, 3, 0.75465487816475352, 'shortstory', 'shortstory')
# (5, 5, 0.99999999999991918, 'shortstory', 'shortstory')
# (5, 6, 0.73610915699277435, 'shortstory', 'shortstory')
# (5, 8, 0.67175941231894198, 'shortstory', 'shortstory')
# (5, 9, 0.64327426859057302, 'shortstory', 'shortstory')
# (6, 0, 0.69449758671910788, 'shortstory', 'shortstory')
# (6, 1, 0.77417140882202362, 'shortstory', 'shortstory')
# (6, 2, 0.63025100326265115, 'shortstory', 'shortstory')
# (6, 3, 0.60998983625342174, 'shortstory', 'shortstory')
# (6, 5, 0.73610915699277435, 'shortstory', 'shortstory')
# (6, 6, 0.99999999999998035, 'shortstory', 'shortstory')
# (7, 7, 1.0000000000000013, 'shortstory', 'shortstory')
# (8, 1, 0.60512632809738498, 'shortstory', 'shortstory')
# (8, 2, 0.61880746992405289, 'shortstory', 'shortstory')
# (8, 3, 0.66105557982354346, 'shortstory', 'shortstory')
# (8, 5, 0.67175941231894198, 'shortstory', 'shortstory')
# (8, 8, 0.99999999999997347, 'shortstory', 'shortstory')
# (9, 0, 0.60481769896147286, 'shortstory', 'shortstory')
# (9, 1, 0.62376298376350636, 'shortstory', 'shortstory')
# (9, 2, 0.66943276248538974, 'shortstory', 'shortstory')
# (9, 5, 0.64327426859057302, 'shortstory', 'shortstory')
# (9, 9, 1.0000000000000304, 'shortstory', 'shortstory')
# (10, 10, 0.99999999999999367, 'technical', 'technical')
# (10, 11, 0.67267845164330831, 'technical', 'technical')
# (10, 12, 0.64996477380730078, 'technical', 'technical')
# (10, 17, 0.68412415086354328, 'technical', 'technical')
# (10, 19, 0.6707643511043605, 'technical', 'technical')
# (10, 20, 0.66479315886304413, 'technical', 'technical')
# (10, 21, 0.66195996207257191, 'technical', 'technical')
# (11, 10, 0.67267845164330831, 'technical', 'technical')
# (11, 11, 0.99999999999993661, 'technical', 'technical')
# (11, 12, 0.76545584565870672, 'technical', 'technical')
# (11, 16, 0.78972183840385024, 'technical', 'technical')
# (11, 17, 0.84297575809193315, 'technical', 'technical')
# (11, 19, 0.74316804346491316, 'technical', 'technical')
# (11, 20, 0.85869866213066404, 'technical', 'technical')
# (11, 21, 0.64225034136024817, 'technical', 'technical')
# (12, 10, 0.64996477380730078, 'technical', 'technical')
# (12, 11, 0.76545584565870672, 'technical', 'technical')
# (12, 12, 0.99999999999997735, 'technical', 'technical')
# (12, 16, 0.68773105332333717, 'technical', 'technical')
# (12, 17, 0.78283230378334245, 'technical', 'technical')
# (12, 19, 0.74012461179772304, 'technical', 'technical')
# (12, 20, 0.80550951152749828, 'technical', 'technical')
# (12, 21, 0.71138905402838126, 'technical', 'technical')
# (12, 22, 0.71673002062397784, 'technical', 'technical')
# (12, 23, 0.66761850196885308, 'technical', 'technical')
# (12, 25, 0.66761850196885308, 'technical', 'technical')
# (12, 32, 0.68748317389743252, 'technical', 'technical')
# (13, 13, 1.0000000000000349, 'technical', 'technical')
# (14, 14, 0.999999999999998, 'technical', 'technical')
# (15, 15, 1.0000000000000107, 'technical', 'technical')
# (16, 11, 0.78972183840385024, 'technical', 'technical')
# (16, 12, 0.68773105332333717, 'technical', 'technical')
# (16, 16, 1.00000000000005, 'technical', 'technical')
# (16, 17, 0.73295682796663642, 'technical', 'technical')
# (16, 20, 0.88589894721642359, 'technical', 'technical')
# (17, 10, 0.68412415086354328, 'technical', 'technical')
# (17, 11, 0.84297575809193315, 'technical', 'technical')
# (17, 12, 0.78283230378334245, 'technical', 'technical')
# (17, 16, 0.73295682796663642, 'technical', 'technical')
# (17, 17, 0.99999999999994038, 'technical', 'technical')
# (17, 19, 0.74377775701024162, 'technical', 'technical')
# (17, 20, 0.82852652292703732, 'technical', 'technical')
# (17, 21, 0.65809116399362377, 'technical', 'technical')
# (18, 18, 1.0000000000000056, 'technical', 'technical')
# (19, 10, 0.6707643511043605, 'technical', 'technical')
# (19, 11, 0.74316804346491316, 'technical', 'technical')
# (19, 12, 0.74012461179772304, 'technical', 'technical')
# (19, 17, 0.74377775701024162, 'technical', 'technical')
# (19, 19, 0.9999999999999456, 'technical', 'technical')
# (19, 20, 0.68714242276406923, 'technical', 'technical')
# (19, 21, 0.70534099583069709, 'technical', 'technical')
# (19, 22, 0.61170276757164455, 'technical', 'technical')
# (19, 23, 0.60893758084484639, 'technical', 'technical')
# (19, 25, 0.60893758084484639, 'technical', 'technical')
# (19, 32, 0.61904804819789527, 'technical', 'technical')
# (20, 10, 0.66479315886304413, 'technical', 'technical')
# (20, 11, 0.85869866213066404, 'technical', 'technical')
# (20, 12, 0.80550951152749828, 'technical', 'technical')
# (20, 16, 0.88589894721642359, 'technical', 'technical')
# (20, 17, 0.82852652292703732, 'technical', 'technical')
# (20, 19, 0.68714242276406923, 'technical', 'technical')
# (20, 20, 0.99999999999997846, 'technical', 'technical')
# (20, 21, 0.64285427097098224, 'technical', 'technical')
# (21, 10, 0.66195996207257191, 'technical', 'technical')
# (21, 11, 0.64225034136024817, 'technical', 'technical')
# (21, 12, 0.71138905402838126, 'technical', 'technical')
# (21, 17, 0.65809116399362377, 'technical', 'technical')
# (21, 19, 0.70534099583069709, 'technical', 'technical')
# (21, 20, 0.64285427097098224, 'technical', 'technical')
# (21, 21, 1.0000000000000422, 'technical', 'technical')
# (21, 22, 0.62712687424097324, 'technical', 'technical')
# (21, 32, 0.63276891684587078, 'technical', 'technical')
# (22, 12, 0.71673002062397784, 'technical', 'technical')
# (22, 19, 0.61170276757164455, 'technical', 'technical')
# (22, 21, 0.62712687424097324, 'technical', 'technical')
# (22, 22, 1.00000000000003, 'technical', 'technical')
# (22, 23, 0.80015865596666735, 'technical', 'technical')
# (22, 24, 0.70389708768245673, 'technical', 'technical')
# (22, 25, 0.80015865596666735, 'technical', 'technical')
# (22, 27, 0.61542328590954576, 'technical', 'technical')
# (22, 28, 0.77163037943733637, 'technical', 'technical')
# (22, 30, 0.70389708768245673, 'technical', 'technical')
# (22, 31, 0.77163037943733637, 'technical', 'technical')
# (22, 32, 0.81879087478934576, 'technical', 'technical')
# (22, 33, 0.64325280183686184, 'technical', 'technical')
# (22, 34, 0.64325280183686184, 'technical', 'technical')
# (23, 12, 0.66761850196885308, 'technical', 'technical')
# (23, 19, 0.60893758084484639, 'technical', 'technical')
# (23, 22, 0.80015865596666735, 'technical', 'technical')
# (23, 23, 0.99999999999997835, 'technical', 'technical')
# (23, 24, 0.72716556588708703, 'technical', 'technical')
# (23, 25, 0.99999999999997835, 'technical', 'technical')
# (23, 27, 0.60319792095433133, 'technical', 'technical')
# (23, 28, 0.7586639334878279, 'technical', 'technical')
# (23, 30, 0.72716556588708703, 'technical', 'technical')
# (23, 31, 0.7586639334878279, 'technical', 'technical')
# (23, 32, 0.80258825316710258, 'technical', 'technical')
# (23, 33, 0.63178152064383897, 'technical', 'technical')
# (23, 34, 0.63178152064383897, 'technical', 'technical')
# (24, 22, 0.70389708768245673, 'technical', 'technical')
# (24, 23, 0.72716556588708703, 'technical', 'technical')
# (24, 24, 0.99999999999999334, 'technical', 'technical')
# (24, 25, 0.72716556588708703, 'technical', 'technical')
# (24, 28, 0.63823376482742022, 'technical', 'technical')
# (24, 29, 0.74761440082438047, 'technical', 'technical')
# (24, 30, 0.99999999999999334, 'technical', 'technical')
# (24, 31, 0.63823376482742022, 'technical', 'technical')
# (24, 32, 0.77942762352016692, 'technical', 'technical')
# (24, 33, 0.64864183198126246, 'technical', 'technical')
# (24, 34, 0.64864183198126246, 'technical', 'technical')
# (25, 12, 0.66761850196885308, 'technical', 'technical')
# (25, 19, 0.60893758084484639, 'technical', 'technical')
# (25, 22, 0.80015865596666735, 'technical', 'technical')
# (25, 23, 0.99999999999997835, 'technical', 'technical')
# (25, 24, 0.72716556588708703, 'technical', 'technical')
# (25, 25, 0.99999999999997835, 'technical', 'technical')
# (25, 27, 0.60319792095433133, 'technical', 'technical')
# (25, 28, 0.7586639334878279, 'technical', 'technical')
# (25, 30, 0.72716556588708703, 'technical', 'technical')
# (25, 31, 0.7586639334878279, 'technical', 'technical')
# (25, 32, 0.80258825316710258, 'technical', 'technical')
# (25, 33, 0.63178152064383897, 'technical', 'technical')
# (25, 34, 0.63178152064383897, 'technical', 'technical')
# (26, 26, 0.99999999999998734, 'technical', 'technical')
# (27, 22, 0.61542328590954576, 'technical', 'technical')
# (27, 23, 0.60319792095433133, 'technical', 'technical')
# (27, 25, 0.60319792095433133, 'technical', 'technical')
# (27, 27, 0.99999999999993161, 'technical', 'technical')
# (27, 32, 0.63089052008829127, 'technical', 'technical')
# (28, 22, 0.77163037943733637, 'technical', 'technical')
# (28, 23, 0.7586639334878279, 'technical', 'technical')
# (28, 24, 0.63823376482742022, 'technical', 'technical')
# (28, 25, 0.7586639334878279, 'technical', 'technical')
# (28, 28, 1.0000000000000875, 'technical', 'technical')
# (28, 30, 0.63823376482742022, 'technical', 'technical')
# (28, 31, 1.0000000000000875, 'technical', 'technical')
# (28, 32, 0.70459224453013991, 'technical', 'technical')
# (29, 24, 0.74761440082438047, 'technical', 'technical')
# (29, 29, 0.99999999999997047, 'technical', 'technical')
# (29, 30, 0.74761440082438047, 'technical', 'technical')
# (29, 32, 0.62661637438893703, 'technical', 'technical')
# (30, 22, 0.70389708768245673, 'technical', 'technical')
# (30, 23, 0.72716556588708703, 'technical', 'technical')
# (30, 24, 0.99999999999999334, 'technical', 'technical')
# (30, 25, 0.72716556588708703, 'technical', 'technical')
# (30, 28, 0.63823376482742022, 'technical', 'technical')
# (30, 29, 0.74761440082438047, 'technical', 'technical')
# (30, 30, 0.99999999999999334, 'technical', 'technical')
# (30, 31, 0.63823376482742022, 'technical', 'technical')
# (30, 32, 0.77942762352016692, 'technical', 'technical')
# (30, 33, 0.64864183198126246, 'technical', 'technical')
# (30, 34, 0.64864183198126246, 'technical', 'technical')
# (31, 22, 0.77163037943733637, 'technical', 'technical')
# (31, 23, 0.7586639334878279, 'technical', 'technical')
# (31, 24, 0.63823376482742022, 'technical', 'technical')
# (31, 25, 0.7586639334878279, 'technical', 'technical')
# (31, 28, 1.0000000000000875, 'technical', 'technical')
# (31, 30, 0.63823376482742022, 'technical', 'technical')
# (31, 31, 1.0000000000000875, 'technical', 'technical')
# (31, 32, 0.70459224453013991, 'technical', 'technical')
# (32, 12, 0.68748317389743252, 'technical', 'technical')
# (32, 19, 0.61904804819789527, 'technical', 'technical')
# (32, 21, 0.63276891684587078, 'technical', 'technical')
# (32, 22, 0.81879087478934576, 'technical', 'technical')
# (32, 23, 0.80258825316710258, 'technical', 'technical')
# (32, 24, 0.77942762352016692, 'technical', 'technical')
# (32, 25, 0.80258825316710258, 'technical', 'technical')
# (32, 27, 0.63089052008829127, 'technical', 'technical')
# (32, 28, 0.70459224453013991, 'technical', 'technical')
# (32, 29, 0.62661637438893703, 'technical', 'technical')
# (32, 30, 0.77942762352016692, 'technical', 'technical')
# (32, 31, 0.70459224453013991, 'technical', 'technical')
# (32, 32, 0.9999999999999406, 'technical', 'technical')
# (32, 33, 0.64697723790272021, 'technical', 'technical')
# (32, 34, 0.64697723790272021, 'technical', 'technical')
# (33, 22, 0.64325280183686184, 'technical', 'technical')
# (33, 23, 0.63178152064383897, 'technical', 'technical')
# (33, 24, 0.64864183198126246, 'technical', 'technical')
# (33, 25, 0.63178152064383897, 'technical', 'technical')
# (33, 30, 0.64864183198126246, 'technical', 'technical')
# (33, 32, 0.64697723790272021, 'technical', 'technical')
# (33, 33, 1.0000000000000104, 'technical', 'technical')
# (33, 34, 1.0000000000000104, 'technical', 'technical')
# (34, 22, 0.64325280183686184, 'technical', 'technical')
# (34, 23, 0.63178152064383897, 'technical', 'technical')
# (34, 24, 0.64864183198126246, 'technical', 'technical')
# (34, 25, 0.63178152064383897, 'technical', 'technical')
# (34, 30, 0.64864183198126246, 'technical', 'technical')
# (34, 32, 0.64697723790272021, 'technical', 'technical')
# (34, 33, 1.0000000000000104, 'technical', 'technical')
# (34, 34, 1.0000000000000104, 'technical', 'technical')
# (35, 35, 0.99999999999998845, 'medicine', 'medicine')
# (36, 36, 1.0000000000000053, 'medicine', 'medicine')
# (37, 37, 0.99999999999999789, 'medicine', 'medicine')
# (38, 38, 0.99999999999999767, 'medicine', 'medicine')
# (39, 39, 0.99999999999998901, 'medicine', 'medicine')
# (40, 40, 0.99999999999999645, 'medicine', 'medicine')
# (41, 41, 1.0000000000000044, 'medicine', 'medicine')
# (42, 42, 0.99999999999999512, 'medicine', 'medicine')
# (43, 43, 1.000000000000002, 'medicine', 'medicine')
# (44, 44, 1.0000000000000042, 'medicine', 'medicine')
# (45, 45, 1.0000000000000078, 'medicine', 'medicine')
# (46, 46, 0.99999999999999267, 'medicine', 'medicine')
# (47, 47, 0.99999999999999367, 'medicine', 'medicine')
# (48, 48, 0.99999999999999578, 'medicine', 'medicine')
# (49, 49, 0.99999999999999944, 'medicine', 'medicine')
# (49, 52, 0.99999999999999944, 'medicine', 'medicine')
# (50, 50, 1.0000000000000002, 'medicine', 'medicine')
# (51, 51, 1.0000000000000033, 'medicine', 'medicine')
# (52, 49, 0.99999999999999944, 'medicine', 'medicine')
# (52, 52, 0.99999999999999944, 'medicine', 'medicine')
# (53, 53, 0.99999999999999267, 'mobile', 'mobile')
# (54, 54, 1.0000000000000069, 'mobile', 'mobile')
# (55, 55, 1.0000000000000016, 'mobile', 'mobile')
# (55, 64, 1.0000000000000016, 'mobile', 'mobile')
# (56, 56, 0.99999999999999833, 'mobile', 'mobile')
# (56, 65, 0.8824586802075709, 'mobile', 'mobile')
# (57, 57, 1.0000000000000027, 'mobile', 'mobile')
# (58, 58, 1.0000000000000049, 'mobile', 'mobile')
# (59, 59, 0.999999999999997, 'mobile', 'mobile')
# (59, 63, 0.64610685909147936, 'mobile', 'mobile')
# (60, 60, 0.99999999999999778, 'mobile', 'mobile')
# (61, 61, 1.0000000000000016, 'mobile', 'mobile')
# (62, 62, 0.99999999999999101, 'mobile', 'mobile')
# (63, 59, 0.64610685909147936, 'mobile', 'mobile')
# (63, 63, 0.99999999999999523, 'mobile', 'mobile')
# (64, 55, 1.0000000000000016, 'mobile', 'mobile')
# (64, 64, 1.0000000000000016, 'mobile', 'mobile')
# (65, 56, 0.8824586802075709, 'mobile', 'mobile')
# (65, 65, 1.0000000000000033, 'mobile', 'mobile')
# (66, 66, 0.999999999999995, 'mobile', 'mobile')
# (67, 67, 0.99999999999999434, 'mobile', 'mobile')
# (68, 68, 0.99999999999998435, 'mobile', 'mobile')
# (68, 72, 0.99999999999998435, 'mobile', 'mobile')
# (69, 69, 0.99999999999996425, 'mobile', 'mobile')
# (69, 74, 0.63856636074297102, 'mobile', 'mobile')
# (69, 78, 0.78570076525842147, 'mobile', 'mobile')
# (70, 70, 1.00000000000001, 'mobile', 'mobile')
# (70, 78, 0.74920387708795788, 'mobile', 'mobile')
# (71, 71, 0.9999999999999879, 'mobile', 'mobile')
# (72, 68, 0.99999999999998435, 'mobile', 'mobile')
# (72, 72, 0.99999999999998435, 'mobile', 'mobile')
# (73, 73, 0.99999999999998057, 'mobile', 'mobile')
# (74, 69, 0.63856636074297102, 'mobile', 'mobile')
# (74, 74, 1.0000000000000098, 'mobile', 'mobile')
# (74, 77, 0.64497872708449988, 'mobile', 'mobile')
# (74, 78, 0.68398147897434569, 'mobile', 'mobile')
# (75, 75, 0.99999999999999423, 'mobile', 'mobile')
# (76, 76, 1.0000000000000187, 'mobile', 'mobile')
# (76, 77, 0.63307056230321623, 'mobile', 'mobile')
# (76, 78, 0.68481128279491343, 'mobile', 'mobile')
# (77, 74, 0.64497872708449988, 'mobile', 'mobile')
# (77, 76, 0.63307056230321623, 'mobile', 'mobile')
# (77, 77, 0.99999999999997236, 'mobile', 'mobile')
# (77, 78, 0.7328781210445211, 'mobile', 'mobile')
# (78, 69, 0.78570076525842147, 'mobile', 'mobile')
# (78, 70, 0.74920387708795788, 'mobile', 'mobile')
# (78, 74, 0.68398147897434569, 'mobile', 'mobile')
# (78, 76, 0.68481128279491343, 'mobile', 'mobile')
# (78, 77, 0.7328781210445211, 'mobile', 'mobile')
# (78, 78, 0.99999999999999256, 'mobile', 'mobile')
# (79, 79, 1.0000000000000027, 'mobile', 'mobile')
# (80, 80, 1.000000000000002, 'lcd', 'lcd')
# (81, 81, 0.99999999999999645, 'lcd', 'lcd')
# (82, 82, 0.99999999999999423, 'lcd', 'lcd')
# (83, 83, 1.0000000000000009, 'lcd', 'lcd')
# (84, 84, 0.99999999999999933, 'lcd', 'lcd')
# (85, 85, 0.99999999999999889, 'lcd', 'lcd')
# (86, 86, 1.0000000000000069, 'lcd', 'lcd')
# (87, 87, 0.99999999999999289, 'lcd', 'lcd')
# (88, 88, 1.000000000000006, 'lcd', 'lcd')
# (89, 89, 0.99999999999999356, 'lcd', 'lcd')
# (90, 90, 1.0000000000000027, 'lcd', 'lcd')
# (91, 91, 0.99999999999999667, 'lcd', 'lcd')
# (92, 92, 0.99999999999999567, 'lcd', 'lcd')
# (93, 93, 1.000000000000004, 'hippa', 'hippa')
# (93, 94, 0.91631181917884441, 'hippa', 'hippa')
# (93, 96, 0.92906158870160094, 'hippa', 'hippa')
# (93, 97, 0.88934546844198603, 'hippa', 'hippa')
# (93, 98, 0.97117574229774195, 'hippa', 'hippa')
# (93, 99, 0.94758472929010806, 'hippa', 'hippa')
# (93, 100, 0.91957849533699698, 'hippa', 'hippa')
# (93, 101, 0.93055197325366867, 'hippa', 'hippa')
# (93, 102, 0.94415395124158241, 'hippa', 'hippa')
# (93, 103, 0.92980693564497874, 'hippa', 'hippa')
# (93, 104, 0.95609652380244747, 'hippa', 'hippa')
# (93, 105, 0.84502866560321355, 'hippa', 'hippa')
# (93, 106, 0.97179695039162106, 'hippa', 'hippa')
# (93, 107, 0.80321238514483639, 'hippa', 'hippa')
# (93, 108, 0.97626125826562915, 'hippa', 'hippa')
# (93, 109, 0.92717714962552844, 'hippa', 'hippa')
# (94, 93, 0.91631181917884441, 'hippa', 'hippa')
# (94, 94, 0.99999999999999911, 'hippa', 'hippa')
# (94, 96, 0.9144749955798479, 'hippa', 'hippa')
# (94, 97, 0.81591844006866476, 'hippa', 'hippa')
# (94, 98, 0.91992245213923152, 'hippa', 'hippa')
# (94, 99, 0.97087435985069992, 'hippa', 'hippa')
# (94, 100, 0.94449684823343016, 'hippa', 'hippa')
# (94, 101, 0.89658610364636104, 'hippa', 'hippa')
# (94, 102, 0.90818304147559104, 'hippa', 'hippa')
# (94, 103, 0.89595045238535687, 'hippa', 'hippa')
# (94, 104, 0.91595069519530536, 'hippa', 'hippa')
# (94, 105, 0.87770249857439209, 'hippa', 'hippa')
# (94, 106, 0.91764431615332565, 'hippa', 'hippa')
# (94, 107, 0.70302508468535441, 'hippa', 'hippa')
# (94, 108, 0.91040822870087124, 'hippa', 'hippa')
# (94, 109, 0.91132955942106553, 'hippa', 'hippa')
# (95, 95, 0.99999999999999711, 'hippa', 'hippa')
# (96, 93, 0.92906158870160094, 'hippa', 'hippa')
# (96, 94, 0.9144749955798479, 'hippa', 'hippa')
# (96, 96, 1.0000000000000018, 'hippa', 'hippa')
# (96, 97, 0.85348478731886512, 'hippa', 'hippa')
# (96, 98, 0.92573494167086157, 'hippa', 'hippa')
# (96, 99, 0.92620081094572437, 'hippa', 'hippa')
# (96, 100, 0.91525046169409863, 'hippa', 'hippa')
# (96, 101, 0.94707329047198563, 'hippa', 'hippa')
# (96, 102, 0.95605476275461609, 'hippa', 'hippa')
# (96, 103, 0.94638022549542367, 'hippa', 'hippa')
# (96, 104, 0.92498597293105411, 'hippa', 'hippa')
# (96, 105, 0.88957893384297981, 'hippa', 'hippa')
# (96, 106, 0.92203348788042561, 'hippa', 'hippa')
# (96, 107, 0.75465485472946914, 'hippa', 'hippa')
# (96, 108, 0.92458547969143878, 'hippa', 'hippa')
# (96, 109, 0.98060333545281275, 'hippa', 'hippa')
# (97, 93, 0.88934546844198603, 'hippa', 'hippa')
# (97, 94, 0.81591844006866476, 'hippa', 'hippa')
# (97, 96, 0.85348478731886512, 'hippa', 'hippa')
# (97, 97, 1.0000000000000047, 'hippa', 'hippa')
# (97, 98, 0.89331755152932746, 'hippa', 'hippa')
# (97, 99, 0.84883503866515642, 'hippa', 'hippa')
# (97, 100, 0.77313792725692365, 'hippa', 'hippa')
# (97, 101, 0.82310150506537139, 'hippa', 'hippa')
# (97, 102, 0.84913285137910055, 'hippa', 'hippa')
# (97, 103, 0.82310150506537139, 'hippa', 'hippa')
# (97, 104, 0.94606409720833295, 'hippa', 'hippa')
# (97, 105, 0.69348969660697501, 'hippa', 'hippa')
# (97, 106, 0.8642679980316208, 'hippa', 'hippa')
# (97, 107, 0.97346057178274803, 'hippa', 'hippa')
# (97, 108, 0.88513012594730134, 'hippa', 'hippa')
# (97, 109, 0.86109624548108188, 'hippa', 'hippa')
# (98, 93, 0.97117574229774195, 'hippa', 'hippa')
# (98, 94, 0.91992245213923152, 'hippa', 'hippa')
# (98, 96, 0.92573494167086157, 'hippa', 'hippa')
# (98, 97, 0.89331755152932746, 'hippa', 'hippa')
# (98, 98, 0.99999999999999944, 'hippa', 'hippa')
# (98, 99, 0.93431542490390651, 'hippa', 'hippa')
# (98, 100, 0.91238224535773194, 'hippa', 'hippa')
# (98, 101, 0.91333249790664861, 'hippa', 'hippa')
# (98, 102, 0.93400257316683399, 'hippa', 'hippa')
# (98, 103, 0.91257798944080259, 'hippa', 'hippa')
# (98, 104, 0.95050492013962939, 'hippa', 'hippa')
# (98, 105, 0.83955657859462429, 'hippa', 'hippa')
# (98, 106, 0.98210600320834596, 'hippa', 'hippa')
# (98, 107, 0.8098068340521003, 'hippa', 'hippa')
# (98, 108, 0.96738219079866783, 'hippa', 'hippa')
# (98, 109, 0.92355056040555028, 'hippa', 'hippa')
# (99, 93, 0.94758472929010806, 'hippa', 'hippa')
# (99, 94, 0.97087435985069992, 'hippa', 'hippa')
# (99, 96, 0.92620081094572437, 'hippa', 'hippa')
# (99, 97, 0.84883503866515642, 'hippa', 'hippa')
# (99, 98, 0.93431542490390651, 'hippa', 'hippa')
# (99, 99, 0.99999999999999845, 'hippa', 'hippa')
# (99, 100, 0.94807845815580261, 'hippa', 'hippa')
# (99, 101, 0.92461350155374999, 'hippa', 'hippa')
# (99, 102, 0.93617120527037767, 'hippa', 'hippa')
# (99, 103, 0.9239358808124134, 'hippa', 'hippa')
# (99, 104, 0.94432857110844115, 'hippa', 'hippa')
# (99, 105, 0.87197687131825508, 'hippa', 'hippa')
# (99, 106, 0.92902726031683969, 'hippa', 'hippa')
# (99, 107, 0.74390323022800764, 'hippa', 'hippa')
# (99, 108, 0.94489832704256616, 'hippa', 'hippa')
# (99, 109, 0.92378194226102228, 'hippa', 'hippa')
# (100, 93, 0.91957849533699698, 'hippa', 'hippa')
# (100, 94, 0.94449684823343016, 'hippa', 'hippa')
# (100, 96, 0.91525046169409863, 'hippa', 'hippa')
# (100, 97, 0.77313792725692365, 'hippa', 'hippa')
# (100, 98, 0.91238224535773194, 'hippa', 'hippa')
# (100, 99, 0.94807845815580261, 'hippa', 'hippa')
# (100, 100, 0.99999999999999933, 'hippa', 'hippa')
# (100, 101, 0.91921440174730296, 'hippa', 'hippa')
# (100, 102, 0.92202308696504331, 'hippa', 'hippa')
# (100, 103, 0.91864785974314445, 'hippa', 'hippa')
# (100, 104, 0.91020198842676125, 'hippa', 'hippa')
# (100, 105, 0.89597640109229837, 'hippa', 'hippa')
# (100, 106, 0.91274249219468195, 'hippa', 'hippa')
# (100, 107, 0.64447857729591251, 'hippa', 'hippa')
# (100, 108, 0.92588343855635236, 'hippa', 'hippa')
# (100, 109, 0.90909648483655814, 'hippa', 'hippa')
# (101, 93, 0.93055197325366867, 'hippa', 'hippa')
# (101, 94, 0.89658610364636104, 'hippa', 'hippa')
# (101, 96, 0.94707329047198563, 'hippa', 'hippa')
# (101, 97, 0.82310150506537139, 'hippa', 'hippa')
# (101, 98, 0.91333249790664861, 'hippa', 'hippa')
# (101, 99, 0.92461350155374999, 'hippa', 'hippa')
# (101, 100, 0.91921440174730296, 'hippa', 'hippa')
# (101, 101, 0.99999999999999911, 'hippa', 'hippa')
# (101, 102, 0.97634846047314183, 'hippa', 'hippa')
# (101, 103, 0.99901542500820395, 'hippa', 'hippa')
# (101, 104, 0.91299277944720925, 'hippa', 'hippa')
# (101, 105, 0.88887678595298603, 'hippa', 'hippa')
# (101, 106, 0.91591679019454653, 'hippa', 'hippa')
# (101, 107, 0.72179120134772479, 'hippa', 'hippa')
# (101, 108, 0.9308413638741273, 'hippa', 'hippa')
# (101, 109, 0.94493436299109324, 'hippa', 'hippa')
# (102, 93, 0.94415395124158241, 'hippa', 'hippa')
# (102, 94, 0.90818304147559104, 'hippa', 'hippa')
# (102, 96, 0.95605476275461609, 'hippa', 'hippa')
# (102, 97, 0.84913285137910055, 'hippa', 'hippa')
# (102, 98, 0.93400257316683399, 'hippa', 'hippa')
# (102, 99, 0.93617120527037767, 'hippa', 'hippa')
# (102, 100, 0.92202308696504331, 'hippa', 'hippa')
# (102, 101, 0.97634846047314183, 'hippa', 'hippa')
# (102, 102, 1.0000000000000011, 'hippa', 'hippa')
# (102, 103, 0.97566016406110578, 'hippa', 'hippa')
# (102, 104, 0.93002181946029316, 'hippa', 'hippa')
# (102, 105, 0.8842103673535715, 'hippa', 'hippa')
# (102, 106, 0.93060911330575247, 'hippa', 'hippa')
# (102, 107, 0.75159691884573043, 'hippa', 'hippa')
# (102, 108, 0.94541333420823315, 'hippa', 'hippa')
# (102, 109, 0.95350604935819305, 'hippa', 'hippa')
# (103, 93, 0.92980693564497874, 'hippa', 'hippa')
# (103, 94, 0.89595045238535687, 'hippa', 'hippa')
# (103, 96, 0.94638022549542367, 'hippa', 'hippa')
# (103, 97, 0.82310150506537139, 'hippa', 'hippa')
# (103, 98, 0.91257798944080259, 'hippa', 'hippa')
# (103, 99, 0.9239358808124134, 'hippa', 'hippa')
# (103, 100, 0.91864785974314445, 'hippa', 'hippa')
# (103, 101, 0.99901542500820395, 'hippa', 'hippa')
# (103, 102, 0.97566016406110578, 'hippa', 'hippa')
# (103, 103, 0.99999999999999911, 'hippa', 'hippa')
# (103, 104, 0.91255791744223314, 'hippa', 'hippa')
# (103, 105, 0.88839863813913289, 'hippa', 'hippa')
# (103, 106, 0.91520539851284199, 'hippa', 'hippa')
# (103, 107, 0.72179120134772479, 'hippa', 'hippa')
# (103, 108, 0.93010054305130674, 'hippa', 'hippa')
# (103, 109, 0.94422866145039797, 'hippa', 'hippa')
# (104, 93, 0.95609652380244747, 'hippa', 'hippa')
# (104, 94, 0.91595069519530536, 'hippa', 'hippa')
# (104, 96, 0.92498597293105411, 'hippa', 'hippa')
# (104, 97, 0.94606409720833295, 'hippa', 'hippa')
# (104, 98, 0.95050492013962939, 'hippa', 'hippa')
# (104, 99, 0.94432857110844115, 'hippa', 'hippa')
# (104, 100, 0.91020198842676125, 'hippa', 'hippa')
# (104, 101, 0.91299277944720925, 'hippa', 'hippa')
# (104, 102, 0.93002181946029316, 'hippa', 'hippa')
# (104, 103, 0.91255791744223314, 'hippa', 'hippa')
# (104, 104, 0.99999999999999978, 'hippa', 'hippa')
# (104, 105, 0.81475505034989459, 'hippa', 'hippa')
# (104, 106, 0.93177139667712772, 'hippa', 'hippa')
# (104, 107, 0.88084455148856988, 'hippa', 'hippa')
# (104, 108, 0.95853802654546927, 'hippa', 'hippa')
# (104, 109, 0.92688997298650577, 'hippa', 'hippa')
# (105, 93, 0.84502866560321355, 'hippa', 'hippa')
# (105, 94, 0.87770249857439209, 'hippa', 'hippa')
# (105, 96, 0.88957893384297981, 'hippa', 'hippa')
# (105, 97, 0.69348969660697501, 'hippa', 'hippa')
# (105, 98, 0.83955657859462429, 'hippa', 'hippa')
# (105, 99, 0.87197687131825508, 'hippa', 'hippa')
# (105, 100, 0.89597640109229837, 'hippa', 'hippa')
# (105, 101, 0.88887678595298603, 'hippa', 'hippa')
# (105, 102, 0.8842103673535715, 'hippa', 'hippa')
# (105, 103, 0.88839863813913289, 'hippa', 'hippa')
# (105, 104, 0.81475505034989459, 'hippa', 'hippa')
# (105, 105, 1.0000000000000002, 'hippa', 'hippa')
# (105, 106, 0.85376596719955611, 'hippa', 'hippa')
# (105, 108, 0.8372778339015472, 'hippa', 'hippa')
# (105, 109, 0.88446443764826332, 'hippa', 'hippa')
# (106, 93, 0.97179695039162106, 'hippa', 'hippa')
# (106, 94, 0.91764431615332565, 'hippa', 'hippa')
# (106, 96, 0.92203348788042561, 'hippa', 'hippa')
# (106, 97, 0.8642679980316208, 'hippa', 'hippa')
# (106, 98, 0.98210600320834596, 'hippa', 'hippa')
# (106, 99, 0.92902726031683969, 'hippa', 'hippa')
# (106, 100, 0.91274249219468195, 'hippa', 'hippa')
# (106, 101, 0.91591679019454653, 'hippa', 'hippa')
# (106, 102, 0.93060911330575247, 'hippa', 'hippa')
# (106, 103, 0.91520539851284199, 'hippa', 'hippa')
# (106, 104, 0.93177139667712772, 'hippa', 'hippa')
# (106, 105, 0.85376596719955611, 'hippa', 'hippa')
# (106, 106, 1.0000000000000036, 'hippa', 'hippa')
# (106, 107, 0.77100034610272794, 'hippa', 'hippa')
# (106, 108, 0.95184444665896173, 'hippa', 'hippa')
# (106, 109, 0.91972372982055761, 'hippa', 'hippa')
# (107, 93, 0.80321238514483639, 'hippa', 'hippa')
# (107, 94, 0.70302508468535441, 'hippa', 'hippa')
# (107, 96, 0.75465485472946914, 'hippa', 'hippa')
# (107, 97, 0.97346057178274803, 'hippa', 'hippa')
# (107, 98, 0.8098068340521003, 'hippa', 'hippa')
# (107, 99, 0.74390323022800764, 'hippa', 'hippa')
# (107, 100, 0.64447857729591251, 'hippa', 'hippa')
# (107, 101, 0.72179120134772479, 'hippa', 'hippa')
# (107, 102, 0.75159691884573043, 'hippa', 'hippa')
# (107, 103, 0.72179120134772479, 'hippa', 'hippa')
# (107, 104, 0.88084455148856988, 'hippa', 'hippa')
# (107, 106, 0.77100034610272794, 'hippa', 'hippa')
# (107, 107, 1.0000000000000007, 'hippa', 'hippa')
# (107, 108, 0.79965834234049493, 'hippa', 'hippa')
# (107, 109, 0.76552971675623627, 'hippa', 'hippa')
# (108, 93, 0.97626125826562915, 'hippa', 'hippa')
# (108, 94, 0.91040822870087124, 'hippa', 'hippa')
# (108, 96, 0.92458547969143878, 'hippa', 'hippa')
# (108, 97, 0.88513012594730134, 'hippa', 'hippa')
# (108, 98, 0.96738219079866783, 'hippa', 'hippa')
# (108, 99, 0.94489832704256616, 'hippa', 'hippa')
# (108, 100, 0.92588343855635236, 'hippa', 'hippa')
# (108, 101, 0.9308413638741273, 'hippa', 'hippa')
# (108, 102, 0.94541333420823315, 'hippa', 'hippa')
# (108, 103, 0.93010054305130674, 'hippa', 'hippa')
# (108, 104, 0.95853802654546927, 'hippa', 'hippa')
# (108, 105, 0.8372778339015472, 'hippa', 'hippa')
# (108, 106, 0.95184444665896173, 'hippa', 'hippa')
# (108, 107, 0.79965834234049493, 'hippa', 'hippa')
# (108, 108, 1.0000000000000022, 'hippa', 'hippa')
# (108, 109, 0.92192948500131144, 'hippa', 'hippa')
# (109, 93, 0.92717714962552844, 'hippa', 'hippa')
# (109, 94, 0.91132955942106553, 'hippa', 'hippa')
# (109, 96, 0.98060333545281275, 'hippa', 'hippa')
# (109, 97, 0.86109624548108188, 'hippa', 'hippa')
# (109, 98, 0.92355056040555028, 'hippa', 'hippa')
# (109, 99, 0.92378194226102228, 'hippa', 'hippa')
# (109, 100, 0.90909648483655814, 'hippa', 'hippa')
# (109, 101, 0.94493436299109324, 'hippa', 'hippa')
# (109, 102, 0.95350604935819305, 'hippa', 'hippa')
# (109, 103, 0.94422866145039797, 'hippa', 'hippa')
# (109, 104, 0.92688997298650577, 'hippa', 'hippa')
# (109, 105, 0.88446443764826332, 'hippa', 'hippa')
# (109, 106, 0.91972372982055761, 'hippa', 'hippa')
# (109, 107, 0.76552971675623627, 'hippa', 'hippa')
# (109, 108, 0.92192948500131144, 'hippa', 'hippa')
# (109, 109, 1.0000000000000038, 'hippa', 'hippa')
# (110, 110, 0.99999999999999101, 'srs', 'srs')
# (111, 111, 1.0000000000000002, 'srs', 'srs')
# (112, 112, 0.99999999999999245, 'srs', 'srs')
# (113, 113, 1.0000000000000042, 'srs', 'srs')
# (114, 114, 0.99999999999999656, 'srs', 'srs')
# (115, 115, 0.99999999999999689, 'srs', 'srs')

# %% [markdown]
# ##### Term Frequency using CountVectorize - Cosine Similarity

# %%
stop_words = stopwords.words("english")  
vectorizer = TfidfVectorizer( min_df=0.15, max_df=0.2, tokenizer=review_to_sentences, 
                             stop_words=stop_words, lowercase=True, use_idf=True, smooth_idf=True, sublinear_tf=True)

train_data_features = vectorizer.fit_transform(data['text'].str.lower())

# %%
train_data_features.shape
# Out:
# (116, 1006)

# %%
pairwise_similarity = cosine_similarity(train_data_features)
print(pairwise_similarity.shape)
dist = 1 - pairwise_similarity
print(dist.shape)
# Out:
# (116, 116)
# (116, 116)

# %%
for i in range(len(pairwise_similarity)):
    for j in range(len(pairwise_similarity)):
        if( pairwise_similarity[i][j] > 0.6 and i != j):
            print(i , j,  pairwise_similarity[i][j], data['tag'][i], data['tag'][j])
# Out:
# (0, 1, 0.69630642233848838, 'shortstory', 'shortstory')
# (0, 2, 0.70720766180967509, 'shortstory', 'shortstory')
# (0, 3, 0.65840718323412561, 'shortstory', 'shortstory')
# (0, 5, 0.68548549129755454, 'shortstory', 'shortstory')
# (0, 6, 0.69164610062197218, 'shortstory', 'shortstory')
# (0, 8, 0.63975304268292821, 'shortstory', 'shortstory')
# (0, 9, 0.62271600454542952, 'shortstory', 'shortstory')
# (1, 0, 0.69630642233848838, 'shortstory', 'shortstory')
# (1, 2, 0.68612306662679823, 'shortstory', 'shortstory')
# (1, 3, 0.79754384259729383, 'shortstory', 'shortstory')
# (1, 4, 0.60884721724825808, 'shortstory', 'shortstory')
# (1, 5, 0.83990873945867883, 'shortstory', 'shortstory')
# (1, 6, 0.87502328471925628, 'shortstory', 'shortstory')
# (1, 8, 0.62047338352472503, 'shortstory', 'shortstory')
# (1, 9, 0.67415629275265598, 'shortstory', 'shortstory')
# (2, 0, 0.70720766180967509, 'shortstory', 'shortstory')
# (2, 1, 0.68612306662679823, 'shortstory', 'shortstory')
# (2, 3, 0.64450292448456126, 'shortstory', 'shortstory')
# (2, 5, 0.67525469776517411, 'shortstory', 'shortstory')
# (2, 6, 0.69198775816833225, 'shortstory', 'shortstory')
# (2, 8, 0.6111085913553348, 'shortstory', 'shortstory')
# (2, 9, 0.64636607564172843, 'shortstory', 'shortstory')
# (3, 0, 0.65840718323412561, 'shortstory', 'shortstory')
# (3, 1, 0.79754384259729383, 'shortstory', 'shortstory')
# (3, 2, 0.64450292448456126, 'shortstory', 'shortstory')
# (3, 5, 0.83407744192648436, 'shortstory', 'shortstory')
# (3, 6, 0.80214806159054586, 'shortstory', 'shortstory')
# (3, 8, 0.60844162859969653, 'shortstory', 'shortstory')
# (4, 1, 0.60884721724825808, 'shortstory', 'shortstory')
# (5, 0, 0.68548549129755454, 'shortstory', 'shortstory')
# (5, 1, 0.83990873945867883, 'shortstory', 'shortstory')
# (5, 2, 0.67525469776517411, 'shortstory', 'shortstory')
# (5, 3, 0.83407744192648436, 'shortstory', 'shortstory')
# (5, 6, 0.83867874894780725, 'shortstory', 'shortstory')
# (5, 8, 0.63528331685303729, 'shortstory', 'shortstory')
# (5, 9, 0.65303653124731764, 'shortstory', 'shortstory')
# (6, 0, 0.69164610062197218, 'shortstory', 'shortstory')
# (6, 1, 0.87502328471925628, 'shortstory', 'shortstory')
# (6, 2, 0.69198775816833225, 'shortstory', 'shortstory')
# (6, 3, 0.80214806159054586, 'shortstory', 'shortstory')
# (6, 5, 0.83867874894780725, 'shortstory', 'shortstory')
# (6, 8, 0.63392332866994572, 'shortstory', 'shortstory')
# (6, 9, 0.68265101710783349, 'shortstory', 'shortstory')
# (8, 0, 0.63975304268292821, 'shortstory', 'shortstory')
# (8, 1, 0.62047338352472503, 'shortstory', 'shortstory')
# (8, 2, 0.6111085913553348, 'shortstory', 'shortstory')
# (8, 3, 0.60844162859969653, 'shortstory', 'shortstory')
# (8, 5, 0.63528331685303729, 'shortstory', 'shortstory')
# (8, 6, 0.63392332866994572, 'shortstory', 'shortstory')
# (8, 9, 0.60138778014621441, 'shortstory', 'shortstory')
# (9, 0, 0.62271600454542952, 'shortstory', 'shortstory')
# (9, 1, 0.67415629275265598, 'shortstory', 'shortstory')
# (9, 2, 0.64636607564172843, 'shortstory', 'shortstory')
# (9, 5, 0.65303653124731764, 'shortstory', 'shortstory')
# (9, 6, 0.68265101710783349, 'shortstory', 'shortstory')
# (9, 8, 0.60138778014621441, 'shortstory', 'shortstory')
# (11, 12, 0.82929990734117864, 'technical', 'technical')
# (11, 13, 0.61615922566026549, 'technical', 'technical')
# (11, 16, 0.65088008175663414, 'technical', 'technical')
# (11, 17, 0.8271757984125464, 'technical', 'technical')
# (11, 19, 0.83629248792497146, 'technical', 'technical')
# (11, 20, 0.83553375244253547, 'technical', 'technical')
# (11, 21, 0.68242758500543654, 'technical', 'technical')
# (11, 22, 0.67790395153630434, 'technical', 'technical')
# (11, 27, 0.68952692441117802, 'technical', 'technical')
# (11, 28, 0.65955091539755206, 'technical', 'technical')
# (11, 29, 0.63255126675878082, 'technical', 'technical')
# (11, 31, 0.65955091539755206, 'technical', 'technical')
# (11, 32, 0.67179136658185723, 'technical', 'technical')
# (11, 33, 0.6372244652523027, 'technical', 'technical')
# (11, 34, 0.6372244652523027, 'technical', 'technical')
# (12, 11, 0.82929990734117864, 'technical', 'technical')
# (12, 16, 0.65692370440899406, 'technical', 'technical')
# (12, 17, 0.80952912573639391, 'technical', 'technical')
# (12, 19, 0.79504694812360688, 'technical', 'technical')
# (12, 20, 0.8271637622969662, 'technical', 'technical')
# (12, 21, 0.67584868160670886, 'technical', 'technical')
# (12, 22, 0.70514499327376479, 'technical', 'technical')
# (12, 23, 0.64356224519169447, 'technical', 'technical')
# (12, 25, 0.64356224519169447, 'technical', 'technical')
# (12, 27, 0.67531514179486785, 'technical', 'technical')
# (12, 28, 0.6962944442954957, 'technical', 'technical')
# (12, 29, 0.60358016388597213, 'technical', 'technical')
# (12, 31, 0.6962944442954957, 'technical', 'technical')
# (12, 32, 0.66731707913516525, 'technical', 'technical')
# (13, 11, 0.61615922566026549, 'technical', 'technical')
# (13, 20, 0.66499049568463919, 'technical', 'technical')
# (16, 11, 0.65088008175663414, 'technical', 'technical')
# (16, 12, 0.65692370440899406, 'technical', 'technical')
# (16, 17, 0.6170156234088191, 'technical', 'technical')
# (16, 19, 0.60137201427909126, 'technical', 'technical')
# (16, 20, 0.74922635134258719, 'technical', 'technical')
# (17, 11, 0.8271757984125464, 'technical', 'technical')
# (17, 12, 0.80952912573639391, 'technical', 'technical')
# (17, 16, 0.6170156234088191, 'technical', 'technical')
# (17, 19, 0.78121445764476882, 'technical', 'technical')
# (17, 20, 0.7943791361000786, 'technical', 'technical')
# (17, 21, 0.664608047516561, 'technical', 'technical')
# (17, 22, 0.65686924402792257, 'technical', 'technical')
# (17, 27, 0.64292785451155487, 'technical', 'technical')
# (17, 28, 0.60402462413297864, 'technical', 'technical')
# (17, 29, 0.6149271705126278, 'technical', 'technical')
# (17, 31, 0.60402462413297864, 'technical', 'technical')
# (17, 32, 0.63281104116235209, 'technical', 'technical')
# (19, 11, 0.83629248792497146, 'technical', 'technical')
# (19, 12, 0.79504694812360688, 'technical', 'technical')
# (19, 16, 0.60137201427909126, 'technical', 'technical')
# (19, 17, 0.78121445764476882, 'technical', 'technical')
# (19, 20, 0.779328842417495, 'technical', 'technical')
# (19, 21, 0.7144194346567041, 'technical', 'technical')
# (19, 22, 0.66886349251901922, 'technical', 'technical')
# (19, 24, 0.6143571708482467, 'technical', 'technical')
# (19, 27, 0.71080969878644118, 'technical', 'technical')
# (19, 28, 0.61608101113167468, 'technical', 'technical')
# (19, 29, 0.65947929592232335, 'technical', 'technical')
# (19, 30, 0.6143571708482467, 'technical', 'technical')
# (19, 31, 0.61608101113167468, 'technical', 'technical')
# (19, 32, 0.67205336544053906, 'technical', 'technical')
# (19, 33, 0.67163774579625946, 'technical', 'technical')
# (19, 34, 0.67163774579625946, 'technical', 'technical')
# (20, 11, 0.83553375244253547, 'technical', 'technical')
# (20, 12, 0.8271637622969662, 'technical', 'technical')
# (20, 13, 0.66499049568463919, 'technical', 'technical')
# (20, 16, 0.74922635134258719, 'technical', 'technical')
# (20, 17, 0.7943791361000786, 'technical', 'technical')
# (20, 19, 0.779328842417495, 'technical', 'technical')
# (20, 21, 0.60196641762535474, 'technical', 'technical')
# (20, 22, 0.63519087172840616, 'technical', 'technical')
# (20, 23, 0.60972772980964907, 'technical', 'technical')
# (20, 25, 0.60972772980964907, 'technical', 'technical')
# (20, 27, 0.66754088049738547, 'technical', 'technical')
# (20, 28, 0.68262949056104216, 'technical', 'technical')
# (20, 31, 0.68262949056104216, 'technical', 'technical')
# (20, 32, 0.63049365048033201, 'technical', 'technical')
# (21, 11, 0.68242758500543654, 'technical', 'technical')
# (21, 12, 0.67584868160670886, 'technical', 'technical')
# (21, 17, 0.664608047516561, 'technical', 'technical')
# (21, 19, 0.7144194346567041, 'technical', 'technical')
# (21, 20, 0.60196641762535474, 'technical', 'technical')
# (21, 33, 0.60416915108506863, 'technical', 'technical')
# (21, 34, 0.60416915108506863, 'technical', 'technical')
# (22, 11, 0.67790395153630434, 'technical', 'technical')
# (22, 12, 0.70514499327376479, 'technical', 'technical')
# (22, 17, 0.65686924402792257, 'technical', 'technical')
# (22, 19, 0.66886349251901922, 'technical', 'technical')
# (22, 20, 0.63519087172840616, 'technical', 'technical')
# (22, 27, 0.61870195504664649, 'technical', 'technical')
# (22, 28, 0.65926879362059621, 'technical', 'technical')
# (22, 31, 0.65926879362059621, 'technical', 'technical')
# (22, 32, 0.74706738776110493, 'technical', 'technical')
# (22, 33, 0.60639545109866588, 'technical', 'technical')
# (22, 34, 0.60639545109866588, 'technical', 'technical')
# (23, 12, 0.64356224519169447, 'technical', 'technical')
# (23, 20, 0.60972772980964907, 'technical', 'technical')
# (23, 25, 1.0000000000000004, 'technical', 'technical')
# (24, 19, 0.6143571708482467, 'technical', 'technical')
# (24, 30, 0.99999999999999933, 'technical', 'technical')
# (25, 12, 0.64356224519169447, 'technical', 'technical')
# (25, 20, 0.60972772980964907, 'technical', 'technical')
# (25, 23, 1.0000000000000004, 'technical', 'technical')
# (27, 11, 0.68952692441117802, 'technical', 'technical')
# (27, 12, 0.67531514179486785, 'technical', 'technical')
# (27, 17, 0.64292785451155487, 'technical', 'technical')
# (27, 19, 0.71080969878644118, 'technical', 'technical')
# (27, 20, 0.66754088049738547, 'technical', 'technical')
# (27, 22, 0.61870195504664649, 'technical', 'technical')
# (27, 29, 0.60014844572028403, 'technical', 'technical')
# (27, 32, 0.60668054221718404, 'technical', 'technical')
# (28, 11, 0.65955091539755206, 'technical', 'technical')
# (28, 12, 0.6962944442954957, 'technical', 'technical')
# (28, 17, 0.60402462413297864, 'technical', 'technical')
# (28, 19, 0.61608101113167468, 'technical', 'technical')
# (28, 20, 0.68262949056104216, 'technical', 'technical')
# (28, 22, 0.65926879362059621, 'technical', 'technical')
# (28, 31, 1.0000000000000004, 'technical', 'technical')
# (29, 11, 0.63255126675878082, 'technical', 'technical')
# (29, 12, 0.60358016388597213, 'technical', 'technical')
# (29, 17, 0.6149271705126278, 'technical', 'technical')
# (29, 19, 0.65947929592232335, 'technical', 'technical')
# (29, 27, 0.60014844572028403, 'technical', 'technical')
# (30, 19, 0.6143571708482467, 'technical', 'technical')
# (30, 24, 0.99999999999999933, 'technical', 'technical')
# (31, 11, 0.65955091539755206, 'technical', 'technical')
# (31, 12, 0.6962944442954957, 'technical', 'technical')
# (31, 17, 0.60402462413297864, 'technical', 'technical')
# (31, 19, 0.61608101113167468, 'technical', 'technical')
# (31, 20, 0.68262949056104216, 'technical', 'technical')
# (31, 22, 0.65926879362059621, 'technical', 'technical')
# (31, 28, 1.0000000000000004, 'technical', 'technical')
# (32, 11, 0.67179136658185723, 'technical', 'technical')
# (32, 12, 0.66731707913516525, 'technical', 'technical')
# (32, 17, 0.63281104116235209, 'technical', 'technical')
# (32, 19, 0.67205336544053906, 'technical', 'technical')
# (32, 20, 0.63049365048033201, 'technical', 'technical')
# (32, 22, 0.74706738776110493, 'technical', 'technical')
# (32, 27, 0.60668054221718404, 'technical', 'technical')
# (33, 11, 0.6372244652523027, 'technical', 'technical')
# (33, 19, 0.67163774579625946, 'technical', 'technical')
# (33, 21, 0.60416915108506863, 'technical', 'technical')
# (33, 22, 0.60639545109866588, 'technical', 'technical')
# (33, 34, 0.99999999999999944, 'technical', 'technical')
# (34, 11, 0.6372244652523027, 'technical', 'technical')
# (34, 19, 0.67163774579625946, 'technical', 'technical')
# (34, 21, 0.60416915108506863, 'technical', 'technical')
# (34, 22, 0.60639545109866588, 'technical', 'technical')
# (34, 33, 0.99999999999999944, 'technical', 'technical')
# (49, 52, 1.0000000000000002, 'medicine', 'medicine')
# (52, 49, 1.0000000000000002, 'medicine', 'medicine')
# (55, 64, 1.0, 'mobile', 'mobile')
# (56, 65, 0.67844051543087658, 'mobile', 'mobile')
# (64, 55, 1.0, 'mobile', 'mobile')
# (65, 56, 0.67844051543087658, 'mobile', 'mobile')
# (68, 72, 1.0000000000000002, 'mobile', 'mobile')
# (69, 70, 0.63348846368764156, 'mobile', 'mobile')
# (69, 76, 0.64970436130454057, 'mobile', 'mobile')
# (69, 78, 0.80256032960018697, 'mobile', 'mobile')
# (70, 69, 0.63348846368764156, 'mobile', 'mobile')
# (70, 78, 0.7121003286644515, 'mobile', 'mobile')
# (72, 68, 1.0000000000000002, 'mobile', 'mobile')
# (76, 69, 0.64970436130454057, 'mobile', 'mobile')
# (76, 77, 0.61528827415096066, 'mobile', 'mobile')
# (76, 78, 0.66320149060723321, 'mobile', 'mobile')
# (77, 76, 0.61528827415096066, 'mobile', 'mobile')
# (77, 78, 0.64524755898511177, 'mobile', 'mobile')
# (78, 69, 0.80256032960018697, 'mobile', 'mobile')
# (78, 70, 0.7121003286644515, 'mobile', 'mobile')
# (78, 76, 0.66320149060723321, 'mobile', 'mobile')
# (78, 77, 0.64524755898511177, 'mobile', 'mobile')
# (80, 87, 0.81891183294916736, 'lcd', 'lcd')
# (87, 80, 0.81891183294916736, 'lcd', 'lcd')
# (93, 94, 0.85343612605642016, 'hippa', 'hippa')
# (93, 96, 0.94532562856532509, 'hippa', 'hippa')
# (93, 97, 0.77797565357366749, 'hippa', 'hippa')
# (93, 98, 0.99983584859881369, 'hippa', 'hippa')
# (93, 99, 0.86312287860575643, 'hippa', 'hippa')
# (93, 100, 0.92949043278899923, 'hippa', 'hippa')
# (93, 101, 0.92298563949191914, 'hippa', 'hippa')
# (93, 102, 0.92175570197501655, 'hippa', 'hippa')
# (93, 103, 0.92298563949191914, 'hippa', 'hippa')
# (93, 104, 0.92824879095550283, 'hippa', 'hippa')
# (93, 105, 0.88039960061078737, 'hippa', 'hippa')
# (93, 106, 0.96003417073510899, 'hippa', 'hippa')
# (93, 107, 0.87731090714848647, 'hippa', 'hippa')
# (93, 108, 0.96326883740874381, 'hippa', 'hippa')
# (93, 109, 0.94532562856532509, 'hippa', 'hippa')
# (94, 93, 0.85343612605642016, 'hippa', 'hippa')
# (94, 96, 0.84923228046528243, 'hippa', 'hippa')
# (94, 97, 0.69889360709866644, 'hippa', 'hippa')
# (94, 98, 0.85093727655966389, 'hippa', 'hippa')
# (94, 99, 0.99971752118935497, 'hippa', 'hippa')
# (94, 100, 0.88412599489428434, 'hippa', 'hippa')
# (94, 101, 0.82916317486495006, 'hippa', 'hippa')
# (94, 102, 0.82805826179505471, 'hippa', 'hippa')
# (94, 103, 0.82916317486495006, 'hippa', 'hippa')
# (94, 104, 0.88371745635082499, 'hippa', 'hippa')
# (94, 105, 0.83853302226883242, 'hippa', 'hippa')
# (94, 106, 0.78279625251637996, 'hippa', 'hippa')
# (94, 107, 0.78813132728188806, 'hippa', 'hippa')
# (94, 108, 0.86868875588012828, 'hippa', 'hippa')
# (94, 109, 0.84923228046528243, 'hippa', 'hippa')
# (96, 93, 0.94532562856532509, 'hippa', 'hippa')
# (96, 94, 0.84923228046528243, 'hippa', 'hippa')
# (96, 97, 0.82297108008630149, 'hippa', 'hippa')
# (96, 98, 0.9392615399961356, 'hippa', 'hippa')
# (96, 99, 0.86154191221301435, 'hippa', 'hippa')
# (96, 100, 0.93167184360897615, 'hippa', 'hippa')
# (96, 101, 0.9763679430681359, 'hippa', 'hippa')
# (96, 102, 0.97506687021055438, 'hippa', 'hippa')
# (96, 103, 0.9763679430681359, 'hippa', 'hippa')
# (96, 104, 0.92961612862121568, 'hippa', 'hippa')
# (96, 105, 0.93131887468969521, 'hippa', 'hippa')
# (96, 106, 0.9217693092018322, 'hippa', 'hippa')
# (96, 107, 0.92805154185858552, 'hippa', 'hippa')
# (96, 108, 0.92629449313777934, 'hippa', 'hippa')
# (96, 109, 1.0, 'hippa', 'hippa')
# (97, 93, 0.77797565357366749, 'hippa', 'hippa')
# (97, 94, 0.69889360709866644, 'hippa', 'hippa')
# (97, 96, 0.82297108008630149, 'hippa', 'hippa')
# (97, 98, 0.77298508405414257, 'hippa', 'hippa')
# (97, 99, 0.70902407803356193, 'hippa', 'hippa')
# (97, 100, 0.76673898342087488, 'hippa', 'hippa')
# (97, 101, 0.8035225806684243, 'hippa', 'hippa')
# (97, 102, 0.80245183533354947, 'hippa', 'hippa')
# (97, 103, 0.8035225806684243, 'hippa', 'hippa')
# (97, 104, 0.76504718943704808, 'hippa', 'hippa')
# (97, 105, 0.83981309164863638, 'hippa', 'hippa')
# (97, 106, 0.75858948398423587, 'hippa', 'hippa')
# (97, 107, 0.76375957977911757, 'hippa', 'hippa')
# (97, 108, 0.76231357949559142, 'hippa', 'hippa')
# (97, 109, 0.82297108008630149, 'hippa', 'hippa')
# (98, 93, 0.99983584859881369, 'hippa', 'hippa')
# (98, 94, 0.85093727655966389, 'hippa', 'hippa')
# (98, 96, 0.9392615399961356, 'hippa', 'hippa')
# (98, 97, 0.77298508405414257, 'hippa', 'hippa')
# (98, 99, 0.86044729874926684, 'hippa', 'hippa')
# (98, 100, 0.92639334481176039, 'hippa', 'hippa')
# (98, 101, 0.91706485780903657, 'hippa', 'hippa')
# (98, 102, 0.91584281011317736, 'hippa', 'hippa')
# (98, 103, 0.91706485780903657, 'hippa', 'hippa')
# (98, 104, 0.92520090496818708, 'hippa', 'hippa')
# (98, 105, 0.8747520004685112, 'hippa', 'hippa')
# (98, 106, 0.95908632801398319, 'hippa', 'hippa')
# (98, 107, 0.87168312040188312, 'hippa', 'hippa')
# (98, 108, 0.96223894238561314, 'hippa', 'hippa')
# (98, 109, 0.9392615399961356, 'hippa', 'hippa')
# (99, 93, 0.86312287860575643, 'hippa', 'hippa')
# (99, 94, 0.99971752118935497, 'hippa', 'hippa')
# (99, 96, 0.86154191221301435, 'hippa', 'hippa')
# (99, 97, 0.70902407803356193, 'hippa', 'hippa')
# (99, 98, 0.86044729874926684, 'hippa', 'hippa')
# (99, 100, 0.89201635801582013, 'hippa', 'hippa')
# (99, 101, 0.84118190469440934, 'hippa', 'hippa')
# (99, 102, 0.8400609758967601, 'hippa', 'hippa')
# (99, 103, 0.84118190469440934, 'hippa', 'hippa')
# (99, 104, 0.89153101985190186, 'hippa', 'hippa')
# (99, 105, 0.84816319348949754, 'hippa', 'hippa')
# (99, 106, 0.79414289326901577, 'hippa', 'hippa')
# (99, 107, 0.79955530000508213, 'hippa', 'hippa')
# (99, 108, 0.8769315320178146, 'hippa', 'hippa')
# (99, 109, 0.86154191221301435, 'hippa', 'hippa')
# (100, 93, 0.92949043278899923, 'hippa', 'hippa')
# (100, 94, 0.88412599489428434, 'hippa', 'hippa')
# (100, 96, 0.93167184360897615, 'hippa', 'hippa')
# (100, 97, 0.76673898342087488, 'hippa', 'hippa')
# (100, 98, 0.92639334481176039, 'hippa', 'hippa')
# (100, 99, 0.89201635801582013, 'hippa', 'hippa')
# (100, 101, 0.90965452155899407, 'hippa', 'hippa')
# (100, 102, 0.90844234861110151, 'hippa', 'hippa')
# (100, 103, 0.90965452155899407, 'hippa', 'hippa')
# (100, 104, 0.99998421910416913, 'hippa', 'hippa')
# (100, 105, 0.913544181624657, 'hippa', 'hippa')
# (100, 106, 0.85878651168624343, 'hippa', 'hippa')
# (100, 107, 0.86463949096754122, 'hippa', 'hippa')
# (100, 108, 0.94200906170638932, 'hippa', 'hippa')
# (100, 109, 0.93167184360897615, 'hippa', 'hippa')
# (101, 93, 0.92298563949191914, 'hippa', 'hippa')
# (101, 94, 0.82916317486495006, 'hippa', 'hippa')
# (101, 96, 0.9763679430681359, 'hippa', 'hippa')
# (101, 97, 0.8035225806684243, 'hippa', 'hippa')
# (101, 98, 0.91706485780903657, 'hippa', 'hippa')
# (101, 99, 0.84118190469440934, 'hippa', 'hippa')
# (101, 100, 0.90965452155899407, 'hippa', 'hippa')
# (101, 102, 0.99998235468617036, 'hippa', 'hippa')
# (101, 103, 1.0, 'hippa', 'hippa')
# (101, 104, 0.90764738734486006, 'hippa', 'hippa')
# (101, 105, 0.95348657140591586, 'hippa', 'hippa')
# (101, 106, 0.89998600440872945, 'hippa', 'hippa')
# (101, 107, 0.90611977498567919, 'hippa', 'hippa')
# (101, 108, 0.90440424894027516, 'hippa', 'hippa')
# (101, 109, 0.9763679430681359, 'hippa', 'hippa')
# (102, 93, 0.92175570197501655, 'hippa', 'hippa')
# (102, 94, 0.82805826179505471, 'hippa', 'hippa')
# (102, 96, 0.97506687021055438, 'hippa', 'hippa')
# (102, 97, 0.80245183533354947, 'hippa', 'hippa')
# (102, 98, 0.91584281011317736, 'hippa', 'hippa')
# (102, 99, 0.8400609758967601, 'hippa', 'hippa')
# (102, 100, 0.90844234861110151, 'hippa', 'hippa')
# (102, 101, 0.99998235468617036, 'hippa', 'hippa')
# (102, 103, 0.99998235468617036, 'hippa', 'hippa')
# (102, 104, 0.90643788903194089, 'hippa', 'hippa')
# (102, 105, 0.95345970953250214, 'hippa', 'hippa')
# (102, 106, 0.89878671537957533, 'hippa', 'hippa')
# (102, 107, 0.90491231231413027, 'hippa', 'hippa')
# (102, 108, 0.90319907231712637, 'hippa', 'hippa')
# (102, 109, 0.97506687021055438, 'hippa', 'hippa')
# (103, 93, 0.92298563949191914, 'hippa', 'hippa')
# (103, 94, 0.82916317486495006, 'hippa', 'hippa')
# (103, 96, 0.9763679430681359, 'hippa', 'hippa')
# (103, 97, 0.8035225806684243, 'hippa', 'hippa')
# (103, 98, 0.91706485780903657, 'hippa', 'hippa')
# (103, 99, 0.84118190469440934, 'hippa', 'hippa')
# (103, 100, 0.90965452155899407, 'hippa', 'hippa')
# (103, 101, 1.0, 'hippa', 'hippa')
# (103, 102, 0.99998235468617036, 'hippa', 'hippa')
# (103, 104, 0.90764738734486006, 'hippa', 'hippa')
# (103, 105, 0.95348657140591586, 'hippa', 'hippa')
# (103, 106, 0.89998600440872945, 'hippa', 'hippa')
# (103, 107, 0.90611977498567919, 'hippa', 'hippa')
# (103, 108, 0.90440424894027516, 'hippa', 'hippa')
# (103, 109, 0.9763679430681359, 'hippa', 'hippa')
# (104, 93, 0.92824879095550283, 'hippa', 'hippa')
# (104, 94, 0.88371745635082499, 'hippa', 'hippa')
# (104, 96, 0.92961612862121568, 'hippa', 'hippa')
# (104, 97, 0.76504718943704808, 'hippa', 'hippa')
# (104, 98, 0.92520090496818708, 'hippa', 'hippa')
# (104, 99, 0.89153101985190186, 'hippa', 'hippa')
# (104, 100, 0.99998421910416913, 'hippa', 'hippa')
# (104, 101, 0.90764738734486006, 'hippa', 'hippa')
# (104, 102, 0.90643788903194089, 'hippa', 'hippa')
# (104, 103, 0.90764738734486006, 'hippa', 'hippa')
# (104, 105, 0.912289648564654, 'hippa', 'hippa')
# (104, 106, 0.8568916167020596, 'hippa', 'hippa')
# (104, 107, 0.8627316815035283, 'hippa', 'hippa')
# (104, 108, 0.9412418702406925, 'hippa', 'hippa')
# (104, 109, 0.92961612862121568, 'hippa', 'hippa')
# (105, 93, 0.88039960061078737, 'hippa', 'hippa')
# (105, 94, 0.83853302226883242, 'hippa', 'hippa')
# (105, 96, 0.93131887468969521, 'hippa', 'hippa')
# (105, 97, 0.83981309164863638, 'hippa', 'hippa')
# (105, 98, 0.8747520004685112, 'hippa', 'hippa')
# (105, 99, 0.84816319348949754, 'hippa', 'hippa')
# (105, 100, 0.913544181624657, 'hippa', 'hippa')
# (105, 101, 0.95348657140591586, 'hippa', 'hippa')
# (105, 102, 0.95345970953250214, 'hippa', 'hippa')
# (105, 103, 0.95348657140591586, 'hippa', 'hippa')
# (105, 104, 0.912289648564654, 'hippa', 'hippa')
# (105, 106, 0.85846115576934812, 'hippa', 'hippa')
# (105, 107, 0.86431191761777448, 'hippa', 'hippa')
# (105, 108, 0.86267554498033827, 'hippa', 'hippa')
# (105, 109, 0.93131887468969521, 'hippa', 'hippa')
# (106, 93, 0.96003417073510899, 'hippa', 'hippa')
# (106, 94, 0.78279625251637996, 'hippa', 'hippa')
# (106, 96, 0.9217693092018322, 'hippa', 'hippa')
# (106, 97, 0.75858948398423587, 'hippa', 'hippa')
# (106, 98, 0.95908632801398319, 'hippa', 'hippa')
# (106, 99, 0.79414289326901577, 'hippa', 'hippa')
# (106, 100, 0.85878651168624343, 'hippa', 'hippa')
# (106, 101, 0.89998600440872945, 'hippa', 'hippa')
# (106, 102, 0.89878671537957533, 'hippa', 'hippa')
# (106, 103, 0.89998600440872945, 'hippa', 'hippa')
# (106, 104, 0.8568916167020596, 'hippa', 'hippa')
# (106, 105, 0.85846115576934812, 'hippa', 'hippa')
# (106, 107, 0.85544942864268358, 'hippa', 'hippa')
# (106, 108, 0.85382983505707211, 'hippa', 'hippa')
# (106, 109, 0.9217693092018322, 'hippa', 'hippa')
# (107, 93, 0.87731090714848647, 'hippa', 'hippa')
# (107, 94, 0.78813132728188806, 'hippa', 'hippa')
# (107, 96, 0.92805154185858552, 'hippa', 'hippa')
# (107, 97, 0.76375957977911757, 'hippa', 'hippa')
# (107, 98, 0.87168312040188312, 'hippa', 'hippa')
# (107, 99, 0.79955530000508213, 'hippa', 'hippa')
# (107, 100, 0.86463949096754122, 'hippa', 'hippa')
# (107, 101, 0.90611977498567919, 'hippa', 'hippa')
# (107, 102, 0.90491231231413027, 'hippa', 'hippa')
# (107, 103, 0.90611977498567919, 'hippa', 'hippa')
# (107, 104, 0.8627316815035283, 'hippa', 'hippa')
# (107, 105, 0.86431191761777448, 'hippa', 'hippa')
# (107, 106, 0.85544942864268358, 'hippa', 'hippa')
# (107, 108, 0.85964903257163305, 'hippa', 'hippa')
# (107, 109, 0.92805154185858552, 'hippa', 'hippa')
# (108, 93, 0.96326883740874381, 'hippa', 'hippa')
# (108, 94, 0.86868875588012828, 'hippa', 'hippa')
# (108, 96, 0.92629449313777934, 'hippa', 'hippa')
# (108, 97, 0.76231357949559142, 'hippa', 'hippa')
# (108, 98, 0.96223894238561314, 'hippa', 'hippa')
# (108, 99, 0.8769315320178146, 'hippa', 'hippa')
# (108, 100, 0.94200906170638932, 'hippa', 'hippa')
# (108, 101, 0.90440424894027516, 'hippa', 'hippa')
# (108, 102, 0.90319907231712637, 'hippa', 'hippa')
# (108, 103, 0.90440424894027516, 'hippa', 'hippa')
# (108, 104, 0.9412418702406925, 'hippa', 'hippa')
# (108, 105, 0.86267554498033827, 'hippa', 'hippa')
# (108, 106, 0.85382983505707211, 'hippa', 'hippa')
# (108, 107, 0.85964903257163305, 'hippa', 'hippa')
# (108, 109, 0.92629449313777934, 'hippa', 'hippa')
# (109, 93, 0.94532562856532509, 'hippa', 'hippa')
# (109, 94, 0.84923228046528243, 'hippa', 'hippa')
# (109, 96, 1.0, 'hippa', 'hippa')
# (109, 97, 0.82297108008630149, 'hippa', 'hippa')
# (109, 98, 0.9392615399961356, 'hippa', 'hippa')
# (109, 99, 0.86154191221301435, 'hippa', 'hippa')
# (109, 100, 0.93167184360897615, 'hippa', 'hippa')
# (109, 101, 0.9763679430681359, 'hippa', 'hippa')
# (109, 102, 0.97506687021055438, 'hippa', 'hippa')
# (109, 103, 0.9763679430681359, 'hippa', 'hippa')
# (109, 104, 0.92961612862121568, 'hippa', 'hippa')
# (109, 105, 0.93131887468969521, 'hippa', 'hippa')
# (109, 106, 0.9217693092018322, 'hippa', 'hippa')
# (109, 107, 0.92805154185858552, 'hippa', 'hippa')
# (109, 108, 0.92629449313777934, 'hippa', 'hippa')

# %%
test_vector_features = vectorizer.transform(test.text)

# %%
test_similarity = cosine_similarity(test_vector_features, train_data_features)

# %%
test_similarity.shape
# Out:
# (30, 116)

# %%
max(test_similarity[0])
# Out:
# 0.28160892067130783

# %%
for row in range(len(test_similarity)):
    print(test.tag[row], test_similarity[row][test_similarity[row].argmax()], data.tag[test_similarity[row].argmax()])
# Out:
# ('medicine', 0.28160892067130783, 'lcd')
# ('medicine', 0.3264902881038278, 'medicine')
# ('medicine', 0.3279560874334661, 'medicine')
# ('medicine', 0.2243675586581832, 'mobile')
# ('medicine', 0.29840640894894116, 'medicine')
# ('medicine', 0.99737932985280975, 'medicine')
# ('mobile', 0.52420535792838574, 'mobile')
# ('mobile', 0.33918958986805348, 'mobile')
# ('mobile', 0.47303192314922526, 'mobile')
# ('mobile', 0.35181005699549156, 'technical')
# ('mobile', 0.5855545552280903, 'mobile')
# ('mobile', 0.50325686923745672, 'mobile')
# ('mobile', 0.24394214011619797, 'mobile')
# ('mobile', 0.20744370493104908, 'mobile')
# ('lcd', 0.35888398229643048, 'lcd')
# ('lcd', 0.42959703353783679, 'lcd')
# ('lcd', 0.29827008927396043, 'mobile')
# ('lcd', 0.48200513596024336, 'lcd')
# ('technical', 0.36524896774816068, 'technical')
# ('hippa', 1.0000000000000002, 'hippa')
# ('hippa', 1.0, 'hippa')
# ('hippa', 1.0, 'hippa')
# ('hippa', 1.0, 'hippa')
# ('hippa', 1.0000000000000002, 'hippa')
# ('mobile', 0.23346183469117593, 'medicine')
# ('mobile', 0.25382257210582559, 'medicine')
# ('mobile', 0.30301743673441128, 'medicine')
# ('srs', 0.25490875829434428, 'srs')
# ('srs', 0.23275054651078331, 'mobile')
# ('srs', 0.48980870051889508, 'srs')

# %%
test.new_text[26]
# Out:
# [u'mobile',
#  u'unit',
#  u'locating',
#  u'system',
#  u'description',
#  u'june',
#  u'30',
#  u'1970',
#  u'filed',
#  u'feb',
#  u'13',
#  u'1969',
#  u'moorehead',
#  u'etal',
#  u'mobile',
#  u'unit',
#  u'locating',
#  u'system',
#  u'2',
#  u'sheets',
#  u'sheet',
#  u'1',
#  u'23',
#  u'w',
#  u'second',
#  u'l5',
#  u'unit',
#  u'1',
#  u'thir',
#  u'receiving',
#  u'receiving',
#  u'station',
#  u'1',
#  u'station',
#  u'5',
#  u'retransmitter',
#  u'53',
#  u'j',
#  u'rei',
#  u'ransmi',
#  u'iter',
#  u'l',
#  u'recfehirsitng',
#  u'station',
#  u'auxiliary',
#  u'20',
#  u'receiver',
#  u'3617',
#  u'reset',
#  u'36',
#  u'360',
#  u'36',
#  u'u',
#  u'programmer',
#  u'380a',
#  u'digital',
#  u'l',
#  u'inter',
#  u'face',
#  u'3',
#  u'computer',
#  u'x',
#  u'8',
#  u'32',
#  u'34',
#  u'l',
#  u'g',
#  u'display',
#  u'inventors',
#  u'dan',
#  u'w',
#  u'patterson',
#  u'donovan',
#  u'lmoorehead',
#  u'attorneys',
#  u'june',
#  u'30',
#  u'1970',
#  u'l',
#  u'moorehead',
#  u'et',
#  u'al',
#  u'3',
#  u'518',
#  u'674',
#  u'mobile',
#  u'unit',
#  u'locating',
#  u'system',
#  u'filed',
#  u'feb',
#  u'15',
#  u'1969',
#  u'2',
#  u'sheets',
#  u'sheet',
#  u'2',
#  u'counter',
#  u'fig',
#  u'2',
#  u'inventors',
#  u'dan',
#  u'w',
#  u'pattersqn',
#  u'donovan',
#  u'l',
#  u'oorehead',
#  u'att',
#  u'orne',
#  u'ys',
#  u'united',
#  u'states',
#  u'patent',
#  u'6',
#  u'3',
#  u'518',
#  u'674',
#  u'mobile',
#  u'unit',
#  u'locating',
#  u'system',
#  u'donovan',
#  u'l',
#  u'moorehead',
#  u'reno',
#  u'nev',
#  u'dan',
#  u'w',
#  u'patterson',
#  u'red',
#  u'bank',
#  u'n',
#  u'j',
#  u'assiguors',
#  u'urban',
#  u'scientific',
#  u'corp',
#  u'corporation',
#  u'new',
#  u'york',
#  u'filed',
#  u'feb',
#  u'13',
#  u'1969',
#  u'ser',
#  u'798',
#  u'968',
#  u'int',
#  u'cl',
#  u'g01s',
#  u'5',
#  u'06',
#  u'us',
#  u'cl',
#  u'343112',
#  u'claims',
#  u'abstract',
#  u'disclosure',
#  u'system',
#  u'locating',
#  u'mobile',
#  u'units',
#  u'surveillance',
#  u'area',
#  u'mobile',
#  u'unit',
#  u'periodically',
#  u'transmits',
#  u'pulse',
#  u'signal',
#  u'plural',
#  u'receivers',
#  u'mutually',
#  u'spaced',
#  u'known',
#  u'locations',
#  u'receive',
#  u'pulse',
#  u'signals',
#  u'relay',
#  u'pulses',
#  u'based',
#  u'thereon',
#  u'computer',
#  u'means',
#  u'either',
#  u'wire',
#  u'radio',
#  u'paths',
#  u'different',
#  u'delays',
#  u'known',
#  u'magnitudes',
#  u'introduced',
#  u'relay',
#  u'paths',
#  u'stagger',
#  u'reception',
#  u'pulses',
#  u'computer',
#  u'means',
#  u'way',
#  u'pulses',
#  u'arriving',
#  u'difierent',
#  u'receivers',
#  u'always',
#  u'arrive',
#  u'prescribed',
#  u'sequence',
#  u'never',
#  u'overlap',
#  u'computer',
#  u'means',
#  u'thus',
#  u'identifying',
#  u'various',
#  u'receivers',
#  u'including',
#  u'means',
#  u'compensating',
#  u'known',
#  u'delays',
#  u'computing',
#  u'mobile',
#  u'unit',
#  u'location',
#  u'hyperbolic',
#  u'techniques',
#  u'system',
#  u'includes',
#  u'special',
#  u'interface',
#  u'circuitry',
#  u'accomplishing',
#  u'functions',
#  u'disclosure',
#  u'invention',
#  u'relates',
#  u'improved',
#  u'system',
#  u'10',
#  u'cating',
#  u'mobile',
#  u'units',
#  u'within',
#  u'surveillance',
#  u'area',
#  u'receiving',
#  u'periodic',
#  u'pulse',
#  u'signal',
#  u'transmissions',
#  u'plural',
#  u'receiving',
#  u'stations',
#  u'using',
#  u'computer',
#  u'solve',
#  u'hyperbolic',
#  u'relationships',
#  u'based',
#  u'upon',
#  u'known',
#  u'locations',
#  u'receiving',
#  u'stations',
#  u'upon',
#  u'times',
#  u'arrival',
#  u'said',
#  u'mobile',
#  u'unit',
#  u'signals',
#  u'thereat',
#  u'particularly',
#  u'relates',
#  u'novel',
#  u'means',
#  u'introducing',
#  u'unique',
#  u'time',
#  u'delays',
#  u'assist',
#  u'computer',
#  u'recognizing',
#  u'various',
#  u'receiving',
#  u'stations',
#  u'sending',
#  u'pulses',
#  u'computer',
#  u'sequence',
#  u'pulses',
#  u'arrive',
#  u'regardless',
#  u'position',
#  u'mobile',
#  u'transmitting',
#  u'unit',
#  u'within',
#  u'surveillance',
#  u'area',
#  u'system',
#  u'including',
#  u'improved',
#  u'means',
#  u'processing',
#  u'signals',
#  u'interface',
#  u'means',
#  u'interposed',
#  u'receiving',
#  u'stations',
#  u'computer',
#  u'number',
#  u'prior',
#  u'art',
#  u'systems',
#  u'using',
#  u'relative',
#  u'times',
#  u'arrival',
#  u'signals',
#  u'fixed',
#  u'receiving',
#  u'stations',
#  u'locate',
#  u'vehicles',
#  u'vicinity',
#  u'solving',
#  u'hyperbolic',
#  u'relationships',
#  u'typical',
#  u'one',
#  u'shown',
#  u'bissett',
#  u'2',
#  u'940',
#  u'076',
#  u'travel',
#  u'times',
#  u'received',
#  u'signals',
#  u'computer',
#  u'made',
#  u'equal',
#  u'placing',
#  u'computer',
#  u'equal',
#  u'distance',
#  u'stations',
#  u'feeding',
#  u'signals',
#  u'computer',
#  u'along',
#  u'separate',
#  u'relay',
#  u'paths',
#  u'pat',
#  u'3',
#  u'047',
#  u'861',
#  u'arnold',
#  u'goes',
#  u'step',
#  u'teaching',
#  u'receiving',
#  u'stations',
#  u'located',
#  u'different',
#  u'distances',
#  u'computer',
#  u'joined',
#  u'thereto',
#  u'separate',
#  u'relay',
#  u'paths',
#  u'delay',
#  u'lines',
#  u'introduced',
#  u'paths',
#  u'insert',
#  u'complementary',
#  u'time',
#  u'delays',
#  u'compensate',
#  u'inequalities',
#  u'distances',
#  u'various',
#  u'receiving',
#  u'stations',
#  u'computer',
#  u'site',
#  u'thereby',
#  u'making',
#  u'apparent',
#  u'path',
#  u'lengths',
#  u'equal',
#  u'time',
#  u'variations',
#  u'result',
#  u'differences',
#  u'range',
#  u'mobile',
#  u'unit',
#  u'respective',
#  u'receiver',
#  u'stations',
#  u'patents',
#  u'signals',
#  u'arrive',
#  u'computer',
#  u'receivers',
#  u'along',
#  u'separate',
#  u'paths',
#  u'receiver',
#  u'signal',
#  u'received',
#  u'clearly',
#  u'identified',
#  u'path',
#  u'along',
#  u'output',
#  u'relayed',
#  u'computer',
#  u'way',
#  u'identifying',
#  u'receiver',
#  u'relaying',
#  u'signal',
#  u'operational',
#  u'receivers',
#  u'joined',
#  u'computer',
#  u'separate',
#  u'wires',
#  u'radio',
#  u'relay',
#  u'links',
#  u'using',
#  u'dilferent',
#  u'frequencies',
#  u'major',
#  u'object',
#  u'invention',
#  u'provide',
#  u'sysp',
#  u'3',
#  u'5',
#  u'18',
#  u'6',
#  u'74',
#  u'l',
#  u'patented',
#  u'june',
#  u'30',
#  u'1',
#  u'970',
#  u'tem',
#  u'multiple',
#  u'receivers',
#  u'linked',
#  u'supply',
#  u'timeof',
#  u'arrival',
#  u'data',
#  u'form',
#  u'pulses',
#  u'computer',
#  u'via',
#  u'paths',
#  u'various',
#  u'lengths',
#  u'additional',
#  u'delays',
#  u'selectively',
#  u'introduced',
#  u'various',
#  u'paths',
#  u'order',
#  u'deliberately',
#  u'stagger',
#  u'moments',
#  u'relayed',
#  u'pulses',
#  u'arrive',
#  u'computer',
#  u'regardless',
#  u'location',
#  u'mobile',
#  u'unit',
#  u'within',
#  u'surveillance',
#  u'area',
#  u'various',
#  u'receivers',
#  u'always',
#  u'report',
#  u'computer',
#  u'fixed',
#  u'sequence',
#  u'real',
#  u'time',
#  u'whereby',
#  u'receivers',
#  u'contribution',
#  u'identified',
#  u'position',
#  u'within',
#  u'sequence',
#  u'related',
#  u'signal',
#  u'pulses',
#  u'computer',
#  u'means',
#  u'compensates',
#  u'delays',
#  u'relay',
#  u'paths',
#  u'delays',
#  u'always',
#  u'constant',
#  u'data',
#  u'path',
#  u'thereby',
#  u'obtains',
#  u'relative',
#  u'times',
#  u'arrival',
#  u'position',
#  u'mobile',
#  u'unit',
#  u'obtained',
#  u'illustrative',
#  u'embodiment',
#  u'obtained',
#  u'time',
#  u'arrival',
#  u'data',
#  u'form',
#  u'differences',
#  u'travel',
#  u'time',
#  u'signal',
#  u'mobile',
#  u'unit',
#  u'various',
#  u'receiving',
#  u'stations',
#  u'computation',
#  u'location',
#  u'mobile',
#  u'unit',
#  u'performed',
#  u'manner',
#  u'resembling',
#  u'computing',
#  u'technique',
#  u'used',
#  u'bissett',
#  u'pat',
#  u'2',
#  u'940',
#  u'076',
#  u'described',
#  u'column',
#  u'3',
#  u'et',
#  u'seq',
#  u'delays',
#  u'establish',
#  u'pulse',
#  u'arrival',
#  u'sequences',
#  u'permit',
#  u'single',
#  u'radio',
#  u'frequency',
#  u'used',
#  u'receivers',
#  u'reporting',
#  u'times',
#  u'arrival',
#  u'computer',
#  u'two',
#  u'receivers',
#  u'report',
#  u'time',
#  u'moreover',
#  u'convenient',
#  u'mandatory',
#  u'retransmissions',
#  u'receiving',
#  u'stations',
#  u'com',
#  u'puter',
#  u'means',
#  u'made',
#  u'different',
#  u'frequency',
#  u'mobile',
#  u'unit',
#  u'signal',
#  u'transmissions',
#  u'however',
#  u'retransmissions',
#  u'must',
#  u'made',
#  u'frequency',
#  u'mobile',
#  u'units',
#  u'employ',
#  u'transmissions',
#  u'receivers',
#  u'gated',
#  u'reception',
#  u'vehicles',
#  u'transmission',
#  u'e',
#  u'period',
#  u'long',
#  u'enough',
#  u'prevent',
#  u'receiver',
#  u'station',
#  u'receiving',
#  u'one',
#  u'retransmissions',
#  u'another',
#  u'station',
#  u'technique',
#  u'also',
#  u'useful',
#  u'eliminating',
#  u'multi',
#  u'path',
#  u'signal',
#  u'reception',
#  u'e',
#  u'gating',
#  u'receiver',
#  u'fixed',
#  u'interval',
#  u'reception',
#  u'direct',
#  u'path',
#  u'signal',
#  u'remote',
#  u'unit',
#  u'another',
#  u'major',
#  u'object',
#  u'invention',
#  u'provide',
#  u'novel',
#  u'interface',
#  u'system',
#  u'receiving',
#  u'aforementioned',
#  u'sequence',
#  u'pulses',
#  u'various',
#  u'receivers',
#  u'converting',
#  u'temporarily',
#  u'storing',
#  u'data',
#  u'parallel',
#  u'binary',
#  u'form',
#  u'delivery',
#  u'computer',
#  u'since',
#  u'delays',
#  u'receivers',
#  u'computer',
#  u'means',
#  u'fixed',
#  u'known',
#  u'stored',
#  u'computer',
#  u'means',
#  u'subtracted',
#  u'arrival',
#  u'times',
#  u'pulses',
#  u'said',
#  u'receiver',
#  u'stations',
#  u'order',
#  u'determine',
#  u'relative',
#  u'times',
#  u'arrival',
#  u'pulse',
#  u'signals',
#  u'vehicle',
#  u'various',
#  u'receiving',
#  u'stations',
#  u'alternatively',
#  u'counters',
#  u'interface',
#  u'programmed',
#  u'automatically',
#  u'eliminate',
#  u'known',
#  u'delays',
#  u'storing',
#  u'times',
#  u'arrival',
#  u'thereat',
#  u'another',
#  u'object',
#  u'invention',
#  u'provide',
#  u'multiple',
#  u'receiving',
#  u'station',
#  u'system',
#  u'relaying',
#  u'data',
#  u'cooperative',
#  u'interface',
#  u'computer',
#  u'delay',
#  u'means',
#  u'way',
#  u'eliminate',
#  u'need',
#  u'precision',
#  u'highly',
#  u'stable',
#  u'time',
#  u'clocks',
#  u'anywhere',
#  u'system',
#  u'need',
#  u'synchronization',
#  u'clocks',
#  u'remote',
#  u'receiving',
#  u'stations',
#  u'objects',
#  u'advantages',
#  u'invention',
#  u'become',
#  u'apparent',
#  u'following',
#  u'discussion',
#  u'drawings',
#  u'wherein',
#  u'fig',
#  u'1',
#  u'diagram',
#  u'showing',
#  u'embodiment',
#  u'invention',
#  u'including',
#  u'three',
#  u'receiving',
#  u'stations',
#  u'mobile',
#  u'unit',
#  u'periodically',
#  u'transmitting',
#  u'pulse',
#  u'signals',
#  u'marking',
#  u'position',
#  u'space',
#  u'respect',
#  u'thereto',
#  u'one',
#  u'receiving',
#  u'stations',
#  u'housing',
#  u'computer',
#  u'means',
#  u'fig',
#  u'2',
#  u'block',
#  u'diagram',
#  u'showing',
#  u'novel',
#  u'interface',
#  u'receiving',
#  u'pulse',
#  u'information',
#  u'three',
#  u'stations',
#  u'converting',
#  u'digital',
#  u'data',
#  u'suitable',
#  u'use',
#  u'computer',
#  u'referring',
#  u'drawings',
#  u'fig',
#  u'1',
#  u'shows',
#  u'mobile',
#  u'unit',
#  u'may',
#  u'comprise',
#  u'ship',
#  u'land',
#  u'vehicle',
#  u'aircraft',
#  u'etc',
#  u'mobile',
#  u'unit',
#  u'including',
#  u'periodic',
#  u'transmitter',
#  u'means',
#  u'17',
#  u'transmitting',
#  u'suitable',
#  u'pulse',
#  u'signal',
#  u'spaced',
#  u'intervals',
#  u'pulse',
#  u'signal',
#  u'picked',
#  u'three',
#  u'receiving',
#  u'stations',
#  u'respectively',
#  u'bearing',
#  u'reference',
#  u'characters',
#  u'19',
#  u'21',
#  u'23',
#  u'receiving',
#  u'stations',
#  u'suitable',
#  u'antennas',
#  u'omnidirectional',
#  u'type',
#  u'two',
#  u'receiving',
#  u'stations',
#  u'include',
#  u'means',
#  u'replaying',
#  u'pulses',
#  u'first',
#  u'receiving',
#  u'station',
#  u'19',
#  u'response',
#  u'pulse',
#  u'signals',
#  u'received',
#  u'mobile',
#  u'unit',
#  u'15',
#  u'embodiment',
#  u'illustrated',
#  u'fig',
#  u'1',
#  u'retransmitting',
#  u'means',
#  u'comprise',
#  u'transmitters',
#  u'25',
#  u'27',
#  u'connected',
#  u'antennas',
#  u'used',
#  u'receiving',
#  u'means',
#  u'21',
#  u'23',
#  u'transmitters',
#  u'actuated',
#  u'delay',
#  u'means',
#  u'29',
#  u'31',
#  u'provides',
#  u'different',
#  u'degree',
#  u'delay',
#  u'discussed',
#  u'hereinafter',
#  u'first',
#  u'receiving',
#  u'station',
#  u'19',
#  u'preferably',
#  u'includes',
#  u'auxiliary',
#  u'receiver',
#  u'tuned',
#  u'receive',
#  u'retransmissions',
#  u'two',
#  u'stations',
#  u'retransmitters',
#  u'27',
#  u'preferably',
#  u'operate',
#  u'different',
#  u'frequency',
#  u'transmitter',
#  u'mobile',
#  u'unit',
#  u'15',
#  u'although',
#  u'workable',
#  u'embodiments',
#  u'telephone',
#  u'lines',
#  u'could',
#  u'used',
#  u'transmitters',
#  u'could',
#  u'used',
#  u'employing',
#  u'frequency',
#  u'mobile',
#  u'unit',
#  u'15',
#  u'use',
#  u'dilferent',
#  u'retransmitting',
#  u'frequency',
#  u'helpful',
#  u'since',
#  u'avoids',
#  u'likelihood',
#  u'one',
#  u'receiving',
#  u'station',
#  u'pick',
#  u'retransmission',
#  u'another',
#  u'receiving',
#  u'station',
#  u'mistake',
#  u'transmission',
#  u'mobile',
#  u'unit',
#  u'another',
#  u'way',
#  u'avoiding',
#  u'difiiculty',
#  u'use',
#  u'coded',
#  u'pulse',
#  u'groups',
#  u'mobile',
#  u'unit',
#  u'signals',
#  u'distinctive',
#  u'instance',
#  u'comprising',
#  u'certain',
#  u'number',
#  u'pulses',
#  u'characteristic',
#  u'spacings',
#  u'uniquely',
#  u'identify',
#  u'mobile',
#  u'unit',
#  u'transmissions',
#  u'moreover',
#  u'retransmitters',
#  u'various',
#  u'receiving',
#  u'stations',
#  u'could',
#  u'use',
#  u'different',
#  u'pulse',
#  u'coded',
#  u'groups',
#  u'identify',
#  u'specific',
#  u'character',
#  u'purpose',
#  u'system',
#  u'shown',
#  u'fig',
#  u'1',
#  u'also',
#  u'comprises',
#  u'computer',
#  u'means',
#  u'including',
#  u'computer',
#  ...]

# %%
ans = pd.DataFrame({
    'tag':data.tag[test_similarity[0].argsort()[-3:][::-1]] , 
    'cosine':  test_similarity[0][test_similarity[0].argsort()[-3:][::-1]]
})

# %%
data.tag[test_similarity[0].argsort()[-8:][::-1]]
# Out:
# 80         lcd
# 87         lcd
# 58      mobile
# 37    medicine
# 88         lcd
# 53      mobile
# 71      mobile
# 36    medicine
# Name: tag, dtype: object

# %%
ans
# Out:
#       cosine  tag
# 80  0.351810  NaN
# 87  0.344635  NaN
# 58  0.341304  NaN

# %%
test['new_text'] = test.text.apply(review_to_sentences)

# %%
test.new_text[0]
# Out:
# [u'medicine',
#  u'supply',
#  u'apparatus',
#  u'abstract',
#  u'disclosed',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'improve',
#  u'dispensing',
#  u'operation',
#  u'efficiency',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'constituted',
#  u'storing',
#  u'plurality',
#  u'tablet',
#  u'cases',
#  u'main',
#  u'body',
#  u'case',
#  u'storage',
#  u'part',
#  u'tablet',
#  u'case',
#  u'comprising',
#  u'container',
#  u'containing',
#  u'medicine',
#  u'discharge',
#  u'drum',
#  u'discharging',
#  u'medicine',
#  u'container',
#  u'comprises',
#  u'motor',
#  u'driving',
#  u'discharge',
#  u'drum',
#  u'controller',
#  u'controlling',
#  u'operation',
#  u'motor',
#  u'controller',
#  u'comprises',
#  u'means',
#  u'rotating',
#  u'forward',
#  u'motor',
#  u'discharge',
#  u'medicine',
#  u'detecting',
#  u'medicine',
#  u'sticking',
#  u'medicine',
#  u'sticking',
#  u'occurs',
#  u'motor',
#  u'rotated',
#  u'backward',
#  u'rotated',
#  u'forward',
#  u'description',
#  u'technical',
#  u'field',
#  u'present',
#  u'invention',
#  u'relates',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'supplies',
#  u'medicine',
#  u'contained',
#  u'tablet',
#  u'case',
#  u'container',
#  u'phial',
#  u'bag',
#  u'like',
#  u'quantity',
#  u'designated',
#  u'prescription',
#  u'hospital',
#  u'like',
#  u'background',
#  u'art',
#  u'hospitals',
#  u'pharmacies',
#  u'example',
#  u'described',
#  u'japanese',
#  u'utility',
#  u'model',
#  u'publication',
#  u'5282',
#  u'1982',
#  u'b65b1',
#  u'30',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'referred',
#  u'tablet',
#  u'packing',
#  u'machine',
#  u'publication',
#  u'heretofore',
#  u'used',
#  u'dispense',
#  u'medicine',
#  u'prescribed',
#  u'doctor',
#  u'patient',
#  u'system',
#  u'quantity',
#  u'described',
#  u'prescription',
#  u'medicines',
#  u'tablets',
#  u'capsules',
#  u'like',
#  u'discharged',
#  u'discharge',
#  u'drum',
#  u'referred',
#  u'alignment',
#  u'board',
#  u'described',
#  u'publication',
#  u'tablet',
#  u'case',
#  u'one',
#  u'one',
#  u'subsequently',
#  u'collected',
#  u'hopper',
#  u'packed',
#  u'moreover',
#  u'example',
#  u'japanese',
#  u'utility',
#  u'model',
#  u'publication',
#  u'40881',
#  u'1987',
#  u'tablet',
#  u'case',
#  u'tablet',
#  u'container',
#  u'provided',
#  u'tablet',
#  u'detecting',
#  u'sensor',
#  u'detecting',
#  u'discharged',
#  u'tablets',
#  u'display',
#  u'tablet',
#  u'discharged',
#  u'empty',
#  u'tablet',
#  u'case',
#  u'tablets',
#  u'get',
#  u'stuck',
#  u'trouble',
#  u'displayed',
#  u'display',
#  u'operation',
#  u'stopped',
#  u'based',
#  u'sensor',
#  u'detecting',
#  u'operation',
#  u'however',
#  u'conventional',
#  u'art',
#  u'tablets',
#  u'get',
#  u'stuck',
#  u'described',
#  u'trouble',
#  u'display',
#  u'performed',
#  u'stop',
#  u'operation',
#  u'therefore',
#  u'problem',
#  u'arises',
#  u'particularly',
#  u'apparatus',
#  u'supplying',
#  u'various',
#  u'types',
#  u'medicines',
#  u'frequency',
#  u'occurrence',
#  u'tablet',
#  u'sticking',
#  u'increases',
#  u'dispensing',
#  u'operation',
#  u'efficiency',
#  u'remarkably',
#  u'deteriorated',
#  u'present',
#  u'invention',
#  u'developed',
#  u'solve',
#  u'conventional',
#  u'technical',
#  u'problem',
#  u'provides',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'improve',
#  u'efficiency',
#  u'dispensing',
#  u'operation',
#  u'disclosure',
#  u'invention',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'present',
#  u'invention',
#  u'constituted',
#  u'storing',
#  u'plurality',
#  u'tablet',
#  u'cases',
#  u'stored',
#  u'main',
#  u'body',
#  u'case',
#  u'storage',
#  u'part',
#  u'tablet',
#  u'case',
#  u'comprising',
#  u'container',
#  u'containing',
#  u'medicine',
#  u'discharge',
#  u'drum',
#  u'discharging',
#  u'medicine',
#  u'container',
#  u'comprises',
#  u'motor',
#  u'driving',
#  u'discharge',
#  u'drum',
#  u'controller',
#  u'controlling',
#  u'operation',
#  u'motor',
#  u'controller',
#  u'comprises',
#  u'means',
#  u'rotating',
#  u'forward',
#  u'motor',
#  u'discharge',
#  u'medicine',
#  u'detecting',
#  u'medicine',
#  u'sticking',
#  u'medicine',
#  u'sticking',
#  u'occurs',
#  u'motor',
#  u'rotated',
#  u'backward',
#  u'rotated',
#  u'forward',
#  u'moreover',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'present',
#  u'invention',
#  u'described',
#  u'controller',
#  u'characterized',
#  u'operation',
#  u'rotating',
#  u'backward',
#  u'rotating',
#  u'forward',
#  u'motor',
#  u'repeated',
#  u'plurality',
#  u'times',
#  u'furthermore',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'present',
#  u'invention',
#  u'performing',
#  u'operation',
#  u'rotating',
#  u'backward',
#  u'rotating',
#  u'forward',
#  u'motor',
#  u'described',
#  u'controller',
#  u'executes',
#  u'predetermined',
#  u'alarm',
#  u'operation',
#  u'medicine',
#  u'sticking',
#  u'state',
#  u'additionally',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'present',
#  u'invention',
#  u'described',
#  u'controller',
#  u'detects',
#  u'medicine',
#  u'sticking',
#  u'detecting',
#  u'lock',
#  u'state',
#  u'based',
#  u'current',
#  u'supplied',
#  u'motor',
#  u'brief',
#  u'description',
#  u'drawings',
#  u'fig',
#  u'1',
#  u'perspective',
#  u'view',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'present',
#  u'invention',
#  u'one',
#  u'door',
#  u'unit',
#  u'open',
#  u'fig',
#  u'2',
#  u'partially',
#  u'perspective',
#  u'side',
#  u'view',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'door',
#  u'unit',
#  u'open',
#  u'fig',
#  u'3',
#  u'perspective',
#  u'view',
#  u'showing',
#  u'internal',
#  u'structure',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'present',
#  u'invention',
#  u'fig',
#  u'4',
#  u'enlarged',
#  u'longitudinal',
#  u'side',
#  u'view',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'showing',
#  u'shelf',
#  u'part',
#  u'fig',
#  u'5',
#  u'perspective',
#  u'view',
#  u'tablet',
#  u'case',
#  u'fig',
#  u'6',
#  u'exploded',
#  u'perspective',
#  u'view',
#  u'tablet',
#  u'case',
#  u'fig',
#  u'7',
#  u'front',
#  u'view',
#  u'door',
#  u'side',
#  u'case',
#  u'storage',
#  u'part',
#  u'stores',
#  u'large',
#  u'capacity',
#  u'tablet',
#  u'case',
#  u'fig',
#  u'8',
#  u'front',
#  u'view',
#  u'main',
#  u'body',
#  u'side',
#  u'case',
#  u'storage',
#  u'part',
#  u'stores',
#  u'small',
#  u'capacity',
#  u'tablet',
#  u'case',
#  u'fig',
#  u'9',
#  u'diagram',
#  u'showing',
#  u'storage',
#  u'modes',
#  u'large',
#  u'capacity',
#  u'tablet',
#  u'case',
#  u'small',
#  u'capacity',
#  u'tablet',
#  u'case',
#  u'respective',
#  u'case',
#  u'storage',
#  u'parts',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'present',
#  u'invention',
#  u'fig',
#  u'10',
#  u'diagram',
#  u'showing',
#  u'number',
#  u'size',
#  u'proportion',
#  u'tablet',
#  u'cases',
#  u'respective',
#  u'storage',
#  u'modes',
#  u'fig',
#  u'9',
#  u'fig',
#  u'11',
#  u'diagram',
#  u'showing',
#  u'relation',
#  u'number',
#  u'medicine',
#  u'types',
#  u'ratio',
#  u'actual',
#  u'operation',
#  u'covered',
#  u'fig',
#  u'12',
#  u'diagram',
#  u'showing',
#  u'relation',
#  u'number',
#  u'medicine',
#  u'types',
#  u'capacity',
#  u'tablet',
#  u'case',
#  u'fig',
#  u'13',
#  u'block',
#  u'diagram',
#  u'showing',
#  u'electric',
#  u'circuit',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'present',
#  u'invention',
#  u'fig',
#  u'14',
#  u'explanatory',
#  u'view',
#  u'showing',
#  u'another',
#  u'tablet',
#  u'case',
#  u'recognizing',
#  u'operation',
#  u'controller',
#  u'fig',
#  u'15',
#  u'timing',
#  u'chart',
#  u'showing',
#  u'backward',
#  u'forward',
#  u'rotating',
#  u'operation',
#  u'motor',
#  u'controller',
#  u'medicine',
#  u'sticking',
#  u'fig',
#  u'16',
#  u'timing',
#  u'chart',
#  u'showing',
#  u'conventional',
#  u'control',
#  u'operation',
#  u'medicine',
#  u'sticking',
#  u'best',
#  u'mode',
#  u'carrying',
#  u'invention',
#  u'embodiment',
#  u'present',
#  u'invention',
#  u'described',
#  u'hereinafter',
#  u'detail',
#  u'reference',
#  u'drawings',
#  u'fig',
#  u'1',
#  u'perspective',
#  u'view',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'1',
#  u'present',
#  u'invention',
#  u'one',
#  u'door',
#  u'unit',
#  u'2',
#  u'open',
#  u'fig',
#  u'2',
#  u'partially',
#  u'perspective',
#  u'side',
#  u'view',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'1',
#  u'door',
#  u'unit',
#  u'2',
#  u'open',
#  u'fig',
#  u'3',
#  u'perspective',
#  u'view',
#  u'showing',
#  u'internal',
#  u'structure',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'1',
#  u'present',
#  u'invention',
#  u'fig',
#  u'4',
#  u'enlarged',
#  u'longitudinal',
#  u'side',
#  u'view',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'1',
#  u'showing',
#  u'shelf',
#  u'part',
#  u'26',
#  u'fig',
#  u'5',
#  u'perspective',
#  u'view',
#  u'tablet',
#  u'case',
#  u'3',
#  u'fig',
#  u'6',
#  u'exploded',
#  u'perspective',
#  u'view',
#  u'tablet',
#  u'case',
#  u'3',
#  u'large',
#  u'capacity',
#  u'l',
#  u'medicine',
#  u'supply',
#  u'apparatus',
#  u'1',
#  u'present',
#  u'invention',
#  u'installed',
#  u'hospital',
#  u'pharmacy',
#  u'like',
#  u'constituted',
#  u'main',
#  u'body',
#  u'7',
#  u'laterally',
#  u'long',
#  u'rectangular',
#  u'shape',
#  u'main',
#  u'body',
#  u'side',
#  u'case',
#  u'storage',
#  u'part',
#  u'8',
#  u'vertically',
#  u'mounted',
#  u'back',
#  u'part',
#  u'top',
#  u'surface',
#  u'7a',
#  u'main',
#  u'body',
#  u'7',
#  u'door',
#  u'units',
#  u'2',
#  u'2',
#  u'openably',
#  u'close',
#  u'front',
#  u'face',
#  u'opening',
#  u'main',
#  u'body',
#  u'side',
#  u'case',
#  u'storage',
#  u'part',
#  u'8',
#  u'movable',
#  u'double',
#  u'swinging',
#  u'system',
#  u'extension',
#  u'unit',
#  u'9',
#  u'attachable',
#  u'detachable',
#  u'back',
#  u'face',
#  u'main',
#  u'body',
#  u'7',
#  u'optionally',
#  u'attached',
#  u'occasion',
#  u'demands',
#  u'like',
#  u'hopper',
#  u'11',
#  u'extended',
#  u'opened',
#  u'upward',
#  u'disposed',
#  u'upper',
#  u'part',
#  u'main',
#  u'body',
#  u'7',
#  u'shutter',
#  u'12',
#  u'attached',
#  u'lower',
#  u'end',
#  u'hopper',
#  u'11',
#  u'moreover',
#  u'packing',
#  u'machine',
#  u'13',
#  u'disposed',
#  u'hopper',
#  u'11',
#  u'main',
#  u'body',
#  u'7',
#  u'medicine',
#  u'discharged',
#  u'hopper',
#  u'11',
#  u'packed',
#  u'obliquely',
#  u'disposed',
#  u'rolled',
#  u'packing',
#  u'paper',
#  u'shown',
#  u'discharged',
#  u'taking',
#  u'port',
#  u'14',
#  u'hand',
#  u'main',
#  u'body',
#  u'side',
#  u'case',
#  u'storage',
#  u'part',
#  u'8',
#  u'opening',
#  u'front',
#  u'face',
#  u'least',
#  u'left',
#  u'right',
#  u'side',
#  u'faces',
#  u'closed',
#  u'transparent',
#  u'walls',
#  u'16',
#  u'glass',
#  u'resin',
#  u'like',
#  u'moreover',
#  u'main',
#  u'body',
#  u'side',
#  u'chute',
#  u'22',
#  u'vertically',
#  u'defined',
#  u'entire',
#  u'width',
#  u'partition',
#  u'plate',
#  u'21',
#  u'back',
#  u'plate',
#  u'20',
#  u'back',
#  u'main',
#  u'body',
#  u'side',
#  u'case',
#  u'storage',
#  u'part',
#  u'8',
#  u'side',
#  u'lower',
#  u'parts',
#  u'main',
#  u'body',
#  u'side',
#  u'chute',
#  u'22',
#  u'inclined',
#  u'bottom',
#  u'faces',
#  u'23',
#  u'23',
#  u'fig',
#  u'8',
#  u'formed',
#  u'narrowed',
#  u'inclined',
#  u'toward',
#  u'sides',
#  u'upper',
#  u'edge',
#  u'hopper',
#  u'11',
#  u'left',
#  u'right',
#  u'ends',
#  u'main',
#  u'body',
#  u'side',
#  u'case',
#  u'storage',
#  u'part',
#  u'8',
#  u'opening',
#  u'upper',
#  u'part',
#  u'hopper',
#  u'11',
#  u'bottom',
#  u'faces',
#  u'23',
#  u'23',
#  u'shutter',
#  u'24',
#  u'attached',
#  u'top',
#  u'surface',
#  u'7a',
#  u'main',
#  u'body',
#  u'7',
#  u'position',
#  u'opposite',
#  u'opening',
#  u'moreover',
#  u'plurality',
#  u'shelves',
#  u'26',
#  u'extended',
#  u'described',
#  u'partition',
#  u'plate',
#  u'21',
#  u'tablet',
#  u'cases',
#  u'attached',
#  u'shelves',
#  u'26',
#  u'described',
#  u'later',
#  u'inner',
#  u'side',
#  u'part',
#  u'respective',
#  u'shelves',
#  u'26',
#  u'plurality',
#  u'paths',
#  u'30',
#  u'opening',
#  u'18',
#  u'top',
#  u'surface',
#  u'formed',
#  u'extend',
#  u'left',
#  u'right',
#  u'predetermined',
#  u'intervals',
#  u'path',
#  u'30',
#  u'inclined',
#  u'low',
#  u'toward',
#  u'inside',
#  u'connected',
#  u'main',
#  u'body',
#  u'side',
#  u'chute',
#  u'22',
#  u'connector',
#  u'17',
#  u'disposed',
#  u'partition',
#  u'plate',
#  u'21',
#  u'positioned',
#  u'inside',
#  u'opening',
#  u'18',
#  u'large',
#  u'capacity',
#  u'l',
#  u'tablet',
#  u'case',
#  u'3',
#  u'small',
#  u'capacity',
#  u'tablet',
#  u'case',
#  u'4',
#  u'prepared',
#  u'tablet',
#  u'case',
#  u'capacity',
#  u'tablet',
#  u'case',
#  u'3',
#  u'set',
#  u'500',
#  u'cc',
#  u'embodiment',
#  u'capacity',
#  u'tablet',
#  u'case',
#  u'4',
#  u'set',
#  u'250',
#  u'cc',
#  u'moreover',
#  u'since',
#  u'structure',
#  u'tablet',
#  u'case',
#  u'3',
#  u'different',
#  u'tablet',
#  u'case',
#  u'4',
#  u'vertical',
#  u'dimension',
#  u'container',
#  u'51',
#  u'described',
#  u'later',
#  u'tablet',
#  u'case',
#  u'4',
#  u'small',
#  u'tablet',
#  u'case',
#  u'3',
#  u'described',
#  u'hereinafter',
#  u'shown',
#  u'figs',
#  u'5',
#  u'6',
#  u'tablet',
#  u'case',
#  u'3',
#  u'constituted',
#  u'container',
#  u'51',
#  u'formed',
#  u'transparent',
#  u'hard',
#  u'synthetic',
#  u'resin',
#  u'drive',
#  u'table',
#  u'52',
#  u'container',
#  u'51',
#  u'opening',
#  u'top',
#  u'surface',
#  u'medicine',
#  u'supplied',
#  u'via',
#  u'opening',
#  u'moreover',
#  u'discharge',
#  u'drum',
#  u'53',
#  u'rotatably',
#  u'attached',
#  u'position',
#  u'deviates',
#  u'inner',
#  u'side',
#  u'lower',
#  u'part',
#  u'container',
#  u'51',
#  u'top',
#  u'surface',
#  u'discharge',
#  u'drum',
#  u'53',
#  u'formed',
#  u'conical',
#  u'surface',
#  u'whose',
#  ...]

# %% [markdown]
# ##### Word2Vec Cosine Similarity

# %%
w2v_model = Word2Vec(data['new_text'],  min_count=1, window=10, workers=2)

# %%
w2v_model.

# %%
import gensim
# train word2vec on the two sentences
model = gensim.models.Word2Vec(data.new_text)

# %%
data['new_text'] = data.text.apply(review_to_sentences)

# %%
model.similarity('ISA\*', '276')

# %%
def avg_feature_vector(words, model, num_features):
        #function to average all words vectors in a given paragraph
        featureVec = np.zeros((num_features,), dtype="float32")
        nwords = 0

        #list containing names of words in the vocabulary
        index2word_set = set(model.index2word) 
        for word in words:
            if word in index2word_set:
                nwords = nwords+1
                featureVec = np.add(featureVec, model[word])

        if(nwords>0):
            featureVec = np.divide(featureVec, nwords)
        return featureVec

# %%
#get average vector for sentence 1
sentence_1 = data.new_text[0]
sentence_1_avg_vector = avg_feature_vector(sentence_1, model=model, num_features=3000)

#get average vector for sentence 2
sentence_2 = test.new_text[0]
sentence_2_avg_vector = avg_feature_vector(sentence_2, model=model, num_features=3000)

sen1_sen2_similarity =  1 - spatial.distance.cosine(sentence_1_avg_vector,sentence_2_avg_vector)

# %%
import gensim
from gensim.models.doc2vec import TaggedDocument
from collections import namedtuple

# %%
from gensim.models import Doc2Vec
import gensim.models.doc2vec
from collections import OrderedDict
import multiprocessing

cores = multiprocessing.cpu_count()
assert gensim.models.doc2vec.FAST_VERSION > -1, "this will be painfully slow otherwise"

# %%
from sklearn.preprocessing import LabelEncoder
labels = LabelEncoder()
y = labels.fit_transform(data.tag)
print(y.shape)

# %% [raw]
# train_corpus = []
# for i , line in enumerate(data.text):
#     train_corpus.append(gensim.models.doc2vec.TaggedDocument(gensim.utils.simple_preprocess(line), data.tag[i]))

# %% [raw]
# simple_models = [
#     # PV-DM w/concatenation - window=5 (both sides) approximates paper's 10-word total window size
#     Doc2Vec(dm=1, dm_concat=1, size=300, window=5, negative=5, hs=0, min_count=2, workers=cores),
#     # PV-DBOW
#     Doc2Vec(dm=0, size=300, negative=5, hs=0, min_count=2, workers=cores),
#     # PV-DM w/average
#     Doc2Vec(dm=1, dm_mean=1, size=300, window=10, negative=5, hs=0, min_count=2, workers=cores),
# ]
#
# # speed setup by sharing results of 1st model's vocabulary scan
# simple_models[0].build_vocab(wordss)  # PV-DM/concat requires one special NULL word so it serves as template
# print(simple_models[0])
# for model in simple_models[1:]:
#     model.reset_from(simple_models[0])
#     print(model)
#
# models_by_name = OrderedDict((str(model), model) for model in simple_models)

# %%
doc2vec_model = gensim.models.doc2vec.Doc2Vec(min_count=1, window=10, size=5, sample=1e-4, negative=5, workers=cores)

# %%
doc2vec_model.build_vocab(train_corpus)

# %%
doc2vec_model.train(train_corpus)

# %%
doc2vec_model.infer_vector(['only', 'you', 'can', 'prevent', 'forrest', 'fires'])

# %%
test_corpus = []
for i , line in enumerate(test.text):
    test_corpus.append(gensim.models.doc2vec.TaggedDocument(gensim.utils.simple_preprocess(line), test.tag[i]))

# %%
len_doc_vec = len(doc2vec_model.docvecs)
for doc_id in range(len(train_corpus)):
    inferred_vector = doc2vec_model.infer_vector(train_corpus[i].words)
    sims = doc2vec_model.docvecs.most_similar([inferred_vector], topn=len_doc_vec)
    print(sims)

# %%
inferred_vector = doc2vec_model.infer_vector(train_corpus[0].words)
doc2vec_model.docvecs.most_similar([inferred_vector], topn=len_doc_vec)

# %%
doc2vec_model.docvecs.count

# %% [markdown]
# s = "<one-one> two 3.4 5,6 seven.eight nine,ten"
# s = '<guestbook><guest><fname>Terje</fname><lname>Beck</lname></guest><guest><fname>Jan</fname><lname>Refsnes</lname></guest><guest><fname>Torleif</fname><lname>Rasmussen</lname></guest>'
# parts = re.split('\s|(?<!\d)[,.](?!\d)', s)
# parts

# %% [raw]
# re.sub(r"(\w)([*])", r"\1 \2 ", "Word*12*Word*Word")

# %% [markdown]
# s = '<guestbook><guest><fname>Terje Prarrot</fname><lname>Beck</lname></guest><guest><fname>2.54</fname><lname>Ref58j_jjk .vfd.bdfsnes</lname></guest><guest><fname>Torleif</fname><lname>Rasmussen</lname></guest>'
# s = re.sub('<',' <', s)
# s = re.sub('>','> ', s)
# re.split(' |\n',s)

# %% [markdown]
# import re
#
# token_pattern = r"""
# (?P<identifier>[a-zA-Z_][a-zA-Z0-9_]*)
# |(?P<integer>[0-9]+)
# |(?P<dot>\.)
# |(?P<open_variable>[$][{])
# |(?P<open_curly>[{])
# |(?P<close_curly>[}])
# |(?P<newline>\n)
# |(?P<whitespace>\s+)
# |(?P<equals>[=])
# |(?P<slash>[/])
# """
#
# token_re = re.compile(token_pattern, re.VERBOSE)

# %% [markdown]
# class TokenizerException(Exception): pass
#
# def tokenize(text):
#     pos = 0
#     while True:
#         m = token_re.match(text, pos)
#         if not m: break
#         pos = m.end()
#         tokname = m.lastgroup
#         tokvalue = m.group(tokname)
#         yield tokname, tokvalue
#     if pos != len(text):
#         raise TokenizerException('tokenizer stopped at pos %r of %r' % (
#             pos, len(text)))
